# %%
"""
Python script to scrape Friktion User Data from Bitquery GraphQL API.

"""

import json
import requests
import requests
import traceback
import time

import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from os.path import exists


class MyPortfolio:
    """
    Python ETL script for Friktion user portfolio data. Currently supported Instruction Names:
        - Deposit
        - CancelPendingDeposit
        - Withdrawal
        - CancelPendingWithdrawal
        - ClaimPendingWithdrawal
    """

    def __init__(
        self,
        date_start,
        date_end,
        ix_fname="./friktion_ix.csv",
        deposit_fname="./friktion_deposit.csv",
        deposit_cxl_fname="./friktion_deposit_cxl.csv",
        withdraw_fname="./friktion_withdraw.csv",
        withdraw_cxl_fname="./friktion_withdraw_cancel.csv",
        withdraw_claim_fname="./friktion_claim_withdrawal.csv",
        endround_fname="./friktion_end_round2.csv",
        batch_size_days=2,
        batch_size_xfers=80,
        skip_ix_scrape=False
    ):
        """
        :ix_fname:              output csv for instructions
        :deposit_fname:         output csv for deposits
        :deposit_cxl_fname:     output csv for deposit cancels
        :withdraw_fname:        output csv for withdrawals
        :withdraw_cxl_fname:    output csv for withdrawal cancels
        :withdraw_claim_fname:  output csv for claiming pending withdrawal
        :batch_size_days:       batch size in days for query to keep query < 10k symbols. Use bigger steps for larger data.
        :batch_size_transfers:  batch size transactions for query to keep query < 8kb

        """
        print(date_start, date_end)
        self.volt_program = "VoLT1mJz1sbnxwq5Fv2SXjdVDgPXrb9tJyC8WpMDkSp"
        self.date_start = date_start
        self.date_end = date_end
        self.ix_fname = ix_fname
        self.deposit_fname = deposit_fname
        self.deposit_cxl_fname = deposit_cxl_fname
        self.withdraw_fname = withdraw_fname
        self.withdraw_cxl_fname = withdraw_cxl_fname
        self.withdraw_claim_fname = withdraw_claim_fname
        self.end_round_fname = endround_fname
        self.batch_size_days = batch_size_days
        self.batch_size_xfers = batch_size_xfers
        self.skip_ix_scrape = skip_ix_scrape
        
        self.df_ix = pd.read_csv(ix_fname) if skip_ix_scrape else [] 
        print("print_ix", self.df_ix)
        self.friktion_metadata = self.get_friktion_snapshot()

    ########################################################################################################
    ####################################          Queries             ######################################
    ########################################################################################################

    @property
    def ix_query(self):
        return """
            query MyQuery {
              solana {
                instructions(
                  time: {between: ["%s", "%s"]}
                  success: {is: true}
                  programId: {is: "VoLT1mJz1sbnxwq5Fv2SXjdVDgPXrb9tJyC8WpMDkSp"}
                  options: {limit: 8700}
                ) {
                  block {
                    timestamp {
                      iso8601
                    }
                  }
                  transaction {
                    signature
                    feePayer
                  }
                  data {
                    base58
                  }
                }
              }
            }
        """

    @property
    def xfer_query(self):
        return """
            query MyQuery {
              solana(network: solana) {
                transfers(
                  signature: {in: [%s]}
                  options: {limit: 2000}
                ) {
                  instruction {
                    action {
                      name
                    }
                    callPath
                  }
                  amount(success: {is: true})
                  transaction {
                    signer
                    signature
                  }
                  block {
                    timestamp {
                      iso8601
                    }
                  }
                  currency {
                    name
                    address
                  }
                  sender {
                    address
                    mintAccount
                  }
                  receiver {
                    address
                  }
                }
              }
            }
        """

    ########################################################################################################
    ################################          Helper Functions             #################################
    ########################################################################################################

    # TODO: Add retry logic to this in case of hangups.
    @staticmethod
    def run_query(query, retries=10):
        """
        Query graphQL API.

        If timeerror
        """
        headers = {"X-API-KEY": "BQYCaXaMZlqZrPCSQVsiJrKtxKRVcSe4"}

        retries_counter = 0
        try:
            request = requests.post(
                "https://graphql.bitquery.io/", json={"query": query}, headers=headers
            )
            result = request.json()
            # print(dir(request.content))
            # Make sure that there is no error message
            # assert not request.content.errors
            assert "errors" not in result
        except:
            while (
                (request.status_code != 200
                or "errors" in result)
                and retries_counter < 10
            ):
                print(datetime.now(), f"Retry number {retries_counter}")
                if "errors" in result:
                    print(result["errors"])
                print(datetime.now(), f"Query failed for reason: {request.reason}. sleeping for {150*retries_counter} seconds and retrying...")
                time.sleep(150*retries_counter)
                request = requests.post(
                    "https://graphql.bitquery.io/",
                    json={"query": query},
                    headers=headers,
                )
                retries_counter += 1
            if retries_counter >= retries:
                raise Exception(
                    "Query failed after {} retries and return code is {}.{}".format(
                        retries_counter, request.status_code, query
                    )
                )
        return request.json()


    @staticmethod
    def batch_iterable(iterable, n=1):
        """
        Takes in an iterable and returns an iterable of iterables with len==x
        """
        idxs = []
        l = len(iterable)
        for idx in range(0, l, n):
            idxs.append(iterable[idx : min(idx + n, l)])
        return idxs

    def format_txs_for_query(self, tx_signatures):
        """
        Batches a list of transactions into a list of string formatted transactions for querying.
        Each of these strings contain (n=self.batch_size_xfers) unique transaction IDs.
        """
        batched_signatures = self.batch_iterable(tx_signatures, self.batch_size_xfers)

        def format_txs(x):
            return str(x)[1:-1].replace("'", '"').replace("\n", "")

        tx_strs = list(map(format_txs, batched_signatures))

        return tx_strs

    def get_existing_df(self, fname):
        """
        Create output file if doesn't exist and returns a DataFrame
        """
        if fname and exists(fname):
            return pd.read_csv(fname)
        else:
            return pd.DataFrame()

    @staticmethod
    def instruction_match(instructionData):
        """
        Match 8-bit instruction identifier with the corresonding instructionType
        """
        if not instructionData or len(instructionData) < 8:
            return False

        instructionDescriptor = instructionData[:8]

        if instructionDescriptor == "A4eeE44X":
            print("EndRound")
            return "EndRound"

    def get_friktion_snapshot(self):
        """
        Load Friktion Metadata for Volt/Symbol Mapping to join to normal data

        """
        try:
            return pd.DataFrame(
                dict(
                    json.loads(
                        requests.get(
                            "https://friktion-labs.github.io/mainnet-tvl-snapshots/friktionSnapshot.json"
                        ).content
                    )
                )["allMainnetVolts"]
            )[
                [
                    "globalId",
                    "vaultAuthority",
                    "shareTokenMint",
                    "depositTokenSymbol",
                    "depositTokenCoingeckoId",
                ]
            ]
        except Exception as e:
            print(datetime.now(), "Snapshot Data Invalid")
            traceback.print_exc()

    ########################################################################################################
    ################################          Data Retrieval             ###################################
    ########################################################################################################

    def get_ix(self, date_start, date_end):
        """
        Runs graphql instruction query for one date range.
        """
        print(date_start, date_end)
        query = self.ix_query % (date_start, date_end)
        print(
            datetime.now(),
            "retrieving instructions for {} to {}".format(date_start, date_end),
        )
        result = self.run_query(query)

        # convert GraphQL json to pandas dataframe
        try:
            df = pd.json_normalize(result["data"]["solana"]["instructions"])
        except:
            print(result)
            traceback.print_exc()
            raise Exception(datetime.now(), "Empty Results... Try Again")

        print(datetime.now(), df.shape[0], "instructions retrieved")

        df = df.rename(
            columns={
                "block.timestamp.iso8601": "timestamp",
                "log.consumed": "computeUnits",
                "transaction.signature": "txSignature",
                "transaction.feePayer": "txSigner",
                "data.base58": "instructionData",
            }
        )
        return df

    def get_ix_batch(self):
        """
        Batch the instruction retrieval. Save the shit Drop duplicates.

        """
        # Batch the days up nice and good so the graphql API calls don't bitch
        dates_batched = pd.date_range(self.date_start, self.date_end, freq=f"{self.batch_size_days}D")
        dates_batched = [
            str(x.isoformat())
            for x in dates_batched.append(pd.DatetimeIndex([self.date_end]))
        ]
        date_ranges = list(zip(dates_batched, dates_batched[1:]))
        ixs = []
        for date_range in date_ranges:
            assert len(date_range) == 2
            data = self.get_ix(date_range[0], date_range[1])
            ixs.append(data)

        df_ix = pd.concat(ixs, ignore_index=False)
        df_ix["instructionType"] = df_ix.instructionData.apply(
            lambda x: self.instruction_match(x)
        )

        # Store df_ix before we write it to the DataFrame so we avoid getting xfers for every single ix 
        self.df_ix = df_ix.drop_duplicates(["txSignature", "instructionType"]).reset_index(drop=True)
        print(datetime.now(), "final instruction data size: ", df_ix.shape[0])

        # Save new data to file
        df_old = self.get_existing_df(self.ix_fname)
        df = df_ix.append(df_old).reset_index(drop=True)
        df = df.drop_duplicates(["txSignature", "instructionType"])
        df.to_csv(self.ix_fname, index=False)
        print(datetime.now(), "wrote instruction data to csv...")

    def get_batched_xfers(self, instructionType, fname):
        """
        Get all transfers corresponding to a specific instructionType from Graphql query.
        Batch these queries up b/c the string size is
        too large (curse GraphQL for not supporting joins)

        :instructionType: String corresponding to the instruction type of each query.
        :fname: Name of where the old df is stored

        """

        temp = self.df_ix.query(f"instructionType == '{instructionType}'")

        if temp.empty:
            print(
                datetime.now(), "instructionType was not found in the data... breaking"
            )
            return

        tx_signatures = list(temp["txSignature"].unique())
        tx_strs = self.format_txs_for_query(tx_signatures)
        print(datetime.now(), len(tx_strs), "signature batches required...")
        xfers = []

        for i, tx_str in enumerate(tx_strs):
            query = self.xfer_query % (tx_str)
            result = self.run_query(query)
            # TODO: Clean up this duplicated logic
            try:
                df = pd.json_normalize(result["data"]["solana"]["transfers"])
            except:
                print(result)
                traceback.print_exc()
                raise Exception("Empty Results... Try Again")
            xfers.append(df)
            print(datetime.now(), df.shape[0], "transfers scraped in batch %d" % i)

        df_xfer = pd.concat(xfers, ignore_index=False)
        df_xfer = df_xfer.rename(
            columns={
                "block.timestamp.iso8601": "timestamp",
                "instruction.action.name": "instructionAction",
                "instruction.callPath": "instructionOrder",
                "transaction.signer": "userAddress",
                "transaction.signature": "txSignature",
                "currency.name": "currencyName",
                "receiver.address": "receiverAddress",
                "sender.address": "senderAddress",
                "currency.decimals": "currencyDecimals",
                "currency.address": "currencyAddress",
                "sender.mintAccount": "senderTokenMint",
            }
        )

        print(datetime.now(), df_xfer.shape[0], "transfers retrieved")

        return df_xfer
        
    def parse_endRound(self):
        instructionType = "EndRound"
        instructionAction = "transfer"
        tx_merge_key = "currencyAddress"
        meta_merge_key = "shareTokenMint"
        out_file = self.end_round_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )
        

    def parse_base(
        self,
        instructionType,
        instructionAction,
        tx_merge_key,
        meta_merge_key,
        output_file,
    ):
        """
        generalized method for parsing transfer data.

        1. Call get_batched_xfers()
        2. for each unique txSignature, find the xfer matching to the last instance of the instructionAction
        3. For SOL CC vaults, need an extra step and query for instructionAccount to find vaultAuthority.
        3. Join it to the friktion metadata based using tx_merge_key and meta_merge_key
        4. Drop extraneous rows
        5. Save the file to the output_file

        :instructionType: Type of instruction listed out in the instruction_match() method
        :instructionAction: type of transfer we are matching towards
        :tx_merge_key: what key in the xfer dataFrame do we want to merge on
        :meta_merge_key: what key in the metadata dataFrame we want to merge on.
        :output_file: as name suggests
        """
        print(
            datetime.now(),
            "Parsing transfers for instructionType: %s" % instructionType,
        )
        df = self.get_batched_xfers(instructionType, output_file)

#         Target only wrapped SOL entries for SOL vaults
        df = df.query('currencyName != "Solana"')
#         )
        shareTokendf = df.query("instructionAction=='mintTo'").copy()
        backup = df.query("instructionOrder=='0-0'").copy()
    
        def find_matching_call_path(x):
            [path1, path2] = x.split("-")
            newCallPath = path1+"-"+str(int(path2)-1)
            return newCallPath
        
        shareTokendf["instructionOrderPair"] = shareTokendf.instructionOrder.apply(find_matching_call_path)
        
        df = pd.merge(shareTokendf, df, left_on=["txSignature", "instructionOrderPair"], 
                      right_on=["txSignature", "instructionOrder"], suffixes=("", "_x"))
        
        df = pd.merge(backup, df, left_on=["txSignature"], 
                      right_on=["txSignature"], suffixes=("_y", ""))
        
        print(df)
        print(df.amount_x.isna().sum())
        print(df.amount.isna().sum())
        df["shareTokenPrice"] = df.amount_x/df.amount
        print(backup.instructionOrder, backup.txSignature, backup.amount)
        df["backupValue"] = df.amount
        
        # Join tables and get rid of extraneous columns from metadata.
        df = pd.merge(
            df,
            self.friktion_metadata,
            how="left",
            left_on=tx_merge_key,
            right_on=meta_merge_key,
            suffixes=("", "_drop"),
        )
        df.drop([col for col in df.columns if "drop" in col], axis=1, inplace=True)

        # Tag the row with the instructionType
        df["userAction"] = instructionType

        df.drop_duplicates().to_csv(output_file, index=False)
        print(datetime.now(), "{} data size: {}".format(instructionType, df.shape[0]))

    def parse_all(self):
        if not self.skip_ix_scrape:
            self.get_ix_batch()
        print("hello")
        self.parse_endRound()

# %%
# date_start = "2021-12-10T00:00:00Z"
date_start = "2021-12-10T00:00:00Z"

date_end = "2022-05-09T08:00:00Z"

x = MyPortfolio(date_start, date_end, skip_ix_scrape=True)

x.parse_all()

dHbWXmci3dT8UFYWYZweBLXgycu7Y3iL6trKn1Y7ARj
# 345         USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 346         USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
#
#                                   senderAddress_y  \
# 0    AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8
# 1    HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
# 2    Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 3    BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 4    2Ahpeqc1bo7Y4dVknvZUVfZPhHhym7JN6az2XMbUA6QA
# ..                                            ...
# 342  5oV1Yf8q1oQgPYuHjepjmKFuaG2Wng9dzTqbSWhU5W2X
# 343  2P427N5sYcEXvZAZwqNzjXEHsBMESQoLyjNquTSmGPMb
# 344  2Ahpeqc1bo7Y4dVknvZUVfZPhHhym7JN6az2XMbUA6QA
# 345  CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# 346  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
#
#                                 senderTokenMint_y  ...      amount_x  \
# 0    HWQn2UdZNzmiPnm8RbuXgeLDnYQGmkw2fJTBD4xso9wD  ...  83825.483696
# 1    CptnNvSuZwM4jsbApVwdPUyZzzyRzBktA28DRdq5K3zR  ...      0.000000
# 2     unrWTSSfz6H7DzYYHRTuTCK3yVzR1YUNqUn7xWwr4Z5  ...   2880.345509
# 3    3C8SvZ9EcYNbEesWh5nF7hEBZgx632ntvkZk5MQ8Hk6h  ...      0.000000
# 4    4aoSKSt2jdqg3R6x9gJxFSVXnR7XLnjYBbhxW5qbLpKm  ...    344.714150
# ..                                            ...  ...           ...
# 342  3nWapVJ5ocrGyM6r5rUJrAXbcRKa2w2v9rVbbqe74jk6  ...    686.930443
# 343  JBPXzHLMDTN3BLACACcBHM1CAfNz2r1s6tUMUhCMgGCZ  ...  12841.645846
# 344  4aoSKSt2jdqg3R6x9gJxFSVXnR7XLnjYBbhxW5qbLpKm  ...    446.177748
# 345  FP7rhnmHexx2Tb4vbt7AX2PjEErSxFgnb8L2NwXwjT1D  ...  32217.656908
# 346   P7TTBhKxrQg4BS651fB5cLX9Jn2UyL2LxeNayrLEMbX  ...      0.000000
#
#      instructionAction_x instructionOrder_x  \
# 0               transfer                0-2
# 1               transfer                0-2
# 2               transfer                0-2
# 3               transfer                0-2
# 4               transfer                0-2
# ..                   ...                ...
# 342             transfer                0-2
# 343             transfer                0-2
# 344             transfer                0-2
# 345             transfer                0-1
# 346             transfer                0-2
#
#                                     userAddress_x           timestamp_x  \
# 0    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-05-06T03:32:04Z
# 1    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-28T02:51:33Z
# 2    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-05-06T03:24:25Z
# 3    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-05-05T03:52:23Z
# 4    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-29T04:47:53Z
# ..                                            ...                   ...
# 342  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-22T03:23:03Z
# 343  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-22T03:21:38Z
# 344  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-22T03:15:26Z
# 345  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-15T22:35:46Z
# 346  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-21T03:12:31Z
#
#       currencyName_x                             currencyAddress_x  \
# 0                     Cvvh8nsKZet59nsDDo3orMa3rZnPWQhpgrMCVcRDRgip
# 1           USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 2        Wrapped SOL   So11111111111111111111111111111111111111112
# 3           USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 4    Lido Staked SOL  7dHbWXmci3dT8UFYWYZweBLXgycu7Y3iL6trKn1Y7ARj
# ..               ...                                           ...
# 342  LUNA (Wormhole)  F6v4wfAdJB8D8p77bMXZgYt8TDKsYxLYxH5AFhUkYx9W
# 343            Serum   SRMuApVNdxXokk5GT7XD5cUUgXMBCoAz2LHeuAoKWRt
# 344  Lido Staked SOL  7dHbWXmci3dT8UFYWYZweBLXgycu7Y3iL6trKn1Y7ARj
# 345         USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 346         USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
#
#                                   senderAddress_x  \
# 0    AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8
# 1    HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
# 2    Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 3    BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 4    2Ahpeqc1bo7Y4dVknvZUVfZPhHhym7JN6az2XMbUA6QA
# 60     14320.367000
# 61       496.107477
# Name: amount, Length: 347, dtype: float64
# 2022-05-06 05:35:36.332688 EndRound data size: 347

# %%
#         ix = pd.read_csv("friktion_ix.csv")
#         deposits = pd.read_csv("friktion_deposit.csv")
#         withdrawals = pd.read_csv("friktion_withdraw.csv")
#         claim = pd.read_csv(self.withdraw_claim_fname)
#         withdrawals_cxl = pd.read_csv(self.withdraw_cxl_fname)
#         deposits_cxl = pd.read_csv(self.deposit_cxl_fname)
end_round = pd.read_csv('friktion_end_round2.csv')
end_round["timestamp_numba"] = pd.to_datetime(end_round.timestamp).astype('int')//1000000

# %%
DEPOSIT_VALUES = {
    "mainnet_income_put_sol_step_circuits": [[1641033886000, 10000000]],
    "mainnet_income_put_btc_step_circuits": [[1641033886000, 2631100]],
    "mainnet_income_put_sol_uxd_circuits": [[1641033886000, 10000100]],
    "mainnet_income_put_sol_parrot_circuits": [[1641033886000, 1000000]],

    
}

# %%
end_round.loc[end_round.shareTokenPrice.isna()]
# Out:
#         amount_y instructionAction_y instructionOrder_y  \
# 1     295.528741            transfer                0-0
# 3    5396.288620            transfer                0-0
# 7     842.742768            transfer                0-0
# 12      0.000000            transfer                0-0
# 16      0.000000            transfer                0-0
# 21   1003.398480            transfer                0-0
# 38      0.000000            transfer                0-0
# 42      0.001000            transfer                0-0
# 46   3000.583286            transfer                0-0
# 48    670.374143            transfer                0-0
# 49    401.009532            transfer                0-0
# 55      0.999600            transfer                0-0
# 57      0.000000            transfer                0-0
# 59      0.000000            transfer                0-0
# 62    621.186426            transfer                0-0
# 129     0.001000            transfer                0-0
# 145     0.000000            transfer                0-0
# 189  3341.940688            transfer                0-0
# 212   616.253400            transfer                0-0
# 233  2559.655728            transfer                0-0
# 242  2562.432616            transfer                0-0
# 245   798.268564            transfer                0-0
# 251   188.766063            transfer                0-0
# 254   703.731394            transfer                0-0
# 256   419.888977            transfer                0-0
# 258  3066.909245            transfer                0-0
# 270   127.320351            transfer                0-0
# 274   166.590837            transfer                0-0
# 289   267.396998            transfer                0-0
# 301     0.001000            transfer                0-0
# 303   306.734856            transfer                0-0
# 305     0.000900            transfer                0-0
# 308   390.414771            transfer                0-0
# 314  2297.940456            transfer                0-0
# 319   977.548824            transfer                0-0
# 330  3558.992833            transfer                0-0
# 331   350.649684            transfer                0-0
# 346   496.107477            transfer                0-0
#
#                                     userAddress_y  \
# 1    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 3    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 7    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 12   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 16   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 21   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 38   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 42   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 46   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 48   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 49   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 55   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 57   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 59   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 62   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 129  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 145  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 189  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 212  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 233  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 242  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 245  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 251  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 254  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 256  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 258  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 270  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 274  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 289  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 301  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 303  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 305  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 308  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 314  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 319  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 330  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 331  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 346  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 254  ALo9jmuDsBxjqEpb2rs4UeNDdWK3UPm8TCcTQU4gofkT  ...
# 256   P7TTBhKxrQg4BS651fB5cLX9Jn2UyL2LxeNayrLEMbX  ...
# 258  3C8SvZ9EcYNbEesWh5nF7hEBZgx632ntvkZk5MQ8Hk6h  ...
# 270  FP7rhnmHexx2Tb4vbt7AX2PjEErSxFgnb8L2NwXwjT1D  ...
# 274  CptnNvSuZwM4jsbApVwdPUyZzzyRzBktA28DRdq5K3zR  ...
# 289  CptnNvSuZwM4jsbApVwdPUyZzzyRzBktA28DRdq5K3zR  ...
# 301  Ftnwc6KXMrgpbiCDPJncUJPyefTWRAtkoAJmxDfiavMq  ...
# 303   P7TTBhKxrQg4BS651fB5cLX9Jn2UyL2LxeNayrLEMbX  ...
# 305  Ftnwc6KXMrgpbiCDPJncUJPyefTWRAtkoAJmxDfiavMq  ...
# 308   P7TTBhKxrQg4BS651fB5cLX9Jn2UyL2LxeNayrLEMbX  ...
# 314  3C8SvZ9EcYNbEesWh5nF7hEBZgx632ntvkZk5MQ8Hk6h  ...
# 319  ALo9jmuDsBxjqEpb2rs4UeNDdWK3UPm8TCcTQU4gofkT  ...
# 330  3C8SvZ9EcYNbEesWh5nF7hEBZgx632ntvkZk5MQ8Hk6h  ...
# 331  CptnNvSuZwM4jsbApVwdPUyZzzyRzBktA28DRdq5K3zR  ...
# 346   P7TTBhKxrQg4BS651fB5cLX9Jn2UyL2LxeNayrLEMbX  ...
#
#                                 receiverAddress_x  shareTokenPrice  \
# 1    HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz              NaN
# 3    BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ              NaN
# 7    EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD              NaN
# 12   FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp              NaN
# 16   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH              NaN
# 21   8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY              NaN
# 38   FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp              NaN
# 42   8oGPKyCV92n2X3shzhHfn8HLEUA222hFccN4mpirg8ZB              NaN
# 46   BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ              NaN
# 48   8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY              NaN
# 49   EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD              NaN
# 55   9V6FswSAGuv4Y2UMmSzZHcCt2s71BRLwX9kyU1PF9zPA              NaN
# 57   DA1M8mw7GnPNKU9ReANtHPQyuVzKZtsuuSbCyc2uX2du              NaN
# 59   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH              NaN
# 62   HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz              NaN
# 129  8oGPKyCV92n2X3shzhHfn8HLEUA222hFccN4mpirg8ZB              NaN
# 145  8oGPKyCV92n2X3shzhHfn8HLEUA222hFccN4mpirg8ZB              NaN
# 189  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ              NaN
# 212  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD              NaN
# 233  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ              NaN
# 242  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ              NaN
# 245  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY              NaN
# 251  HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz              NaN
# 254  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY              NaN
# 256  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD              NaN
# 258  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ              NaN
# 270  CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6              NaN
# 274  HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz              NaN
# 289  HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz              NaN
# 301  5KZY4cG8vHfmFYrs4NVRik6yof3ArcwCY8GtTG7aH3yv              NaN
# 303  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD              NaN
# 305  5KZY4cG8vHfmFYrs4NVRik6yof3ArcwCY8GtTG7aH3yv              NaN
# 308  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD              NaN
# 314  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ              NaN
# 319  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY              NaN
# 330  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ              NaN
# 331  HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz              NaN
# 346  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD              NaN
#
#     backupValue                                globalId  \
# 1           0.0     mainnet_income_put_sol_uxd_circuits
# 3           0.0    mainnet_income_put_sol_step_circuits
# 7           0.0  mainnet_income_put_sol_parrot_circuits
# 12          0.0                 mainnet_income_call_eth
# 16          0.0            mainnet_income_call_marinade
# 21          0.0    mainnet_income_put_btc_step_circuits
# 38          0.0                 mainnet_income_call_eth
# 42          0.0                                     NaN
# 46          0.0    mainnet_income_put_sol_step_circuits
# 48          0.0    mainnet_income_put_btc_step_circuits
# 49          0.0  mainnet_income_put_sol_parrot_circuits
# 55          0.0                                     NaN
# 57          0.0                 mainnet_income_call_btc
# 59          0.0            mainnet_income_call_marinade
# 62          0.0     mainnet_income_put_sol_uxd_circuits
# 129         0.0                                     NaN
# 145         0.0                                     NaN
# 189         0.0    mainnet_income_put_sol_step_circuits
# 212         0.0  mainnet_income_put_sol_parrot_circuits
# 233         0.0    mainnet_income_put_sol_step_circuits
# 242         0.0    mainnet_income_put_sol_step_circuits
# 245         0.0    mainnet_income_put_btc_step_circuits
# 251         0.0     mainnet_income_put_sol_uxd_circuits
# 254         0.0    mainnet_income_put_btc_step_circuits
# 256         0.0  mainnet_income_put_sol_parrot_circuits
# 258         0.0    mainnet_income_put_sol_step_circuits
# 270         0.0                 mainnet_income_put_mngo
# 274         0.0     mainnet_income_put_sol_uxd_circuits
# 289         0.0     mainnet_income_put_sol_uxd_circuits
# 301         0.0                                     NaN
# 303         0.0  mainnet_income_put_sol_parrot_circuits
# 305         0.0                                     NaN
# 308         0.0  mainnet_income_put_sol_parrot_circuits
# 314         0.0    mainnet_income_put_sol_step_circuits
# 319         0.0    mainnet_income_put_btc_step_circuits
# 330         0.0    mainnet_income_put_sol_step_circuits
# 331         0.0     mainnet_income_put_sol_uxd_circuits
# 346         0.0  mainnet_income_put_sol_parrot_circuits
#
#                                    vaultAuthority  \
# 1    HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
# 3    BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 7    EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
# 12   FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# 16   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH
# 21   8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY
# 38   FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# 42                                            NaN
# 46   BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 48   8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY
# 49   EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
# 55                                            NaN
# 57   DA1M8mw7GnPNKU9ReANtHPQyuVzKZtsuuSbCyc2uX2du
# 59   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH
# 62   HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
# 129                                           NaN
# 145                                           NaN
# 189  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 212  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
# 233  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 242  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 245  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY
# 251  HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
# 254  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY
# 256  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
# 258  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 270  CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# 274  HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
# 289  HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
# 301                                           NaN
# 303  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
# 305                                           NaN
# 308  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
# 314  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 319  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY
# 330  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 331  HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
# 346  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
#
#                                    shareTokenMint  depositTokenSymbol  \
# 1    BAyzqZuKUQ4k93Yfm3xp85SkAKtr4xghBsqZLBTZT14z                USDC
# 3     Bikt7D3nMQmJSpxX7oczCDKgevrpWk3g4D3VhQZzqAT                USDC
# 7    J1TX6c1R6WykW2wonvrL6xA2g8vZ2FLDqDDF1mLYrMYK                USDC
# 12   GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS                 ETH
# 16   6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt                mSOL
# 21   ET4nQ6we7KDemfzni8dy2EkNCuYo1RryiRPjC6XwnnC3                USDC
# 38   GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS                 ETH
# 42                                            NaN                 NaN
# 46    Bikt7D3nMQmJSpxX7oczCDKgevrpWk3g4D3VhQZzqAT                USDC
# 48   ET4nQ6we7KDemfzni8dy2EkNCuYo1RryiRPjC6XwnnC3                USDC
# 49   J1TX6c1R6WykW2wonvrL6xA2g8vZ2FLDqDDF1mLYrMYK                USDC
# 55                                            NaN                 NaN
# 57   3BjcHXvyzMsjmeqE2qFLx45K4XFx3JPiyRnjJiF5MAHt                 BTC
# 59   6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt                mSOL
# 62   BAyzqZuKUQ4k93Yfm3xp85SkAKtr4xghBsqZLBTZT14z                USDC
# 129                                           NaN                 NaN
# 145                                           NaN                 NaN
# 189   Bikt7D3nMQmJSpxX7oczCDKgevrpWk3g4D3VhQZzqAT                USDC
# 212  J1TX6c1R6WykW2wonvrL6xA2g8vZ2FLDqDDF1mLYrMYK                USDC
# 233   Bikt7D3nMQmJSpxX7oczCDKgevrpWk3g4D3VhQZzqAT                USDC
# 242   Bikt7D3nMQmJSpxX7oczCDKgevrpWk3g4D3VhQZzqAT                USDC
# 245  ET4nQ6we7KDemfzni8dy2EkNCuYo1RryiRPjC6XwnnC3                USDC
# 251  BAyzqZuKUQ4k93Yfm3xp85SkAKtr4xghBsqZLBTZT14z                USDC
# 254  ET4nQ6we7KDemfzni8dy2EkNCuYo1RryiRPjC6XwnnC3                USDC
# 256  J1TX6c1R6WykW2wonvrL6xA2g8vZ2FLDqDDF1mLYrMYK                USDC
# 258   Bikt7D3nMQmJSpxX7oczCDKgevrpWk3g4D3VhQZzqAT                USDC
# 270  CxHG1tPkeEHsAVmPF2UrjZK3W719J5DGFgMaLtUkBoeP                USDC
# 274  BAyzqZuKUQ4k93Yfm3xp85SkAKtr4xghBsqZLBTZT14z                USDC
# 289  BAyzqZuKUQ4k93Yfm3xp85SkAKtr4xghBsqZLBTZT14z                USDC
# 301                                           NaN                 NaN
# 303  J1TX6c1R6WykW2wonvrL6xA2g8vZ2FLDqDDF1mLYrMYK                USDC
# 305                                           NaN                 NaN
# 308  J1TX6c1R6WykW2wonvrL6xA2g8vZ2FLDqDDF1mLYrMYK                USDC
# 314   Bikt7D3nMQmJSpxX7oczCDKgevrpWk3g4D3VhQZzqAT                USDC
# 319  ET4nQ6we7KDemfzni8dy2EkNCuYo1RryiRPjC6XwnnC3                USDC
# 330   Bikt7D3nMQmJSpxX7oczCDKgevrpWk3g4D3VhQZzqAT                USDC
# 331  BAyzqZuKUQ4k93Yfm3xp85SkAKtr4xghBsqZLBTZT14z                USDC
# 346  J1TX6c1R6WykW2wonvrL6xA2g8vZ2FLDqDDF1mLYrMYK                USDC
#
#     depositTokenCoingeckoId  userAction  timestamp_numba
# 1                  usd-coin    EndRound    1651114293000
# 3                  usd-coin    EndRound    1651722743000
# 7                  usd-coin    EndRound    1651721079000
# 12                 ethereum    EndRound    1640134626000
# 16                     msol    EndRound    1640063521000
# 21                 usd-coin    EndRound    1651114784000
# 38                 ethereum    EndRound    1640129217000
# 42                      NaN    EndRound    1642106598000
# 46                 usd-coin    EndRound    1651114457000
# 48                 usd-coin    EndRound    1651722914000
# 49                 usd-coin    EndRound    1651114257000
# 55                      NaN    EndRound    1642144751000
# 57                  bitcoin    EndRound    1639880221000
# 59                     msol    EndRound    1640066351000
# 62                 usd-coin    EndRound    1651721202000
# 129                     NaN    EndRound    1643955998000
# 145                     NaN    EndRound    1643952440000
# 189                usd-coin    EndRound    1648088887000
# 212                usd-coin    EndRound    1648089292000
# 233                usd-coin    EndRound    1647483710000
# 242                usd-coin    EndRound    1649902891000
# 245                usd-coin    EndRound    1649298300000
# 251                usd-coin    EndRound    1649297759000
# 254                usd-coin    EndRound    1649902884000
# 256                usd-coin    EndRound    1648692594000
# 258                usd-coin    EndRound    1648692279000
# 270                usd-coin    EndRound    1648788992000
# 274                usd-coin    EndRound    1648692876000
# 289                usd-coin    EndRound    1649902780000
# 301                     NaN    EndRound    1649920391000
# 303                usd-coin    EndRound    1649297744000
# 305                     NaN    EndRound    1649919466000
# 308                usd-coin    EndRound    1649902751000
# 314                usd-coin    EndRound    1649298222000
# 319                usd-coin    EndRound    1650511305000
# 330                usd-coin    EndRound    1650510894000
# 331                usd-coin    EndRound    1650510888000
# 346                usd-coin    EndRound    1650510751000
#
# [38 rows x 41 columns]

# %%
OVERRIDES = [
    {
        "globalId": "mainnet_income_put_mngo", 
        "index": 10, 
        "operation": "insert", 
        "value": 1.0472839410249204+0.0021
    },
    {
        "globalId": "mainnet_income_call_luna", 
        "index": 13, 
        "operation": "replace", 
        "value": 1.0312272300070189+1.17
    },
    {
        "globalId": "mainnet_income_call_luna", 
        "index": 13, 
        "operation": "replace", 
        "value": 1.0312272300070189+1.17
    },
]

# %%
for globalId in end_round.globalId.unique():
    print(globalId)
    if globalId!=globalId or "circuits" in globalId:
        continue
    temp = end_round.query("globalId == @globalId").copy().sort_values("timestamp")
    output = temp[["timestamp_numba", "shareTokenPrice"]].values.tolist()
    output =  list(filter(lambda x: x, map(lambda x: [int(x[0]), x[1]] if x[1]==x[1] else None, output)))
    if output[0][1] < 0.999999 or output[0][1] > 1.0000001:
        output.insert(0, [output[0][0]-61*60*24*7*1000, 1.0])
    print(output)
