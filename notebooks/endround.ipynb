# %%
"""
Python script to scrape Friktion User Data from Bitquery GraphQL API.

"""

import json
import requests
import requests
import traceback
import time

import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from os.path import exists


class MyPortfolio:
    """
    Python ETL script for Friktion user portfolio data. Currently supported Instruction Names:
        - Deposit
        - CancelPendingDeposit
        - Withdrawal
        - CancelPendingWithdrawal
        - ClaimPendingWithdrawal
    """

    def __init__(
        self,
        date_start,
        date_end,
        ix_fname="./friktion_ix.csv",
        deposit_fname="./friktion_deposit.csv",
        deposit_cxl_fname="./friktion_deposit_cxl.csv",
        withdraw_fname="./friktion_withdraw.csv",
        withdraw_cxl_fname="./friktion_withdraw_cancel.csv",
        withdraw_claim_fname="./friktion_claim_withdrawal.csv",
        endround_fname="./friktion_end_round2.csv",
        batch_size_days=2,
        batch_size_xfers=80,
        skip_ix_scrape=False
    ):
        """
        :ix_fname:              output csv for instructions
        :deposit_fname:         output csv for deposits
        :deposit_cxl_fname:     output csv for deposit cancels
        :withdraw_fname:        output csv for withdrawals
        :withdraw_cxl_fname:    output csv for withdrawal cancels
        :withdraw_claim_fname:  output csv for claiming pending withdrawal
        :batch_size_days:       batch size in days for query to keep query < 10k symbols. Use bigger steps for larger data.
        :batch_size_transfers:  batch size transactions for query to keep query < 8kb

        """
        print(date_start, date_end)
        self.volt_program = "VoLT1mJz1sbnxwq5Fv2SXjdVDgPXrb9tJyC8WpMDkSp"
        self.date_start = date_start
        self.date_end = date_end
        self.ix_fname = ix_fname
        self.deposit_fname = deposit_fname
        self.deposit_cxl_fname = deposit_cxl_fname
        self.withdraw_fname = withdraw_fname
        self.withdraw_cxl_fname = withdraw_cxl_fname
        self.withdraw_claim_fname = withdraw_claim_fname
        self.end_round_fname = endround_fname
        self.batch_size_days = batch_size_days
        self.batch_size_xfers = batch_size_xfers
        self.skip_ix_scrape = skip_ix_scrape
        
        self.df_ix = pd.read_csv(ix_fname) if skip_ix_scrape else [] 
        print("print_ix", self.df_ix)
        self.friktion_metadata = self.get_friktion_snapshot()

    ########################################################################################################
    ####################################          Queries             ######################################
    ########################################################################################################

    @property
    def ix_query(self):
        return """
            query MyQuery {
              solana {
                instructions(
                  time: {between: ["%s", "%s"]}
                  success: {is: true}
                  programId: {is: "VoLT1mJz1sbnxwq5Fv2SXjdVDgPXrb9tJyC8WpMDkSp"}
                  options: {limit: 8700}
                ) {
                  block {
                    timestamp {
                      iso8601
                    }
                  }
                  transaction {
                    signature
                    feePayer
                  }
                  data {
                    base58
                  }
                }
              }
            }
        """

    @property
    def xfer_query(self):
        return """
            query MyQuery {
              solana(network: solana) {
                transfers(
                  signature: {in: [%s]}
                  options: {limit: 2000}
                ) {
                  instruction {
                    action {
                      name
                    }
                    callPath
                  }
                  amount(success: {is: true})
                  transaction {
                    signer
                    signature
                  }
                  block {
                    timestamp {
                      iso8601
                    }
                  }
                  currency {
                    name
                    address
                  }
                  sender {
                    address
                    mintAccount
                  }
                  receiver {
                    address
                  }
                }
              }
            }
        """

    ########################################################################################################
    ################################          Helper Functions             #################################
    ########################################################################################################

    # TODO: Add retry logic to this in case of hangups.
    @staticmethod
    def run_query(query, retries=10):
        """
        Query graphQL API.

        If timeerror
        """
        headers = {"X-API-KEY": "BQYCaXaMZlqZrPCSQVsiJrKtxKRVcSe4"}

        retries_counter = 0
        try:
            request = requests.post(
                "https://graphql.bitquery.io/", json={"query": query}, headers=headers
            )
            result = request.json()
            # print(dir(request.content))
            # Make sure that there is no error message
            # assert not request.content.errors
            assert "errors" not in result
        except:
            while (
                (request.status_code != 200
                or "errors" in result)
                and retries_counter < 10
            ):
                print(datetime.now(), f"Retry number {retries_counter}")
                if "errors" in result:
                    print(result["errors"])
                print(datetime.now(), f"Query failed for reason: {request.reason}. sleeping for {150*retries_counter} seconds and retrying...")
                time.sleep(150*retries_counter)
                request = requests.post(
                    "https://graphql.bitquery.io/",
                    json={"query": query},
                    headers=headers,
                )
                retries_counter += 1
            if retries_counter >= retries:
                raise Exception(
                    "Query failed after {} retries and return code is {}.{}".format(
                        retries_counter, request.status_code, query
                    )
                )
        return request.json()


    @staticmethod
    def batch_iterable(iterable, n=1):
        """
        Takes in an iterable and returns an iterable of iterables with len==x
        """
        idxs = []
        l = len(iterable)
        for idx in range(0, l, n):
            idxs.append(iterable[idx : min(idx + n, l)])
        return idxs

    def format_txs_for_query(self, tx_signatures):
        """
        Batches a list of transactions into a list of string formatted transactions for querying.
        Each of these strings contain (n=self.batch_size_xfers) unique transaction IDs.
        """
        batched_signatures = self.batch_iterable(tx_signatures, self.batch_size_xfers)

        def format_txs(x):
            return str(x)[1:-1].replace("'", '"').replace("\n", "")

        tx_strs = list(map(format_txs, batched_signatures))

        return tx_strs

    def get_existing_df(self, fname):
        """
        Create output file if doesn't exist and returns a DataFrame
        """
        if fname and exists(fname):
            return pd.read_csv(fname)
        else:
            return pd.DataFrame()

    @staticmethod
    def instruction_match(instructionData):
        """
        Match 8-bit instruction identifier with the corresonding instructionType
        """
        if not instructionData or len(instructionData) < 8:
            return False

        instructionDescriptor = instructionData[:8]

        if instructionDescriptor == "A4eeE44X":
            print("EndRound")
            return "EndRound"

    def get_friktion_snapshot(self):
        """
        Load Friktion Metadata for Volt/Symbol Mapping to join to normal data

        """
        try:
            return pd.DataFrame(
                dict(
                    json.loads(
                        requests.get(
                            "https://friktion-labs.github.io/mainnet-tvl-snapshots/friktionSnapshot.json"
                        ).content
                    )
                )["allMainnetVolts"]
            )[
                [
                    "globalId",
                    "vaultAuthority",
                    "shareTokenMint",
                    "depositTokenSymbol",
                    "depositTokenCoingeckoId",
                ]
            ]
        except Exception as e:
            print(datetime.now(), "Snapshot Data Invalid")
            traceback.print_exc()

    ########################################################################################################
    ################################          Data Retrieval             ###################################
    ########################################################################################################

    def get_ix(self, date_start, date_end):
        """
        Runs graphql instruction query for one date range.
        """
        print(date_start, date_end)
        query = self.ix_query % (date_start, date_end)
        print(
            datetime.now(),
            "retrieving instructions for {} to {}".format(date_start, date_end),
        )
        result = self.run_query(query)

        # convert GraphQL json to pandas dataframe
        try:
            df = pd.json_normalize(result["data"]["solana"]["instructions"])
        except:
            print(result)
            traceback.print_exc()
            raise Exception(datetime.now(), "Empty Results... Try Again")

        print(datetime.now(), df.shape[0], "instructions retrieved")

        df = df.rename(
            columns={
                "block.timestamp.iso8601": "timestamp",
                "log.consumed": "computeUnits",
                "transaction.signature": "txSignature",
                "transaction.feePayer": "txSigner",
                "data.base58": "instructionData",
            }
        )
        return df

    def get_ix_batch(self):
        """
        Batch the instruction retrieval. Save the shit Drop duplicates.

        """
        # Batch the days up nice and good so the graphql API calls don't bitch
        dates_batched = pd.date_range(self.date_start, self.date_end, freq=f"{self.batch_size_days}D")
        dates_batched = [
            str(x.isoformat())
            for x in dates_batched.append(pd.DatetimeIndex([self.date_end]))
        ]
        date_ranges = list(zip(dates_batched, dates_batched[1:]))
        ixs = []
        for date_range in date_ranges:
            assert len(date_range) == 2
            data = self.get_ix(date_range[0], date_range[1])
            ixs.append(data)

        df_ix = pd.concat(ixs, ignore_index=False)
        df_ix["instructionType"] = df_ix.instructionData.apply(
            lambda x: self.instruction_match(x)
        )

        # Store df_ix before we write it to the DataFrame so we avoid getting xfers for every single ix 
        self.df_ix = df_ix.drop_duplicates(["txSignature", "instructionType"]).reset_index(drop=True)
        print(datetime.now(), "final instruction data size: ", df_ix.shape[0])

        # Save new data to file
        df_old = self.get_existing_df(self.ix_fname)
        df = df_ix.append(df_old).reset_index(drop=True)
        df = df.drop_duplicates(["txSignature", "instructionType"])
        df.to_csv(self.ix_fname, index=False)
        print(datetime.now(), "wrote instruction data to csv...")

    def get_batched_xfers(self, instructionType, fname):
        """
        Get all transfers corresponding to a specific instructionType from Graphql query.
        Batch these queries up b/c the string size is
        too large (curse GraphQL for not supporting joins)

        :instructionType: String corresponding to the instruction type of each query.
        :fname: Name of where the old df is stored

        """

        temp = self.df_ix.query(f"instructionType == '{instructionType}'")

        if temp.empty:
            print(
                datetime.now(), "instructionType was not found in the data... breaking"
            )
            return

        tx_signatures = list(temp["txSignature"].unique())
        tx_strs = self.format_txs_for_query(tx_signatures)
        print(datetime.now(), len(tx_strs), "signature batches required...")
        xfers = []

        for i, tx_str in enumerate(tx_strs):
            query = self.xfer_query % (tx_str)
            result = self.run_query(query)
            # TODO: Clean up this duplicated logic
            try:
                df = pd.json_normalize(result["data"]["solana"]["transfers"])
            except:
                print(result)
                traceback.print_exc()
                raise Exception("Empty Results... Try Again")
            xfers.append(df)
            print(datetime.now(), df.shape[0], "transfers scraped in batch %d" % i)

        df_xfer = pd.concat(xfers, ignore_index=False)
        df_xfer = df_xfer.rename(
            columns={
                "block.timestamp.iso8601": "timestamp",
                "instruction.action.name": "instructionAction",
                "instruction.callPath": "instructionOrder",
                "transaction.signer": "userAddress",
                "transaction.signature": "txSignature",
                "currency.name": "currencyName",
                "receiver.address": "receiverAddress",
                "sender.address": "senderAddress",
                "currency.decimals": "currencyDecimals",
                "currency.address": "currencyAddress",
                "sender.mintAccount": "senderTokenMint",
            }
        )

        print(datetime.now(), df_xfer.shape[0], "transfers retrieved")

        df_old = self.get_existing_df(fname)
        df_final = df_old.append(df_xfer, ignore_index=True).sort_values(
            "instructionOrder"
        )

        return df_final
        
    def parse_endRound(self):
        instructionType = "EndRound"
        instructionAction = "transfer"
        tx_merge_key = "currencyAddress"
        meta_merge_key = "shareTokenMint"
        out_file = self.end_round_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )
        

    def parse_base(
        self,
        instructionType,
        instructionAction,
        tx_merge_key,
        meta_merge_key,
        output_file,
    ):
        """
        generalized method for parsing transfer data.

        1. Call get_batched_xfers()
        2. for each unique txSignature, find the xfer matching to the last instance of the instructionAction
        3. For SOL CC vaults, need an extra step and query for instructionAccount to find vaultAuthority.
        3. Join it to the friktion metadata based using tx_merge_key and meta_merge_key
        4. Drop extraneous rows
        5. Save the file to the output_file

        :instructionType: Type of instruction listed out in the instruction_match() method
        :instructionAction: type of transfer we are matching towards
        :tx_merge_key: what key in the xfer dataFrame do we want to merge on
        :meta_merge_key: what key in the metadata dataFrame we want to merge on.
        :output_file: as name suggests
        """
        print(
            datetime.now(),
            "Parsing transfers for instructionType: %s" % instructionType,
        )
        df = self.get_batched_xfers(instructionType, output_file)

#         Target only wrapped SOL entries for SOL vaults
        df = df.query('currencyName != "Solana"')

#         print(df)
#         returnRow = df.query("instructionOrder=='0-2'")
#         depositTokens = df.query("instructionOrder=='0-3'").amount.iloc[0]
#         voltTokens = returnRow.amount.iloc[0]
#         returnRow["shareTokenPrice"] = depositTokens/voltTokens
#         assert returnRow.shape[0]==1, "Only one end round row per asset"
        
#         df = (
#             df.query('instructionAction=="{}"'.format(instructionAction))
#             .groupby("txSignature")
#             .last()
#             .reset_index()
#         )
        shareTokendf = df.query("instructionAction=='mintTo'").copy()
    
        def find_matching_call_path(x):
            [path1, path2] = x.split("-")
            newCallPath = path1+"-"+str(int(path2)-1)
            return newCallPath
        
        shareTokendf["instructionOrderPair"] = shareTokendf.instructionOrder.apply(find_matching_call_path)
        
        df = pd.merge(shareTokendf, df, left_on=["txSignature", "instructionOrderPair"], 
                      right_on=["txSignature", "instructionOrder"], suffixes=("", "_x"))
        print(df)
        print(df.amount_x.isna().sum())
        print(df.amount.isna().sum())
        df["shareTokenPrice"] = df.amount_x/df.amount
        
        # Join tables and get rid of extraneous columns from metadata.
        df = pd.merge(
            df,
            self.friktion_metadata,
            how="left",
            left_on=tx_merge_key,
            right_on=meta_merge_key,
            suffixes=("", "_drop"),
        )
        df.drop([col for col in df.columns if "drop" in col], axis=1, inplace=True)

        # Tag the row with the instructionType
        df["userAction"] = instructionType

        df.drop_duplicates().to_csv(output_file, index=False)
        print(datetime.now(), "{} data size: {}".format(instructionType, df.shape[0]))

    def parse_all(self):
        if not self.skip_ix_scrape:
            self.get_ix_batch()
#         self.parse_claim_withdrawal()
#         self.parse_deposit_cancel()
#         self.parse_withdrawal_cancel()
#         self.parse_withdrawal()
#         self.parse_deposits()
        print("hello")
        self.parse_endRound()

xHG1tPkeEHsAVmPF2UrjZK3W719J5DGFgMaLtUkBoeP
# ..           ...                                           ...           ...
# 345               5SLqZSywodLS8ih6U2AAioZrxpgR149hR8SApmCB7r5X
# 346               4sTuzTYfcE2NF7zy6Sy8XhVcNLa6JQSLrx3roy97n4sD
# 347               4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2
# 348               2uTkms42P62dJ7JRaefc1HFkvyBeMP28J6MPmH1gVHoT
# 349               GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS
#
#     senderTokenMint  ...      amount_x instructionAction_x  \
# 0                    ...  8.600257e+02            transfer
# 1                    ...  2.477598e+05            transfer
# 2                    ...  3.060749e+04            transfer
# 3                    ...  1.030870e+02            transfer
# 4                    ...  3.221766e+04            transfer
# ..              ...  ...           ...                 ...
# 345                  ...  2.213949e+04            transfer
# 346                  ...  3.718435e+06            transfer
# 347                  ...  5.037176e+03            transfer
# 348                  ...  8.521109e+04            transfer
# 349                  ...  1.234733e+01            transfer
#
#      instructionOrder_x                                 userAddress_x  \
# 0                   0-1  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 1                   0-1  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 2                   0-1  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 3                   0-1  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 4                   0-1  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# ..                  ...                                           ...
# 345                 0-2  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 346                 0-3  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 347                 1-2  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 348                 1-2  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 349                 1-2  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
#
#               timestamp_x             currencyName_x  \
# 0    2022-04-15T03:41:26Z            LUNA (Wormhole)
# 1    2022-03-25T17:19:03Z                      Serum
# 2    2022-04-01T04:53:50Z                    Raydium
# 3    2022-04-08T03:44:22Z            Lido Staked SOL
# 4    2022-04-15T22:35:46Z                   USD Coin
# ..                    ...                        ...
# 345  2022-02-04T08:30:16Z                      Serum
# 346  2022-01-07T08:26:46Z                      Mango
# 347  2022-04-01T02:34:23Z                Wrapped SOL
# 348  2022-04-01T02:46:12Z                   USD Coin
# 349  2022-04-01T02:42:17Z  Wrapped Ethereum (Sollet)
#
#                                 currencyAddress_x  \
# 0    F6v4wfAdJB8D8p77bMXZgYt8TDKsYxLYxH5AFhUkYx9W
# 1     SRMuApVNdxXokk5GT7XD5cUUgXMBCoAz2LHeuAoKWRt
# 2    4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R
# 3    7dHbWXmci3dT8UFYWYZweBLXgycu7Y3iL6trKn1Y7ARj
# 4    EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# ..                                            ...
# 345   SRMuApVNdxXokk5GT7XD5cUUgXMBCoAz2LHeuAoKWRt
# 346   MangoCzJ36AjZyKwVj3VnYU4GTonjfVEnJmvvWaxLac
# 347   So11111111111111111111111111111111111111112
# 348  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 349  2FPyTwcZLUg1MDrwsyoP4D6s1tM7hAkHYRjkNb5w6Pxk
#
#                                   senderAddress_x  \
# 0    5oV1Yf8q1oQgPYuHjepjmKFuaG2Wng9dzTqbSWhU5W2X
# 1    2P427N5sYcEXvZAZwqNzjXEHsBMESQoLyjNquTSmGPMb
# 2    A6XsYxGj9wpqUZG81XwgQJ2zJ3efCbuWSQfnkHqUSmdM
# 3    2Ahpeqc1bo7Y4dVknvZUVfZPhHhym7JN6az2XMbUA6QA
# 4    CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# ..                                            ...
# 345  2P427N5sYcEXvZAZwqNzjXEHsBMESQoLyjNquTSmGPMb
# 346  B3yakZxwomkmnCxRr8ZmQtiWgtxtVBuCREDFDdAvcCVQ
# 347  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 348  EA29Xf3HGMtYziw7UKZDUKby7gkoCbXwmiNKwc7z54Ax
# 349  FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
#
#                                 senderTokenMint_x  \
# 0    2mAEZdxpNHWyUrRd4SB5bGNHgEFgZwFiQXovus7tXAZa
# 1    DrrE59ehum4DcprCAupUqjwDmFxNszPXwigyPkadEXKL
# 2    8iDJoR9FPcsfit9AmtHfH9doJ9ao6WbjKfaNEnbUCyAQ
# 3    6Q57epGrx4bMDgLXETYnBM9DmfgwbQmjgD4K9NdeHb8j
# 4    J6EaaYnQq1cgvwtUrkWcBb69uMYPdzaebAS2rg3QT8Sn
# ..                                            ...
# 345  C1RFcCnwrQfUjWFjhUTGmpstQiK4ExcFzvG8Rv5hkcaL
# 346  2EY7eTumMrcasThoXyHY5XBP3k9PWq5DqXEVmwYLqQCj
# 347  EfFMndpyXnv2edT1c7dZRzi1LSYmULFJp8gHeoe6uPtB
# 348  ADc3DFQge78PEpFcbCbnPfm1fwbzWCSX4HFQnjH1MJAr
# 349  GeHRjyya4mz7msXsTGrfisMbpLCTmvasx6Q1BMbzpKtG
#
#                                 receiverAddress_x
# 0    5oV1Yf8q1oQgPYuHjepjmKFuaG2Wng9dzTqbSWhU5W2X
# 1    2P427N5sYcEXvZAZwqNzjXEHsBMESQoLyjNquTSmGPMb
# 2    A6XsYxGj9wpqUZG81XwgQJ2zJ3efCbuWSQfnkHqUSmdM
# 3    2Ahpeqc1bo7Y4dVknvZUVfZPhHhym7JN6az2XMbUA6QA
# 4    CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# ..                                            ...
# 345  2P427N5sYcEXvZAZwqNzjXEHsBMESQoLyjNquTSmGPMb
# 346  B3yakZxwomkmnCxRr8ZmQtiWgtxtVBuCREDFDdAvcCVQ
# 347  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 348  EA29Xf3HGMtYziw7UKZDUKby7gkoCbXwmiNKwc7z54Ax
# 349  FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
#
# [350 rows x 22 columns]
# 0
# 0
# 2022-05-06 02:13:16.822131 EndRound data size: 350
# /var/folders/t5/lm3g0brx0dsf0ymt1ldc8xdr0000gp/T/ipykernel_29368/3452502133.py:400: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_final = df_old.append(df_xfer, ignore_index=True).sort_values(

# %%
import requests

def run_query(query, retries=10):
    """
    Query graphQL API.

    If timeerror
    """
    headers = {"X-API-KEY": "BQYCaXaMZlqZrPCSQVsiJrKtxKRVcSe4"}

    retries_counter = 0
    request = requests.post(
        "https://graphql.bitquery.io/", json={"query": query}, headers=headers
    )
    print(request.content)
    result = request.json()
    # print(dir(request.content))
    # Make sure that there is no error message
    # assert not request.content.errors
    assert "errors" not in result, result
    return result

query = """
    query MyQuery {
      solana(network: solana) {
        transfers(
          signature: {in: ["3JStT5VCY3yZvSTLPw9uXUKabzjzEk38iaZAiu55BA67Nps3NMDhQ2zDRh9hUHa8mmfqaXuYUSc5gkstpTfvFHCE"
          ]}
          options: {limit: 2000}
        ) {
          instruction {
            action {
              name
            }
            callPath
          }
          amount(success: {is: true})
          transaction {
            signer
            signature
          }
          block {
            timestamp {
              iso8601
            }
          }
          currency {
            name
            address
          }
          sender {
            address
            mintAccount
          }
          receiver {
            address
          }
        }
      }
    }
"""


result = run_query(query)

# convert GraphQL json to pandas dataframe
df = pd.json_normalize(result["data"]["solana"]["transfers"])

# %%
df

# %%
df["instructionOrder"] = df["instruction.callPath"]

# %%
df["txSignature"] = df["transaction.signature"]

# %%
df = pd.merge(df.query("instructionOrder=='0-2'"), df.query("instructionOrder=='0-3'"), on="txSignature", suffixes=("", "_x"))

# %%
df

# %%
df.instructionOrder

# %%
x = df.query("instructionOrder=='0-3'")

# %%
y = df.query("instructionOrder=='0-2'")

# %%
x.combine_first(y)

# %%
pd.merge(df.query("instructionOrder=='0-3'"), df.query("instructionOrder=='0-2'"), on="")

# %%
df

# %%
query = """"""

# %%
headers = {"X-API-KEY": "BQYCaXaMZlqZrPCSQVsiJrKtxKRVcSe4"}

retries_counter = 0

request = requests.post(
    "https://graphql.bitquery.io/", json={"query": query}, headers=headers
)

# %%
request.content

# %%
#         ix = pd.read_csv("friktion_ix.csv")
#         deposits = pd.read_csv("friktion_deposit.csv")
#         withdrawals = pd.read_csv("friktion_withdraw.csv")
#         claim = pd.read_csv(self.withdraw_claim_fname)
#         withdrawals_cxl = pd.read_csv(self.withdraw_cxl_fname)
#         deposits_cxl = pd.read_csv(self.deposit_cxl_fname)
end_round = pd.read_csv('friktion_end_round2.csv')

#         print(ix)
#         print(deposits)

#         assert ix.loc[ix.instructionType=="Deposit"].shape[0] == deposits.shape[0]
#         assert ix.loc[ix.instructionType=="Withdraw"].shape[0] == withdrawals.shape[0]
#         assert ix.loc[ix.instructionType=="ClaimPendingWithdrawal"].shape[0] == claim.shape[0]
#         assert ix.loc[ix.instructionType=="CancelPendingDeposit"].shape[0] == deposits_cxl.shape[0]
#         assert ix.loc[ix.instructionType=="CancelPendingWithdrawal"].shape[0] == withdrawals_cxl.shape[0]

# %%
end_round.timestamp.sort_values()
# Out:
# 20     2021-12-16T22:52:56Z
# 15     2021-12-17T18:24:05Z
# 14     2021-12-17T19:24:04Z
# 170    2021-12-17T23:12:02Z
# 13     2021-12-18T00:40:13Z
#                ...
# 90     2022-05-06T03:32:04Z
# 98     2022-05-06T03:32:04Z
# 10     2022-05-06T03:32:04Z
# 141    2022-05-06T03:32:09Z
# 132    2022-05-06T03:32:10Z
# Name: timestamp, Length: 350, dtype: object

# %%
end_round.loc[end_round.depositTokenCoingeckoId=="usd-coin"].columns
# Out:
# Index(['amount', 'instructionAction', 'instructionOrder', 'userAddress',
#        'txSignature', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress',
#        'instructionOrderPair', 'amount_x', 'instructionAction_x',
#        'instructionOrder_x', 'userAddress_x', 'timestamp_x', 'currencyName_x',
#        'currencyAddress_x', 'senderAddress_x', 'senderTokenMint_x',
#        'receiverAddress_x', 'shareTokenPrice', 'globalId', 'vaultAuthority',
#        'shareTokenMint', 'depositTokenSymbol', 'depositTokenCoingeckoId',
#        'userAction'],
#       dtype='object')

# %%
end_round.loc[end_round.depositTokenCoingeckoId=="usd-coin"].sort_values("timestamp")
# Out:
#            amount instructionAction instructionOrder  \
# 171  6.587749e+06            mintTo              0-3
# 138  4.038910e+04            mintTo              0-3
# 16   3.145516e+05            mintTo              0-2
# 145  2.761838e+06            mintTo              0-3
# 344  1.506252e+04            mintTo              0-3
# ..            ...               ...              ...
# 90   8.041121e+04            mintTo              0-3
# 98   6.300303e+04            mintTo              0-3
# 10   2.530169e+01            mintTo              0-2
# 141  1.311799e+06            mintTo              0-3
# 132  6.087274e+04            mintTo              0-3
#
#                                       userAddress  \
# 171  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 138  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 16   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 145  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 344  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# ..                                            ...
# 90   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 98   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 10   DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 141  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
# 132  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE
#
#                                            txSignature             timestamp  \
# 171  3zBYatTtANjp9LpufbzyjNHBWhY4dVrH3Fdic5uC3hYxpE...  2022-01-07T08:40:39Z
# 138  566Gs3CvSFbmtyq1i8GeVSDAX7om1G59nUjqiVtfftREGC...  2022-01-07T08:41:21Z
# 16   3FRJ8fmZ8Z4F3LYHpTRgPfvMbwW2yk9bkGS7RbWHRiTaPp...  2022-01-07T09:07:21Z
# 145  5vDABhK9At5ayB6DhdT8LZiKEF8nV6KxiSvgPCw7FUPKGX...  2022-01-14T08:30:09Z
# 344  36PZp5jhDCjMK1TPoDo3pLGXTVSK4pi1fF23h7thQsJaHv...  2022-01-14T08:37:46Z
# ..                                                 ...                   ...
# 90   228qt3WPHTJwCWHvGme9g4Ym1EirsdK2bs6JMNYEgjoEfn...  2022-05-06T03:32:04Z
# 98   2JqRusctP1XPqHw316BYqxtSVjkcmcQwU9C7HGYJvkqjhE...  2022-05-06T03:32:04Z
# 10   2PG72crRwFyBnj2QGN7ZeFkZzVYa4ZVZfSDjG4fgQ3WoVt...  2022-05-06T03:32:04Z
# 141  5TswY9RUTQC39hgVnjM2HDEXJhBUzhXkV1CcjGjBquQ9C4...  2022-05-06T03:32:09Z
# 132  35mU6m2QoNnqvKHbhkjog7ac1e18paxJ6iAhrGkSoWXvns...  2022-05-06T03:32:10Z
#
#      currencyName                               currencyAddress  \
# 171           NaN  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU
# 138           NaN   THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC
# 16            NaN  CxHG1tPkeEHsAVmPF2UrjZK3W719J5DGFgMaLtUkBoeP
# 145           NaN  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU
# 344           NaN   THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC
# ..            ...                                           ...
# 90            NaN  Fw8mw9zNyfngvBYuS2L6XWfvFE8fExQ3apZVw4Ery5oy
# 98            NaN  G8jsAWUA2KdDn7XmV1sBqUdbEXESaPdjPWDEYCsnkRX2
# 10            NaN  8R2L3r6N6odiUkztEzhxr9wkFio8UikYWbp36qdZvA9U
# 141           NaN  2uTkms42P62dJ7JRaefc1HFkvyBeMP28J6MPmH1gVHoT
# 132           NaN   THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC
#
#      senderAddress  senderTokenMint  ...  \
# 171            NaN              NaN  ...
# 138            NaN              NaN  ...
# 16             NaN              NaN  ...
# 145            NaN              NaN  ...
# 344            NaN              NaN  ...
# ..             ...              ...  ...
# 90             NaN              NaN  ...
# 98             NaN              NaN  ...
# 10             NaN              NaN  ...
# 141            NaN              NaN  ...
# 132            NaN              NaN  ...
#
#                                   senderAddress_x  \
# 171  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
# 138  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 16   CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# 145  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
# 344  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# ..                                            ...
# 90   AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8
# 98   BThMeTgWZBoBbAzp9sK9T7gQzpQDQdRQUVLtVQ3781q1
# 10   7Nvs437r3waBgBoFpgsqBjouy5PLP7h2wUFbsF1FD2AK
# 141  EA29Xf3HGMtYziw7UKZDUKby7gkoCbXwmiNKwc7z54Ax
# 132  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
#
#                                 senderTokenMint_x  \
# 171  BoStoAqM3vusQjRQ8AuW6XiFfS6vVDFatPjmrzkLeHaY
# 138  5XUJrnYr5aiMvdccCgiBsgynQFYuoYVZWSdQU81miMUP
# 16   E6mXqoh8HCJv8YFFwHj91iUKzczGawKtJEP3LrCvSjoP
# 145  B8URJfrBmnWz3tfAZG81DN9CSquqnkTqAdY21GAuTeC6
# 344  GVWs5Wn7JDgfvePpjRxYHQ8xhe2at4GdX861m6pdWozj
# ..                                            ...
# 90   HEjRyNfJNpxh29skWc78ooiW1tLf3ypiWt4qTXSFZgQ7
# 98   49nQcccEQhnsQ2TBa5WXetz7RyQwsxDz59hKBy7ZSs8x
# 10   9RYXLP3q7nGAn2WfpEg4jUSs2AWhZiaZ8qrg5EGZQvgS
# 141  9xc2ozU7TNDdC3DWXHmji9FfWEgvbfeLkquPRzk7QX4h
# 132  5XgApGwccXFgwpSxEjdTeE31Ejmov3yALMfyxjsc9Eac
#
#                                 receiverAddress_x shareTokenPrice  \
# 171  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK        1.000000
# 138  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f        1.000000
# 16   CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6        1.000000
# 145  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK        1.002813
# 344  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f        1.003288
# ..                                            ...             ...
# 90   AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8        1.042460
# 98   BThMeTgWZBoBbAzp9sK9T7gQzpQDQdRQUVLtVQ3781q1        1.077378
# 10   7Nvs437r3waBgBoFpgsqBjouy5PLP7h2wUFbsF1FD2AK        0.988076
# 141  EA29Xf3HGMtYziw7UKZDUKby7gkoCbXwmiNKwc7z54Ax        1.053509
# 132  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f        1.068730
#
#                         globalId  \
# 171       mainnet_income_put_sol
# 138       mainnet_income_put_btc
# 16       mainnet_income_put_mngo
# 145       mainnet_income_put_sol
# 344       mainnet_income_put_btc
# ..                           ...
# 90     mainnet_income_put_tsUSDC
# 98   mainnet_income_put_sol_high
# 10        mainnet_income_put_pai
# 141       mainnet_income_put_eth
# 132       mainnet_income_put_btc
#
#                                    vaultAuthority  \
# 171  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
# 138  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 16   CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# 145  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
# 344  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# ..                                            ...
# 90   AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8
# 98   BThMeTgWZBoBbAzp9sK9T7gQzpQDQdRQUVLtVQ3781q1
# 10   7Nvs437r3waBgBoFpgsqBjouy5PLP7h2wUFbsF1FD2AK
# 141  EA29Xf3HGMtYziw7UKZDUKby7gkoCbXwmiNKwc7z54Ax
# 132  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
#
#                                    shareTokenMint depositTokenSymbol  \
# 171  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU               USDC
# 138   THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC               USDC
# 16   CxHG1tPkeEHsAVmPF2UrjZK3W719J5DGFgMaLtUkBoeP               USDC
# 145  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU               USDC
# 344   THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC               USDC
# ..                                            ...                ...
# 90   Fw8mw9zNyfngvBYuS2L6XWfvFE8fExQ3apZVw4Ery5oy             tsUSDC
# 98   G8jsAWUA2KdDn7XmV1sBqUdbEXESaPdjPWDEYCsnkRX2               USDC
# 10   8R2L3r6N6odiUkztEzhxr9wkFio8UikYWbp36qdZvA9U                PAI
# 141  2uTkms42P62dJ7JRaefc1HFkvyBeMP28J6MPmH1gVHoT               USDC
# 132   THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC               USDC
#
#     depositTokenCoingeckoId userAction
# 171                usd-coin   EndRound
# 138                usd-coin   EndRound
# 16                 usd-coin   EndRound
# 145                usd-coin   EndRound
# 344                usd-coin   EndRound
# ..                      ...        ...
# 90                 usd-coin   EndRound
# 98                 usd-coin   EndRound
# 10                 usd-coin   EndRound
# 141                usd-coin   EndRound
# 132                usd-coin   EndRound
#
# [110 rows x 29 columns]

# %%
end_round.loc[end_round.shareTokenMint=="86nx2WyrdC6VuWyfdG1gMLiiBduktBTJgToKZAYwcbct"]
# Out:
# Empty DataFrame
# Columns: [amount, instructionAction, instructionOrder, userAddress, txSignature, timestamp, currencyName, currencyAddress, senderAddress, senderTokenMint, receiverAddress, instructionOrderPair, amount_x, instructionAction_x, instructionOrder_x, userAddress_x, timestamp_x, currencyName_x, currencyAddress_x, senderAddress_x, senderTokenMint_x, receiverAddress_x, shareTokenPrice, globalId, vaultAuthority, shareTokenMint, depositTokenSymbol, depositTokenCoingeckoId, userAction]
# Index: []
#
# [0 rows x 29 columns]

# %%
end_round.groupby(pd.to_datetime(end_round.timestamp).dt.strftime("%Y%m%d")).txSignature.count().reset_index().sort_values("timestamp")
# Out:
#    timestamp  txSignature
# 0   20211216            1
# 1   20211217            3
# 2   20211218            1
# 3   20211219            1
# 4   20211221            4
# 5   20211222            1
# 6   20211231            3
# 7   20220107           12
# 8   20220113            1
# 9   20220114           15
# 10  20220121           14
# 11  20220128           15
# 12  20220204           17
# 13  20220211           16
# 14  20220218           17
# 15  20220225           11
# 16  20220304           19
# 17  20220311           15
# 18  20220317            1
# 19  20220318           19
# 20  20220324            2
# 21  20220325           16
# 22  20220331            3
# 23  20220401           22
# 24  20220407            4
# 25  20220408           18
# 26  20220414            6
# 27  20220415           22
# 28  20220421            4
# 29  20220422           16
# 30  20220424            2
# 31  20220428            4
# 32  20220429           22
# 33  20220505            4
# 34  20220506           19

# %%
creapes2 = end_round.txSignature

# %%
creapes = end_round.txSignature

# %%
set(creapes2).difference(set(creapes))
# Out:
# set()

# %%
creapes
# Out:
# 0     2PG72crRwFyBnj2QGN7ZeFkZzVYa4ZVZfSDjG4fgQ3WoVt...
# 1     4vaZ5uQ13W44LxBPhDfySejn1XddGGXGhagTdvfp2CezAV...
# 2     3XS6THfidnxnyttMAhUx2XPHgXAjHUGL3PjFK1qLU4uXFV...
# 3     4UWbMV6mxC49iypU6ci4PjPKpzDLeZtD75nhCjzVF2yV9j...
# 4     3gxUdw1kvJcnig6e8422h9Ccg9bArNWMM1Hhrhp3hqex6U...
# 5     4AyWmPuiHdnJD46PJHa8VM9aATErWbkJuKmonbY9aEctCr...
# 6     4BRUG8SrRGgdZfUyNBEmUXypQmu16bHgh8xTH7oTUYs2wr...
# 7     4Bj21yx9ZYFyBy5HFM98ThJVLftr315bkvuWNAQGBkfw92...
# 8     4RHR72pqrBURaCUH6XJoRnCXf4k7nHqDz2JtLXwzQiWsAW...
# 21    FJD888jPDeep14p2AMVn516jLxXy18n1LX2znq8Xrb7T4e...
# 22    2K6gQbqFUVXBSBCraX9hdgw2YUwvftQ2awfy3UhteDinTa...
# 23    38FC4wu922EMUuqios9UYQcFgLCYS7LVp1iD62xHk5VsZk...
# 24    m9gV56TvKLcJLchyKova3GKSFfgNB7fgqEBc3uxwJwF2ff...
# 25    Pm7M6A5gzcUmSME9xhhh3wsGoe8SG9uwfvtxtJA82yw31D...
# 26    228qt3WPHTJwCWHvGme9g4Ym1EirsdK2bs6JMNYEgjoEfn...
# 27    24kgfRXk6hjc25CsAQmt4SGSR7Nt7vNbgs8kxij3csdJTc...
# 28    25o5ku3zi732wXCw11e6oWDhDNF9ZjPDJDMG9Pv75ZZEUD...
# 29    27WqdgwcFMyQZJ4Uv5774fxVk3UkrBsrJfoz1EcGpTwumQ...
# 30    29deAnNipkSvG96Cj7C2Aw2PM8fGpixS6eVTciurwdLx45...
# 31    2GxKC6DEzvruX9KuQTiyfSmixTV3SEo8huxETJogFwokfu...
# 32    2JqRusctP1XPqHw316BYqxtSVjkcmcQwU9C7HGYJvkqjhE...
# 33    2S5z561EZYQi9mVbptUER2SGStK3fuyZkZy7Qv4dq1sCDn...
# 34    2SoxuiWQZTW5uF7uUpex8ZTHPZy7rJ6Tgvt4jFTbsvxz9C...
# 35    2TDd2ZDT6Gj7tdV6D67nQ2Th4QPjSVhEmTf9x39zic45yS...
# 36    2VBzDBZGbLFG99gm1QRboD5ZPGFimdqhkLUeXYRcaFAsEB...
# 37    2YQQVTidYUNHLiwTuLAV7a2yUttm3KjXRj6wiQb9bd1HEw...
# 38    2a568JJWFHLgepMWwRwMu5uMNySUT4yogqGYZz7bCZAArm...
# 39    2deZAcv3rdygUEXBiqD2Gii76nmmrjjZd3JpKKCzbseBr7...
# 40    2dxEpGcte2k1jw7YrEVUnF1EqV64AFSd85u1RgtbJeDWSJ...
# 41    35mU6m2QoNnqvKHbhkjog7ac1e18paxJ6iAhrGkSoWXvns...
# 42    35mx1iQFxFVW8PBCDrhem9AcXM6gb56TqazskVFb6FH1RC...
# 43    3A3Ktcz69vN9aqbSoCTLV6aYjsdS2f2JFGN2UM6r1mpaK3...
# 44    mpHWj4LiHsZp5nPrMA92mdNj3vcwhTvTuEgRtjGM1L1C1V...
# 45    3QB1FNwMAzafcuhy142FMrtxTBCp4XvWtxoSoZ9DmPbnuv...
# 46    5yd7Sw4QLVfUYmrekV3hzSMFgkkHp4ZmmTveK7u53oaA2f...
# 47    tK2jC56rfFFEncCq1gcFdt1eBNPXPL7bgxQG8V9c5raBR8...
# 48    65B9cK3y8vvYtd4yaxVo3vyReJnqchSpUR6cei1hVR5RpG...
# Name: txSignature, dtype: object

# %%
end_round.shareTokenPrice.isna().sum()
# Out:
# 8

# %%
end_round.loc[end_round.shareTokenPrice.isna()][["timestamp", "globalId", "txSignature", "currencyAddress", "currencyAddress_x"]].sort_values("timestamp")
# Out:
#                timestamp                                globalId  \
#        '2dxEpGcte2k1jw7YrEVUnF1EqV64AFSd85u1RgtbJeDWSJoF9wGgBvGKKwT3RhEj3UGDSnLT7gu4tTwvdzFxMucz'],
#       dtype=object)

# %%
end_round.groupby("globalId").shareTokenPrice.count()
# Out:
# globalId
# mainnet_income_call_avax                   6
# mainnet_income_call_btc                   20
# mainnet_income_call_eth                   18
# mainnet_income_call_ftt                   17
# mainnet_income_call_luna                  18
# mainnet_income_call_marinade              19
# mainnet_income_call_mngo                  12
# mainnet_income_call_ray                   11
# mainnet_income_call_sbr                   11
# mainnet_income_call_socean                18
# mainnet_income_call_sol                   24
# mainnet_income_call_sol_high              10
# mainnet_income_call_srm                   17
# mainnet_income_call_step                   7
# mainnet_income_call_stsol                  6
# mainnet_income_put_btc                    18
# mainnet_income_put_btc_step_circuits       0
# mainnet_income_put_eth                    13
# mainnet_income_put_luna                   15
# mainnet_income_put_mngo                   11
# mainnet_income_put_pai                     1
# mainnet_income_put_sol                    18
# mainnet_income_put_sol_high               10
# mainnet_income_put_sol_parrot_circuits     0
# mainnet_income_put_sol_step_circuits       0
# mainnet_income_put_sol_uxd_circuits        0
# mainnet_income_put_tsUSDC                 12
# Name: shareTokenPrice, dtype: int64

# %%
end_round.groupby("globalId").shareTokenPrice.count()
# Out:
# globalId
# mainnet_income_call_avax                   6
# mainnet_income_call_btc                   20
# mainnet_income_call_eth                   18
# mainnet_income_call_ftt                   17
# mainnet_income_call_luna                  18
# mainnet_income_call_marinade              19
# mainnet_income_call_mngo                  12
# mainnet_income_call_ray                   11
# mainnet_income_call_sbr                   11
# mainnet_income_call_socean                18
# mainnet_income_call_sol                   24
# mainnet_income_call_sol_high              10
# mainnet_income_call_srm                   17
# mainnet_income_call_step                   7
# mainnet_income_call_stsol                  6
# mainnet_income_put_btc                    18
# mainnet_income_put_btc_step_circuits       0
# mainnet_income_put_eth                    13
# mainnet_income_put_luna                   15
# mainnet_income_put_mngo                   11
# mainnet_income_put_pai                     1
# mainnet_income_put_sol                    18
# mainnet_income_put_sol_high               10
# mainnet_income_put_sol_parrot_circuits     0
# mainnet_income_put_sol_step_circuits       0
# mainnet_income_put_sol_uxd_circuits        0
# mainnet_income_put_tsUSDC                 12
# Name: shareTokenPrice, dtype: int64

# %%
end_round.groupby("globalId").amount.count()
# Out:
# globalId
# mainnet_income_call_avax                   6
# mainnet_income_call_btc                   21
# mainnet_income_call_eth                   20
# mainnet_income_call_ftt                   17
# mainnet_income_call_luna                  18
# mainnet_income_call_marinade              21
# mainnet_income_call_mngo                  12
# mainnet_income_call_ray                   11
# mainnet_income_call_sbr                   11
# mainnet_income_call_socean                18
# mainnet_income_call_sol                   24
# mainnet_income_call_sol_high              10
# mainnet_income_call_srm                   17
# mainnet_income_call_step                   7
# mainnet_income_call_stsol                  6
# mainnet_income_put_btc                    18
# mainnet_income_put_btc_step_circuits       5
# mainnet_income_put_eth                    13
# mainnet_income_put_luna                   15
# mainnet_income_put_mngo                   12
# mainnet_income_put_pai                     1
# mainnet_income_put_sol                    18
# mainnet_income_put_sol_high               10
# mainnet_income_put_sol_parrot_circuits     7
# mainnet_income_put_sol_step_circuits       8
# mainnet_income_put_sol_uxd_circuits        6
# mainnet_income_put_tsUSDC                 12
# Name: amount, dtype: int64

# %%
end_round["timestamp_numba"] = pd.to_datetime(end_round.timestamp).astype('int')//1000000

# %%
end_round[["timestamp_numba", "shareTokenPrice"]]
# Out:
#      timestamp_numba  shareTokenPrice
# 0      1649994086000         1.031227
# 1      1648228743000         0.743239
# 2      1648788830000         0.967075
# 3      1649389462000         1.003587
# 4      1650062146000         1.017334
# ..               ...              ...
# 345    1643963416000         1.027444
# 346    1641544006000         1.012325
# 347    1648780463000         1.100783
# 348    1648781172000         1.037547
# 349    1648780937000         1.043097
#
# [350 rows x 2 columns]

# %%
[].insert
# Out:
# <function list.insert(index, object, /)>

# %%
[].insert
# Out:
# <function list.insert(index, object, /)>

# %%
np.nan==np.nan
# Out:
# False

# %%
end_round.loc[end_round.globalId=="mainnet_income_call_sol_high"].sort_values("timestamp").columns
# Out:
# Index(['amount', 'instructionAction', 'instructionOrder', 'userAddress',
#        'txSignature', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress',
#        'instructionOrderPair', 'amount_x', 'instructionAction_x',
#        'instructionOrder_x', 'userAddress_x', 'timestamp_x', 'currencyName_x',
#        'currencyAddress_x', 'senderAddress_x', 'senderTokenMint_x',
#        'receiverAddress_x', 'shareTokenPrice', 'globalId', 'vaultAuthority',
#        'shareTokenMint', 'depositTokenSymbol', 'depositTokenCoingeckoId',
#        'userAction', 'timestamp_numba'],
#       dtype='object')

# %%
end_round.loc[end_round.globalId=="mainnet_income_call_sol_high"].sort_values("timestamp").txSignature.iloc[-1]
# Out:
# 'tK2jC56rfFFEncCq1gcFdt1eBNPXPL7bgxQG8V9c5raBR8PbT4n3k2iq5H9APhxoz1xPijCjysavmLTpWzhozgd'

# %%
end_round.loc[end_round.globalId=="mainnet_income_call_srm"].sort_values("timestamp").txSignature.iloc[-1]
# Out:
# '5bCd4q25uWJWDXTPYYPdAhEhVueWLTBDDDXqnxBfiKX2MdSVCcezUJAkDSh4XNYSYuDtJsuWtNr7E4Wp9DAjbpHy'

# %%
end_round.loc[end_round.globalId=="mainnet_income_call_step"].sort_values("timestamp").txSignature.iloc[-1]
# Out:
# '38FC4wu922EMUuqios9UYQcFgLCYS7LVp1iD62xHk5VsZker6Qk8CEa3NxHzRqnF33iKyvKYnEcU9bFbfFfhLhar'

# %%
end_round.loc[end_round.globalId=="mainnet_income_call_luna"].sort_values("timestamp").txSignature.iloc[-4]
# Out:
# 'T79vT16ZkjaY2Mp3Vaa6da2QG8zUrbzueyi5EhGwitJztS4LEyekzUYtapvmWRCe9QMSteoAN2sEXt5yP4MVpLY'

# %%
end_round.loc[end_round.globalId=="mainnet_income_call_srm"].sort_values("timestamp").shareTokenPrice
# Out:
# 139    1.008345
# 337    1.013041
# 214    1.020411
# 215    1.024656
# 345    1.027444
# 331    1.029996
# 294    1.032057
# 287    1.035864
# 277    1.043827
# 252    1.045950
# 1      0.743239
# 61     0.743562
# 63     0.752447
# 31     0.755209
# 112    0.762000
# 173    0.766717
# 144    0.767239
# Name: shareTokenPrice, dtype: float64

# %%
for globalId in end_round.globalId.unique():
    print(globalId)
    if globalId!=globalId or "circuits" in globalId:
        continue
    temp = end_round.query("globalId == @globalId").copy().sort_values("timestamp")
    output = temp[["timestamp_numba", "shareTokenPrice"]].values.tolist()
    output =  list(filter(lambda x: x, map(lambda x: [int(x[0]), x[1]] if x[1]==x[1] else None, output)))
    if output[0][1] < 0.999999 or output[0][1] > 1.0000001:
        output.insert(0, [output[0][0]-61*60*24*7*1000, 1.0])
    print(output)
    with open(f'../derived_timeseries/{globalId}_sharePricesByGlobalId.json', 'w') as f:
        json.dump(output, f, separators=(",", ":"), indent=2)
# Out:
# mainnet_income_call_luna
# [[1640931286000, 1.0], [1641546166000, 1.0187347253023524], [1642150586000, 1.0269159583156628], [1642754858000, 1.037399825495834], [1643358050000, 1.048594646308907], [1643963484000, 1.0537127291994774], [1644546713000, 1.0562189024742632], [1645152424000, 1.0684165308123343], [1645757778000, 1.040446936490399], [1646361919000, 1.003085985611619], [1646973171000, 1.0071702925309058], [1647572109000, 1.010797312486993], [1648179512000, 1.0167015517282232], [1648788461000, 1.0193456844769877], [1649389099000, 1.0312272292744806], [1649994086000, 1.0312272300070189], [1650597783000, 1.0508361633327457], [1651206059000, 1.0585412106807597], [1651807626000, 1.0605569195070734]]
# mainnet_income_call_srm
# [[1640930687000, 1.0], [1641545567000, 1.008344675583902], [1642150173000, 1.0130412173906866], [1642754340000, 1.0204111968130043], [1643358996000, 1.024655830324491], [1643963416000, 1.027444377584872], [1644545891000, 1.0299960865185571], [1645150530000, 1.0320566683864485], [1646362099000, 1.0358642728898932], [1646966815000, 1.043827391510506], [1647571985000, 1.0459495509812649], [1648228743000, 0.7432392816317436], [1648788654000, 0.7435623825478984], [1649387780000, 0.752447101884427], [1649994199000, 0.7552089892211983], [1650597698000, 0.7620004332875789], [1651205511000, 0.7667174895428397], [1651807615000, 0.7672392767161182]]
# mainnet_income_call_ray
# [[1641536545000, 1.0], [1642151425000, 1.002748758055082], [1642756227000, 1.0176369145942914], [1643357278000, 1.0243848923792762], [1643963691000, 1.024385187838707], [1644545693000, 1.0366130102559703], [1645151633000, 1.0638966931848464], [1646362510000, 1.0766823189002608], [1647572570000, 1.0806019020086295], [1648788830000, 0.9670753967427048], [1649995848000, 0.96987074262163], [1651206084000, 0.9759088996876216]]
# mainnet_income_call_stsol
# [[1648173295000, 1.0], [1648788175000, 1.0035869942774749], [1649389462000, 1.003586994278105], [1649993402000, 1.0074434950072169], [1650597326000, 1.0112877199734254], [1651207673000, 1.01379593960379], [1651807786000, 1.016372946024892]]
# mainnet_income_put_mngo
# mainnet_income_put_btc_step_circuits
# mainnet_income_call_sbr
# [[1641536685000, 1.0], [1642151565000, 1.0466743621168428], [1642756192000, 1.050439376370783], [1643361073000, 1.052328655142385], [1643963757000, 1.0542213319411824], [1644545768000, 1.0551693723838986], [1645166306000, 1.0572779862833868], [1646362606000, 1.059654971385534], [1647572581000, 1.06245768789383], [1648788839000, 1.0700006877408526], [1649995889000, 1.1020751058744322], [1651205628000, 1.1157450716099655]]

# %%
for globalId in end_round.globalId.unique():
    plt.figure()
    temp = end_round.query("globalId == @globalId").copy()
    temp["timestamp"] = pd.to_datetime(temp.timestamp)
    temp.set_index("timestamp").shareTokenPrice.plot(title=globalId, marker='.')
    plt.grid(True)
# Out:
# /var/folders/t5/lm3g0brx0dsf0ymt1ldc8xdr0000gp/T/ipykernel_29368/46826939.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
end_round
# Out:
#                                            txSignature        amount  \
# 0    1F4bqTsHqYS9nEMsbMpTABGxtPjXK1SJ4vLC7NmxK6r8YN...   4108.701055
# 1    23Ws8JdskuKa6NwCfL218cjTGHzciNc7m5WFQ5RdimcVTP...  10654.888726
# 2    24kgfRXk6hjc25CsAQmt4SGSR7Nt7vNbgs8kxij3csdJTc...      0.000000
# 3    26Uqm8u7gQPiWidqyjqSK7uaQv8j6XKjpYpZnDY46cG5x4...    791.963588
# 4    26gJjF72t17YCFAK3Zz44SUYyYXkF9SYDgci4nF7T3TX2g...   5013.255659
# ..                                                 ...           ...
# 321  sv8PrQ8SRLbcN6t4nqofbxPzyKyreR4LxKBzsvJVm6r7Yy...   2662.329073
# 322  utZkRp7bkcbLWVg2rqQ9DqMGsXCtzvrNbR91wgZ1uqMkgU...    446.177748
# 323  whftpUrFmRj7p6zJRe9yWdaMSXDk4C4Kk9dSCctRjnWDBL...  32217.656908
# 324  yUaML9jVW8nABTD6PjeWAXykt55SjtXdNdrFycgvq463Sy...   6119.432260
# 325  zGamJBhHiX4MkQ6Nh75Djc8J8QAAa14YbBPySFfef5wb7V...      0.000000
#
#     instructionAction instructionOrder  \
# 0            transfer              0-2
# 1            transfer              0-2
# 2            transfer              0-2
# 3            transfer              0-2
# 4            transfer              0-2
# ..                ...              ...
# 321          transfer              0-2
# 322          transfer              0-2
# 323          transfer              0-1
# 324          transfer              0-2
# 325          transfer              0-2
#
#                                       userAddress             timestamp  \
# 0    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-03-11T02:22:37Z
# 1    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-03-04T02:43:16Z
# 2    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-28T02:51:33Z
# 3    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-01-28T09:07:14Z
# 4    DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-08T03:38:19Z
# ..                                            ...                   ...
# 321  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-01-28T08:49:21Z
# 322  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-22T03:15:26Z
# 323  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-15T22:35:46Z
# 324  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-03-25T02:31:53Z
# 325  DxMJgeSVoe1cWo1NPExiAsmn83N3bADvkT86dSP1k7WE  2022-04-21T03:12:31Z
#
#         currencyName                               currencyAddress  \
# 0        Wrapped SOL   So11111111111111111111111111111111111111112
# 1                NaN  Cvvh8nsKZet59nsDDo3orMa3rZnPWQhpgrMCVcRDRgip
# 2           USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 3           USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 4    LUNA (Wormhole)  F6v4wfAdJB8D8p77bMXZgYt8TDKsYxLYxH5AFhUkYx9W
# ..               ...                                           ...
# 321         USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 322  Lido Staked SOL  7dHbWXmci3dT8UFYWYZweBLXgycu7Y3iL6trKn1Y7ARj
# 323         USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 324      Wrapped SOL   So11111111111111111111111111111111111111112
# 325         USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
#
#                                     senderAddress  \
# 0    Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 1    AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8
# 2    HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
# 3    CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# 4    5oV1Yf8q1oQgPYuHjepjmKFuaG2Wng9dzTqbSWhU5W2X
# ..                                            ...
# 321  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 322  2Ahpeqc1bo7Y4dVknvZUVfZPhHhym7JN6az2XMbUA6QA
# 323  CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# 324  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 325  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
#
#                                   senderTokenMint  ... senderAddress_x  \
# 0    5GHuBr9njP3KBqXYS7KWRX6z97eYCmqBpn7b5Ae4jeWj  ...             NaN
# 1    75JcqeoPvbP9L7fEgTgfgF3okorogu8CvVjgupsTe1Hz  ...             NaN
# 2    4peHk7vxSxQoBpfveczGZvYaaKM7SMxSoSP98E16F3bD  ...             NaN
# 3    Ee3qGPkyYnuq6dSaeGqQz69ZYPAyTYHhkcVi9ND19GFs  ...             NaN
# 4    6bhCxQQWvvM4q8aWSe6UEKcunwGqMErhR2WrmUirtwaZ  ...             NaN
# ..                                            ...  ...             ...
# 321  5bHjcoSKns5CVz8MSfp7VnNPotY5eLXr52uBBG5ShNvd  ...             NaN
# 322  AdTq5z1UannEUMhTwNzj5g1vrrwEvUNFNcLfHKbDeD5g  ...             NaN
# 323  J6EaaYnQq1cgvwtUrkWcBb69uMYPdzaebAS2rg3QT8Sn  ...             NaN
# 324  HiepGSjE1udH3GDTzwHF1bdmNKyuTUiweWu1vsx8okPk  ...             NaN
# 325   XKJmV7jxnVxJNWLRRPzX22ntas1fuyv55m7H5S69oXH  ...             NaN
#
#      senderTokenMint_x receiverAddress_x shareTokenPrice globalId  \
# 0                  NaN               NaN             NaN      NaN
# 1                  NaN               NaN             NaN      NaN
# 2                  NaN               NaN             NaN      NaN
# 3                  NaN               NaN             NaN      NaN
# 4                  NaN               NaN             NaN      NaN
# ..                 ...               ...             ...      ...
# 321                NaN               NaN             NaN      NaN
# 322                NaN               NaN             NaN      NaN
# 323                NaN               NaN             NaN      NaN
# 324                NaN               NaN             NaN      NaN
# 325                NaN               NaN             NaN      NaN
#
#     vaultAuthority shareTokenMint depositTokenSymbol depositTokenCoingeckoId  \
# 0              NaN            NaN                NaN                     NaN
# 1              NaN            NaN                NaN                     NaN
# 2              NaN            NaN                NaN                     NaN
# 3              NaN            NaN                NaN                     NaN
# 4              NaN            NaN                NaN                     NaN
# ..             ...            ...                ...                     ...
# 321            NaN            NaN                NaN                     NaN
# 322            NaN            NaN                NaN                     NaN
# 323            NaN            NaN                NaN                     NaN
# 324            NaN            NaN                NaN                     NaN
# 325            NaN            NaN                NaN                     NaN
#
#     userAction
# 0     EndRound
# 1     EndRound
# 2     EndRound
# 3     EndRound
# 4     EndRound
# ..         ...
# 321   EndRound
# 322   EndRound
# 323   EndRound
# 324   EndRound
# 325   EndRound
#
# [326 rows x 28 columns]

# %%
for globalId in end_round.globalId.unique():
    plt.figure()
    temp = end_round.query("globalId == @globalId").copy()
    temp["timestamp"] = pd.to_datetime(temp.timestamp)
    temp.set_index("timestamp").amount.plot(title=globalId, marker='.')
    plt.grid(True)
# Out:
# /var/folders/t5/lm3g0brx0dsf0ymt1ldc8xdr0000gp/T/ipykernel_24835/54879240.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
end_round.loc[end_round.shareTokenPrice.isna()].amount
# Out:
# 10     0.0
# 11     0.0
# 26     0.0
# 30     0.0
# 47     0.0
# 50     0.0
# 53     0.0
# 57     0.0
# 62     0.0
# 114    0.0
# 120    0.0
# 124    0.0
# 125    0.0
# 128    0.0
# 157    0.0
# 188    0.0
# 229    0.0
# 233    0.0
# 240    0.0
# 251    0.0
# 258    0.0
# 265    0.0
# 270    0.0
# 272    0.0
# 277    0.0
# 289    0.0
# 290    0.0
# 296    0.0
# Name: amount, dtype: float64

# %%
ix.loc[ix.instructionType=="EndRound"].txSignature.values
# Out:
# array(['3aYJs5bZjM9AqRBXtJHXXh7trk9f4Dv5UhtXEGshXaV2sDndaj7QsEk1yGfudRoUjVJ651qAA6eHq2cSgGEBXZfw',
#        '3RNd4drGrwmQr7oe4dSMiehw4VLMLnhwQQG2BqUYv3o4tbmuEtGtuRMbhbnX1PmbCe2wkqpkgoLWb2HvTcCFy8pY',
#        '3gxUdw1kvJcnig6e8422h9Ccg9bArNWMM1Hhrhp3hqex6UHAq1o28XgieBJra1skcUrgKg58tcpXNsK6sBjvyV28',
#        'FJD888jPDeep14p2AMVn516jLxXy18n1LX2znq8Xrb7T4eNKvxrqbWVha4CmU8Fr5ECC7GQ5n4qfy88fK1GaHvf',
#        '5ivWA9tR5y1SgQ2RF1C7J6E4gG7CTv6kwnbSicP7ojz5TTAkWY2TCD5cBsucuame7GG6D5khSYz3U3UyoVGPwLAT',
#        'Pm7M6A5gzcUmSME9xhhh3wsGoe8SG9uwfvtxtJA82yw31DfHGsTcjS1d7zRgik4WkvSzgu42HZ6yFZx5pK7XDFM',
#        '3A3Ktcz69vN9aqbSoCTLV6aYjsdS2f2JFGN2UM6r1mpaK31QDnS2PMnCvaWf7WLc4Ntqe8MZVXWAGg52pX5Z7N3o',
#        '4AyWmPuiHdnJD46PJHa8VM9aATErWbkJuKmonbY9aEctCrnhjNnFya3CBYmv9DCSmqLr4CBr6ZfbN86g6Ldr7NZR',
#        '4Bj21yx9ZYFyBy5HFM98ThJVLftr315bkvuWNAQGBkfw92i3nJm4J6EYMyYSce7o8swQ7LbzMhotLTxQddCYJyWc',
#        '4BRUG8SrRGgdZfUyNBEmUXypQmu16bHgh8xTH7oTUYs2wrdgBZKvzPQt7JX9oKh3vD7HKCVkLDhhZ9VECzUExJjK',
#        '3QB1FNwMAzafcuhy142FMrtxTBCp4XvWtxoSoZ9DmPbnuvQaKbo6HGRQBVFSi2tEumHQ6Nx1d3xF6HofApXh1B5',
#        '2TDd2ZDT6Gj7tdV6D67nQ2Th4QPjSVhEmTf9x39zic45ySRFA4kMAXUtuAS239cfx4j4rfCw39MPJRByyQMDDTa8',
#        '2SoxuiWQZTW5uF7uUpex8ZTHPZy7rJ6Tgvt4jFTbsvxz9CPz143LLLybqSZWDPaZJjmEbb8ubB74xgauSGTCkEUm',
# 14  4SavoCp7EX9BMv9e44RVBxw1ZQi1Vm4V22V9Xk2dQ7rqYf...  1.000000e+03
# 15  4gvEuzmtBEnsNFzGZp5WXqb4UAkxYBJs4BHoBYppTiJxMa...  1.957084e-01
# 16  4oRAzEWzSPzVCeEQdy2pu4XFTmtHcqmBugntdy6vLndXhR...  7.081551e+01
# 17  4qcDVYPbUDCdAuMSrGPYTUTjbqGCnLNPUZ642yk6AFFXnJ...  1.100000e+02
# 18  4qrazvwcv4dvDhuifK71DztWMqVf6qx6ZaBt7AY8PxMtBS...  1.957084e-01
# 19  4sg7CWha116S3LzM8WbR6rjKYdShBaCLKcDAsbUKi8i1mj...  5.069600e-02
# 20  4tkNVzvhgVEXTpYmHwWSe4329h4KDgo5WQXEHeinLB7dkh...  9.785419e-02
# 21  54AP4JWVyjLJzCfB5xFGZgL7bV3KgXeoAFeGZ1jYKRz1v6...  1.025800e+02
# 22  55ZYE8YwMv9HP3PSj8ULLNTx4HsiKVPheb7kcjxUGMMmze...  2.500000e+02
# 23  5VNYS6UwsXwDuzF6Wc9u2hvWTyfuBn1r93y8b8dcWTEAxe...  8.042914e-02
# 24  5X83N5DyD16La7ogySH5LUB9vxBGj1EcaipyNb8iRHifow...  2.943753e+06
# 25  5YHMMPKaStEqZD6aSop7tyPQsYWRkG2wg7rBDgabHoYpGU...  1.957084e-01
# 26  5f3JC3puLrD5yvwUCdJbHJ224g5WgbtEpuapM5hSxRzzCn...  2.500024e+04
# 27  5nn4YFKeoT2Bx432Jt12rogsqkhdiNxsjKQvkP88tBS3F3...  4.942032e-01
# 28  66VYNyiasDMTuHy3rZkHhBvBYwzvcgsqyhMoAPCxDKXBVz...  5.138822e+03
# 29  7BkK53fDo4xcFS9PgUtMDJW2YDt6GtDZLW1B9G3FHihuzn...  1.933436e-01
# 30  HTr6P7bwXZwdjhEPR1kcsk6NvLtSgzhtFDLbjGGapMxZm7...  1.957084e-01
# 31  Y39qs12rk4E2LEYe3wKVXiVMF6uTe8gaSBNgN8ckqXLNZR...  9.690258e-02
# 32  hzZt554RTv5xmtoyksrnJegYBaKNTU7sKKQEbKFB2uBZR9...  9.667179e-02
# 33  xTcqibUh2hut8ukFAsnJjTWrU8DFSntmhmQfSz2v4QwRba...  3.982696e-02
#
#    instructionAction instructionOrder  \
# 0               burn              0-1
# 1               burn              2-1
# 2               burn              0-0
# 3               burn              2-1
# 4               burn              2-1
# 5               burn              2-1
# 6               burn              3-1
# 7               burn              0-1
# 8               burn              1-1
# 9               burn              0-1
# 10              burn              2-1
# 11              burn              2-1
# 12              burn              2-1
# 13              burn              3-1
# 14              burn              0-1
# 15              burn              2-1
# 16              burn              1-1
# 17              burn              0-1
# 18              burn              2-1
# 19              burn              1-1
# 20              burn              2-0
# 21              burn              0-0
# 22              burn              0-1
# 23              burn              3-1
# 24              burn              0-1
# 25              burn              2-1
# 26              burn              0-1
# 27              burn              3-1
# 28              burn              0-1
# 29              burn              1-1
# 30              burn              2-1
# 31              burn              2-1
# 11  6qm8D92vqB7t4ipmN3fP9oja9J4BP5hxeM295QzZMbMf              NaN
# 12  6yioMxgGqZfWmFeMTovYiE7SJ7H5ZSusC1swRTZ8BQB8              NaN
# 13  Dz4qp56eYpgg5hLHsd1EUMTjV2JMQ5A87MSBZyJQnqYf              NaN
# 14  GDEFz8ouwbZAvHSZHpupwEPCq9EKFs67HG1kcEEHaboP              NaN
# 15  BcZYXd4SJTCSffPeeRpG9JsGQLruk7pbU1L7DjoWmnpe              NaN
# 16  9mbh1nL9tFY7CdbgtxiQp9oq3qnen6nMPUbww4ChNU2U              NaN
# 17   jYAQwCi3vxHh1xMNvFVm1xQP5KvL8C7nj7FBzy1dMcw              NaN
# 18  7EEKydwZh57eQL8yhbjnjDUuXWsV9D1KJfvhgTzGmS2n              NaN
# 19  8PXMUhfCtDqeUHQkPGZ6zNscjpknJA8dQh5Ep9bSRWDj              NaN
# 20  HhSNpSNa1453wYt6fRMhMZkdtVQv6J5DB6pEDDN692J3              NaN
# 21  3tcv6zzGkmCwBPk23Yg9koZKjP5VZkpqB7mHnTsCjb3n              NaN
# 22  JA3aCgD9FoZNycN73hRZhiWejfPhEd6KsnfuJA6HXmRH              NaN
# 23  F73KofLyysrkBPAcrqqeXdnhVX2X93zHRGSzWansJ9Tq              NaN
# 24  13imG2DgTyaVukszwvLnjZjG8zPkDMRKtfrpkQh7fKN8              NaN
# 25  8R1cfkd7zXCVFqn4xMC5ErtLP5au2JrqfVtkbksVjcrk              NaN
# 26  4Ryd4oqM4YhCyzndLXXonHp5hmDJsacYHnv5LPJho96f              NaN
# 27  4tPi2n2NAA64egiYUbhwHX7RQJqxyKJ1trdPDatkseWd              NaN
# 28  FPt4ckgD4kjLYCCg8CVt4dqk31gksDU41Trp8CrdiDgT              NaN
# 29  7HmjvqcvQniNcs7hbEcQ6bUg5ACqdgxsBCQvxAxseBVe              NaN
# 30  GSjuPEYEYBb47mz816ejNA6gonBahSzvNq7WxaAaHgSn              NaN
# 31  J1UoQQu5Ufc3vrT56egzRtFTS5YLBFu5ezA98r925qLF              NaN
# 32  68Lne7nhogYrGSZrBy1Yp8YJVeLLkCpdDRFuuhMe36zz              NaN
# 33  ExuWpTHPu3h7nB38LxvNDkU1SmzpvUvQGE4CPYHV78ec              NaN
#
#                         globalId  \
# 0        mainnet_income_call_sbr
# 1        mainnet_income_call_sol
# 2         mainnet_income_put_sol
# 3        mainnet_income_call_sol
# 4        mainnet_income_call_sol
# 5        mainnet_income_call_sol
# 6        mainnet_income_call_sol
# 7        mainnet_income_call_eth
# 8        mainnet_income_call_sbr
# 9         mainnet_income_put_btc
# 10       mainnet_income_call_sol
# 11       mainnet_income_call_sol
# 12       mainnet_income_call_sol
# 13       mainnet_income_call_sol
# 14       mainnet_income_put_mngo
# 15       mainnet_income_call_sol
# 16  mainnet_income_call_marinade
# 17        mainnet_income_put_sol
# 18       mainnet_income_call_sol
# 19       mainnet_income_call_btc
# 20       mainnet_income_call_sol
# 21        mainnet_income_put_sol
# 22        mainnet_income_put_sol
# 23       mainnet_income_call_sol
# 24       mainnet_income_call_sbr
# 25       mainnet_income_call_sol
# 26        mainnet_income_put_btc
# 27       mainnet_income_call_sol
# 28        mainnet_income_put_btc
# 29  mainnet_income_call_marinade
# 30       mainnet_income_call_sol
# 31       mainnet_income_call_sol
# 32  mainnet_income_call_marinade
# 33       mainnet_income_call_sol
#
#                                   vaultAuthority  \
# 0   BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h
# 1   Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 2   6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
# 3   Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 4   Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 5   Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 6   Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 7   FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# 8   BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h
# 9   GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 10  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 11  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 12  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 13  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 14  CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# 15  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 16  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH
# 17  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
# 18  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 19  DA1M8mw7GnPNKU9ReANtHPQyuVzKZtsuuSbCyc2uX2du
# 20  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 21  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
# 22  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
# 23  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 24  BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h
# 25  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 26  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 27  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 28  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 29  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH
# 30  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 31  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 32  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH
# 33  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
#
#                                   shareTokenMint depositTokenSymbol  \
# 0   DPMCwE9z9jXaDVDti5aKhdgCWGgsvioz6ZvB9eZjH7UE                SBR
# 1   4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 2   EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU               USDC
# 3   4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 4   4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 5   4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 6   4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 7   GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS                ETH
# 8   DPMCwE9z9jXaDVDti5aKhdgCWGgsvioz6ZvB9eZjH7UE                SBR
# 9    THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC               USDC
# 10  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 11  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 12  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 13  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 14  CxHG1tPkeEHsAVmPF2UrjZK3W719J5DGFgMaLtUkBoeP               USDC
# 15  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 16  6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt               mSOL
# 17  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU               USDC
# 18  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 19  3BjcHXvyzMsjmeqE2qFLx45K4XFx3JPiyRnjJiF5MAHt                BTC
# 20  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 21  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU               USDC
# 22  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU               USDC
# 23  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 24  DPMCwE9z9jXaDVDti5aKhdgCWGgsvioz6ZvB9eZjH7UE                SBR
# 25  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 26   THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC               USDC
# 27  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 28   THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC               USDC
# 29  6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt               mSOL
# 30  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 31  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 32  6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt               mSOL
# 33  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
#
#    depositTokenCoingeckoId userAction
# 0                    saber   Withdraw
# 1                   solana   Withdraw
# 2                 usd-coin   Withdraw
# 3                   solana   Withdraw
# 4                   solana   Withdraw
# 5                   solana   Withdraw
# 6                   solana   Withdraw
# 7                 ethereum   Withdraw
# 8                    saber   Withdraw
# 9                 usd-coin   Withdraw
# 10                  solana   Withdraw
# 11                  solana   Withdraw
# 12                  solana   Withdraw
# 13                  solana   Withdraw
# 14                usd-coin   Withdraw
# 15                  solana   Withdraw
# 16                    msol   Withdraw
# 17                usd-coin   Withdraw
# 18                  solana   Withdraw
# 19                 bitcoin   Withdraw
# 20                  solana   Withdraw
# 21                usd-coin   Withdraw
# 22                usd-coin   Withdraw
# 23                  solana   Withdraw
# 24                   saber   Withdraw
# 25                  solana   Withdraw
# 26                usd-coin   Withdraw
# 27                  solana   Withdraw
# 28                usd-coin   Withdraw
# 29                    msol   Withdraw
# 30                  solana   Withdraw
# 31                  solana   Withdraw
# 32                    msol   Withdraw
# 33                  solana   Withdraw

# %%
deposits.shape

# %%
ix.loc[ix.instructionType=="Deposit"].shape
# Out:
# (29408, 5)

# %%
deposits.sort_values("amount")[::-1]
# Out:
#                                              txSignature        amount  \
# 7486   3FvYTiomvJTpAjs5XxGc81egpWzebGXA4sSs7VMvWB6c9G...  4.879066e+06
# 11664  3zZ8TKn9gYpFhrqcx8W2HTJikwHSTZLG3GyiqbM12BWPQY...  2.998353e+06
# 19671  5M3H96K3RJghDp5R3SdJsCyeCnRYypTXtL5PvzE6W8wS82...  2.943753e+06
# 1691   2GR1JARZMSRP9wEtvVg5D1tbMptBayGuhCt6BuHjevvztx...  2.904146e+06
# 25363  JBK4C7XkJKknRMD9NTmiengbiBn9rwNTdFd8MUDvbvsSHa...  2.630611e+06
# ...                                                  ...           ...
# 15554  4eVtsrbxsB5yKwANXpWQU5kH5Qc3HAD37ak8L9uzk5GEeU...  1.000000e-09
# 12164  45X8ZKAUZUPZBVorVhavjAgncR2KXynevXNB9sRkAwbSQH...  1.000000e-09
# 16534  4pSgwJkyp6PuitQMC5UiKoJiV1bmUUk9E7VzE73Ds9XMqb...  1.000000e-09
# 2386   2PXZks2t4YUZWQuDc6MNo1nLre5SgMWhumRvGx4jqemQSS...  1.000000e-09
# 3583   2bYFAv2MMyQXzxth6cZpnpj6AFeLyXz2EoizcCvwXvVPF1...  1.000000e-09
#
#       instructionAction instructionOrder  \
# 7486           transfer              1-1
# 11664          transfer              1-1
# 19671          transfer              1-1
# 1691           transfer              0-0
# 25363          transfer              1-1
# ...                 ...              ...
# 15554          transfer            0-0-0
# 12164          transfer              1-1
# 16534          transfer              1-1
# 2386           transfer              0-0
# 3583           transfer              1-1
#
#                                         userAddress             timestamp  \
# 7486   7xTjub4EpTLx7QLHdeJKNQsuVYkqaiGbBd4DJRYjKAYZ  2022-01-13T17:40:28Z
# 11664  CHbwVQQvMvhGxLPBkaL6SZuJ8f895bGHZ5BsLXbaJL3N  2022-02-05T01:47:19Z
# 19671  GmRC6EhKtBEcKM1bjCBzamWDy3qmP5z2Kc9tYjQuc2Pn  2021-12-30T10:31:36Z
# 1691   3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs  2022-03-07T10:10:46Z
# 25363  3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs  2022-03-28T21:44:12Z
# ...                                             ...                   ...
# 15554  GgF8AhcdiJ4hhyFaMoJ3XpQo9q7NgFnNaMQ6x6Xj3Lvt  2021-12-27T02:05:05Z
# 12164  J1sFjvcmhAxiYS5oerp167VDCu1u76csG5bXkkgijVJn  2022-01-24T23:48:03Z
# 16534  GFZpgo47bsmPzLentNshwHnapbryMiu1hfisng7DBbDm  2022-03-30T09:39:59Z
# 2386   5cvX5RGXCbX12Rso1UCTFFDdzgN9W7jMTHCDzKAthmuo  2022-01-26T21:29:48Z
# 3583   FxZMeiQchnuppwe9SeyNYxkVchkpUjnnJsJM9DP3d78U  2022-03-30T09:29:45Z
#
#                      currencyName  \
# 7486         Saber Protocol Token
# 11664                         NaN
# 19671        Saber Protocol Token
# 1691                     USD Coin
# 25363                    USD Coin
# ...                           ...
# 15554  Marinade staked SOL (mSOL)
# 12164  Marinade staked SOL (mSOL)
# 16534  Marinade staked SOL (mSOL)
# 2386   Marinade staked SOL (mSOL)
# 3583   Marinade staked SOL (mSOL)
#
#                                     currencyAddress  \
# 7486    Saber2gLauYim4Mvftnrasomsv6NvAuncvMEZwcLpD1
# 11664  Cvvh8nsKZet59nsDDo3orMa3rZnPWQhpgrMCVcRDRgip
# 19671   Saber2gLauYim4Mvftnrasomsv6NvAuncvMEZwcLpD1
# 1691   EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 25363  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# ...                                             ...
# 15554   mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 12164   mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 16534   mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 2386    mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 3583    mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
#
#                                       senderAddress  \
# 7486   7xTjub4EpTLx7QLHdeJKNQsuVYkqaiGbBd4DJRYjKAYZ
# 11664  CHbwVQQvMvhGxLPBkaL6SZuJ8f895bGHZ5BsLXbaJL3N
# 19671  GmRC6EhKtBEcKM1bjCBzamWDy3qmP5z2Kc9tYjQuc2Pn
# 1691   3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs
# 25363  3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs
# ...                                             ...
# 15554  6qfyGvoUqGB6AQ7xLc4pVwFNdgJSbAMkTtKkBXhLRiV1
# 12164  J1sFjvcmhAxiYS5oerp167VDCu1u76csG5bXkkgijVJn
# 16534  GFZpgo47bsmPzLentNshwHnapbryMiu1hfisng7DBbDm
# 2386   5cvX5RGXCbX12Rso1UCTFFDdzgN9W7jMTHCDzKAthmuo
# 3583   FxZMeiQchnuppwe9SeyNYxkVchkpUjnnJsJM9DP3d78U
#
#                                     senderTokenMint  \
# 7486   3JEfWY4V6sQBQXsbXeWkDVA5pqPisudwhxRbWWd76rt9
# 11664  424dm7Lauis6QRBreU9nt8yvwe1FZqUtp6oiEAzMcttQ
# 19671  FLEiW8R1qj2XnZ5vuJskFZ1X7umntUJV2DAgFRckcfv5
# 1691   8LrqyZvCsyBVFXDU9YbVAj6ukJ9tSKeXTmXNHWfZkGRF
# 25363  8LrqyZvCsyBVFXDU9YbVAj6ukJ9tSKeXTmXNHWfZkGRF
# ...                                             ...
# 15554  5Vfn9EmBYkxDFASQKLEZqDuDCT2G2tbmNrizisa4m4uL
# 12164  EqXN26d6mKUKPXrziWxaHxF7wsDzt95vWPnFkFMe7Nok
# 16534  5BMHymXSNFgyoGYzxx6b9yGTTq4zRwXzCkrwu2SUFs2n
# 2386   EFHB1NyzjTQW7hmAorGzHBoUqdVZDsGQ4jDVyPMXTvjn
# 3583   ExAoBt7qQuc7G7sX65AA7nmxfTw4ZemWMFzJdvzz1Dmc
#
#                                     receiverAddress globalId vaultAuthority  \
# 7486   BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h      NaN            NaN
# 11664  AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8      NaN            NaN
# 19671  BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h      NaN            NaN
# 1691   BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ      NaN            NaN
# 25363  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY      NaN            NaN
# ...                                             ...      ...            ...
# 15554  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 12164  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 16534  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 2386   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 3583   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
#
#       shareTokenMint depositTokenSymbol depositTokenCoingeckoId userAction
# 7486             NaN                NaN                     NaN    Deposit
# 11664            NaN                NaN                     NaN    Deposit
# 19671            NaN                NaN                     NaN    Deposit
# 1691             NaN                NaN                     NaN    Deposit
# 25363            NaN                NaN                     NaN    Deposit
# ...              ...                ...                     ...        ...
# 15554            NaN                NaN                     NaN    Deposit
# 12164            NaN                NaN                     NaN    Deposit
# 16534            NaN                NaN                     NaN    Deposit
# 2386             NaN                NaN                     NaN    Deposit
# 3583             NaN                NaN                     NaN    Deposit
#
# [29406 rows x 17 columns]

# %%
pd.options.display.width = 0

# %%
deposits.loc[
    deposits.vaultAuthority=="Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G"].sort_values("amount")[["timestamp", "amount", "txSignature"]]
# Out:
#                  timestamp        amount  \
# 7978  2022-02-25T19:56:08Z  1.000000e-09
# 5862  2022-02-12T02:52:57Z  1.000000e-09
# 479   2022-02-03T21:05:08Z  1.000000e-09
# 4532  2022-03-18T14:21:43Z  1.000000e-09
# 5087  2022-01-07T15:34:27Z  1.000000e-09
# ...                    ...           ...
# 2415  2022-01-12T08:06:22Z  3.638800e+03
# 4309  2022-03-30T16:18:44Z  8.230664e+03
# 4799  2022-02-01T16:45:17Z  8.586272e+03
# 2362  2022-02-17T09:13:40Z  1.168541e+04
# 5075  2022-01-21T14:59:41Z  1.581595e+04
#
#                                             txSignature
# 7978  mQPf6mdLdSpCtnmvPkKarwhMykNNp5FEzKg6yzvJbo12yG...
# 5862  5VtrMPM6nGsWSzeWrFQ4dQFnHyixUMmK4GXF5wzyRsYp2L...
# 479   2H4hQFTSkvWJUTr3t5f9i8hFDG1XW7Rak31WoiDLqf733t...
# 4532  4h55mB7Hwosedtx3kttVfbLmAGdKoHkKRoSY7fhBoufYVU...
# 5087  52jsKGk4ryoqbQCiNnZg1TcDJ81RHxq5PrptiunnjW3TJb...
# ...                                                 ...
# 2415  3Rkt6Z9QHzxxrP6FhVoLA4jkcKCXJPjASDsjeUHmbbBsUd...
# 4309  4a2KegHZpt2Mfp45FjcbFUVV1HsMHSHzyN6kfML9mJ8qrN...
# 4799  4rbL6s8PcsHaPBBM5Sf1mgGBkQHUvVo8zxa5VhP92oU2oN...
# 2362  3PezBkLDECULRfmgLNz92qZewjzC6oAbr7xAbstGTuV1CN...
# 5075  529CebmeMLq6PLXNyNW4WTTNuEVKGoyNsUcGyQb1VVMvjc...
#
# [2680 rows x 3 columns]

# %%
deposits.loc[
    deposits.vaultAuthority=="Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G"].sort_values("amount")[["timestamp", "amount", "txSignature"]][::-1].iloc[3]["txSignature"]
# Out:
# '4a2KegHZpt2Mfp45FjcbFUVV1HsMHSHzyN6kfML9mJ8qrN4iQKGUWPXBetXMrGKDRtu8JuhZPC4ttBZqaiAtL3dD'

# %%
depsots

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId', 'userAction'],
#       dtype='object')

# %%
deposits

# %%
# Have Price
# Have VoltTokenShare

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId'],
#       dtype='object')

# %%
deposits.shape
# Out:
# (115, 16)

# %%
deposits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   txSignature              115 non-null    object
#  1   amount                   115 non-null    float64
#  2   instructionAction        115 non-null    object
#  3   instructionOrder         115 non-null    object
#  4   userAddress              115 non-null    object
#  5   timestamp                115 non-null    object
#  6   currencyName             115 non-null    object
#  7   currencyAddress          115 non-null    object
#  8   senderAddress            115 non-null    object
#  9   senderTokenMint          115 non-null    object
#  10  receiverAddress          115 non-null    object
#  11  globalId                 115 non-null    object
#  12  vaultAuthority           115 non-null    object
#  13  shareTokenMint           115 non-null    object
#  14  depositTokenSymbol       115 non-null    object
#  15  depositTokenCoingeckoId  115 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 14.5+ KB

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId'],
#       dtype='object')

# %%
deposits.iloc[0]
# Out:
# txSignature                122tbxak1CeaRQSMZD2izGb9tXa7rSaRpyD2s3iSv4bKp3...
# amount                                                              1.062448
# instructionAction                                                       burn
# instructionOrder                                                         1-1
# userAddress                     GbYTQgbXndUJoczx23Hy3hobAReguEuddijnsRTkn8pJ
# timestamp                                               2022-01-09T10:12:13Z
# currencyName                                                             NaN
# currencyAddress                 6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt
# senderAddress                   GbYTQgbXndUJoczx23Hy3hobAReguEuddijnsRTkn8pJ
# senderTokenMint                 2ALneL69HRuthso7f4inq75g8AYBTbKHKgFB2oBgE6mh
# receiverAddress                                                          NaN
# globalId                                                                 NaN
# vaultAuthority                                                           NaN
# shareTokenMint                                                           NaN
# depositTokenSymbol                                                       NaN
# depositTokenCoingeckoId                                                  NaN
# userAction                                                          Withdraw
# Name: 0, dtype: object

# %%
deposits.loc[deposits.depositTokenCoingeckoId.isna()].currencyAddress
# Out:
# Series([], Name: currencyAddress, dtype: object)

# %%
deposits.shape
# Out:
# (115, 16)

# %%
deposits.loc[deposits.txSignature=="24y4KRma4BUarjw4y8Rv9Dt1kZdVVSP5kVnkbu4Ra5KMs7G9Df2Vb9C1b3M8f6yCuNuhsEW9s1WR8WrSKuN5bVBX"].iloc[0]
# Out:
# txSignature                24y4KRma4BUarjw4y8Rv9Dt1kZdVVSP5kVnkbu4Ra5KMs7...
# amount                                                                 551.0
# instructionAction                                                   transfer
# instructionOrder                                                         3-1
# userAddress                     9T19SkKUpSNbt2cMcCQVz7NZEfmXW3gdMDkH9db1yidw
# timestamp                                               2022-03-17T18:39:38Z
# currencyName                                                     Wrapped SOL
# currencyAddress                  So11111111111111111111111111111111111111112
# senderAddress                   9T19SkKUpSNbt2cMcCQVz7NZEfmXW3gdMDkH9db1yidw
# senderTokenMint                 D9QnLjbjTEBCqFZUrovoFkNW3B8gLmsJkT6PDt4HUv1H
# receiverAddress                  wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# globalId                                        mainnet_income_call_sol_high
# vaultAuthority                   wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# shareTokenMint                  DNa849drqW19uBV5X9ohpJ5brRGzq856gk3HDRqveFrA
# depositTokenSymbol                                                       SOL
# depositTokenCoingeckoId                                               solana
# Name: 2, dtype: object

# %%
deposits.loc[deposits.txSignature=="1kx6PYTANDwsAZGZ5xoRNe51uRK68k6roF6KYDauHQMmemH4JunDBCA47oHT2J1QUbh5YJHFdoZtQECqUVLVbZp"].iloc[0]
# Out:
# txSignature                1kx6PYTANDwsAZGZ5xoRNe51uRK68k6roF6KYDauHQMmem...
# amount                                                               0.99859
# instructionAction                                                   transfer
# instructionOrder                                                         1-1
# userAddress                     79jbRVMQu5rQkEcAPbzZNqnwKEASHyEyWgUn9q76yUKT
# timestamp                                               2022-03-17T19:33:26Z
# currencyName                                       Wrapped Ethereum (Sollet)
# currencyAddress                 2FPyTwcZLUg1MDrwsyoP4D6s1tM7hAkHYRjkNb5w6Pxk
# senderAddress                   79jbRVMQu5rQkEcAPbzZNqnwKEASHyEyWgUn9q76yUKT
# senderTokenMint                 3e81Tr2AGVLwPLLsUwiBSaYdGDwSxCMXmhF5ZWUuQAsn
# receiverAddress                 FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# globalId                                             mainnet_income_call_eth
# vaultAuthority                  FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# shareTokenMint                  GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS
# depositTokenSymbol                                                       ETH
# depositTokenCoingeckoId                                             ethereum
# Name: 0, dtype: object

# %%
zz = pd.DataFrame(
                dict(
                    json.loads(
                        requests.get(
                            "https://friktion-labs.github.io/mainnet-tvl-snapshots/friktionSnapshot.json"
                        ).content
                    )
                )["allMainnetVolts"]
            )

# %%
zz
# Out:
#                                   globalId  \
# 0                  mainnet_income_call_btc
# 1                  mainnet_income_call_sol
# 2             mainnet_income_call_sol_high
# 3             mainnet_income_call_marinade
# 4                  mainnet_income_call_eth
# 5                  mainnet_income_call_ftt
# 6                  mainnet_income_call_srm
# 7                 mainnet_income_call_mngo
# 8               mainnet_income_call_socean
# 9                  mainnet_income_call_sbr
# 10                mainnet_income_call_luna
# 11                 mainnet_income_call_ray
# 12                mainnet_income_call_step
# 13               mainnet_income_call_stsol
# 14                mainnet_income_call_avax
# 15                 mainnet_income_put_luna
# 16                  mainnet_income_put_sol
# 17             mainnet_income_put_sol_high
# 18                 mainnet_income_put_mngo
# 19                  mainnet_income_put_btc
# 20               mainnet_income_put_tsUSDC
# 21                  mainnet_income_put_eth
# 22    mainnet_income_put_sol_step_circuits
# 23  mainnet_income_put_sol_parrot_circuits
# 24  mainnet_income_put_eth_parrot_circuits
# 25    mainnet_income_put_btc_step_circuits
# 26     mainnet_income_put_sol_uxd_circuits
#
#                                   vaultAuthority  \
# 0   DA1M8mw7GnPNKU9ReANtHPQyuVzKZtsuuSbCyc2uX2du
# 1   Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 2    wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# 3   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH
# 4   FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# 5   7KqHFuUksvNhrWgoacKkqyp2RwfBNdypCYgK9nxD1d6K
# 6   2P427N5sYcEXvZAZwqNzjXEHsBMESQoLyjNquTSmGPMb
# 7   B3yakZxwomkmnCxRr8ZmQtiWgtxtVBuCREDFDdAvcCVQ
# 8   A5MpyajTy6hdsg3S2em5ukcgY1ZBhxTxEKv8BgHajv1A
# 9   BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h
# 10  5oV1Yf8q1oQgPYuHjepjmKFuaG2Wng9dzTqbSWhU5W2X
# 11  A6XsYxGj9wpqUZG81XwgQJ2zJ3efCbuWSQfnkHqUSmdM
# 12  FiEHDTKT6X7VFwGaUmsm1XXYr8vvkoSR5EqcY4znpefq
# 13  2Ahpeqc1bo7Y4dVknvZUVfZPhHhym7JN6az2XMbUA6QA
# 14  5LrULR5w9N1dfnJ9vHnzRkQi9uBL3CkSRWkDGTG6dP1e
# 15  5kA7FPiB3t2X5s65dK1AoEu5asDjC5d7f5vaB4iY2yrj
# 16  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
# 17  BThMeTgWZBoBbAzp9sK9T7gQzpQDQdRQUVLtVQ3781q1
# 18  CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# 19  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 20  AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8
# 21  EA29Xf3HGMtYziw7UKZDUKby7gkoCbXwmiNKwc7z54Ax
# 22  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 23  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
# 24  EfxrH3pwGBuRJgbbA9x5skFamLVXUhDnA7DukZmDsjaL
# 25  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY
# 26  HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
#
#                                   shareTokenMint depositTokenSymbol  \
# 0   3BjcHXvyzMsjmeqE2qFLx45K4XFx3JPiyRnjJiF5MAHt                BTC
# 1   4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 2   DNa849drqW19uBV5X9ohpJ5brRGzq856gk3HDRqveFrA                SOL
# 3   6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt               mSOL
# 4   GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS                ETH
# 5   7wDh4VCTPwx41kvbLE6fkFgMEjnqw7NpGJvQtNabCm2B                FTT
# 6   5SLqZSywodLS8ih6U2AAioZrxpgR149hR8SApmCB7r5X                SRM
# 7   4sTuzTYfcE2NF7zy6Sy8XhVcNLa6JQSLrx3roy97n4sD               MNGO
# 8    5VmdHqvRMbXivuC34w4Hux9zb1y9moiBEQmXDrTR1kV             scnSOL
# 9   DPMCwE9z9jXaDVDti5aKhdgCWGgsvioz6ZvB9eZjH7UE                SBR
# 10  95sn4kgeJnnBfRCD8S2quu4HS9Y6vb7JDuXrarnmEjYE               LUNA
# 11   SoAnGsHVqSyaN4MjWoPCcftC1V6oSeNxLJjF5TXrtuL                RAY
# 12  AQFLXqLLofcbUCoi5HPfuuvX6vMPafubZfBNBMumnKq2               STEP
# 13  EPoDdEcDQ478YNRAiMYMHLs7mEnmo5z9322Q2D5exKFU              stSOL
# 14  HLfkEc6E2HEcABaWm3QZSfDvswzXjh1onF9xEzUAtWNS               AVAX
# 15  74ozhToAS71nDVBtFZMMucdkNB95tV2o5fhtFGQeixwS                UST
# 16  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU               USDC
# 17  G8jsAWUA2KdDn7XmV1sBqUdbEXESaPdjPWDEYCsnkRX2               USDC
# 18  CxHG1tPkeEHsAVmPF2UrjZK3W719J5DGFgMaLtUkBoeP               USDC
# 19   THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC               USDC
# 20  Fw8mw9zNyfngvBYuS2L6XWfvFE8fExQ3apZVw4Ery5oy             tsUSDC
# 21  2uTkms42P62dJ7JRaefc1HFkvyBeMP28J6MPmH1gVHoT               USDC
# 22   Bikt7D3nMQmJSpxX7oczCDKgevrpWk3g4D3VhQZzqAT               USDC
# 23  J1TX6c1R6WykW2wonvrL6xA2g8vZ2FLDqDDF1mLYrMYK               USDC
# 24  5VF9CTD9GNNDSrfQ1ZswfMdCc2NkbH2hvTirSb1FMEo3               USDC
# 25  ET4nQ6we7KDemfzni8dy2EkNCuYo1RryiRPjC6XwnnC3               USDC
# 26  BAyzqZuKUQ4k93Yfm3xp85SkAKtr4xghBsqZLBTZT14z               USDC
#
#    depositTokenCoingeckoId
# 0                  bitcoin
# 1                   solana
# 2                   solana
# 3                     msol
# 4                 ethereum
# 5                ftx-token
# 6                    serum
# 7            mango-markets
# 8        socean-staked-sol
# 9                    saber
# 10              terra-luna
# 11                 raydium
# 12            step-finance
# 13         lido-staked-sol
# 14             avalanche-2
# 15                terrausd
# 16                usd-coin
# 17                usd-coin
# 18                usd-coin
# 19                usd-coin
# 20                usd-coin
# 21                usd-coin
# 22                usd-coin
# 23                usd-coin
# 24                usd-coin
# 25                usd-coin
# 26                usd-coin
