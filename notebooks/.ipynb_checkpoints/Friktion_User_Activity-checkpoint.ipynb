# %%
"""
Python script to scrape Friktion User Data from Bitquery GraphQL API.

"""

import json
import requests
import requests
import traceback
import time

import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from os.path import exists


class MyPortfolio:
    """
    Python ETL script for Friktion user portfolio data. Currently supported Instruction Names:
        - Deposit
        - CancelPendingDeposit
        - Withdrawal
        - CancelPendingWithdrawal
        - ClaimPendingWithdrawal
    """

    def __init__(
        self,
        date_start,
        date_end,
        ix_fname="./friktion_ix.csv",
        deposit_fname="./friktion_deposit.csv",
        deposit_cxl_fname="./friktion_deposit_cxl.csv",
        withdraw_fname="./friktion_withdraw.csv",
        withdraw_cxl_fname="./friktion_withdraw_cancel.csv",
        withdraw_claim_fname="./friktion_claim_withdrawal.csv",
        batch_size_days=2,
        batch_size_xfers=90,
        skip_ix_scrape=False
    ):
        """
        :ix_fname:              output csv for instructions
        :deposit_fname:         output csv for deposits
        :deposit_cxl_fname:     output csv for deposit cancels
        :withdraw_fname:        output csv for withdrawals
        :withdraw_cxl_fname:    output csv for withdrawal cancels
        :withdraw_claim_fname:  output csv for claiming pending withdrawal
        :batch_size_days:       batch size in days for query to keep query < 10k symbols. Use bigger steps for larger data.
        :batch_size_transfers:  batch size transactions for query to keep query < 8kb

        """
        self.volt_program = "VoLT1mJz1sbnxwq5Fv2SXjdVDgPXrb9tJyC8WpMDkSp"
        self.date_start = date_start
        self.date_end = date_end
        self.ix_fname = ix_fname
        self.deposit_fname = deposit_fname
        self.deposit_cxl_fname = deposit_cxl_fname
        self.withdraw_fname = withdraw_fname
        self.withdraw_cxl_fname = withdraw_cxl_fname
        self.withdraw_claim_fname = withdraw_claim_fname
        self.batch_size_days = batch_size_days
        self.batch_size_xfers = batch_size_xfers
        self.skip_ix_scrape = skip_ix_scrape
        
        self.df_ix = pd.read_csv(ix_fname) if skip_ix_scrape else [] 
        self.friktion_metadata = self.get_friktion_snapshot()

    ########################################################################################################
    ####################################          Queries             ######################################
    ########################################################################################################

    @property
    def ix_query(self):
        return """
            query MyQuery {
              solana {
                instructions(
                  time: {between: ["%s", "%s"]}
                  success: {is: true}
                  programId: {is: "VoLT1mJz1sbnxwq5Fv2SXjdVDgPXrb9tJyC8WpMDkSp"}
                  options: {limit: 8700}
                ) {
                  block {
                    timestamp {
                      iso8601
                    }
                  }
                  transaction {
                    signature
                    feePayer
                  }
                  data {
                    base58
                  }
                }
              }
            }
        """

    @property
    def xfer_query(self):
        return """
            query MyQuery {
              solana(network: solana) {
                transfers(
                  signature: {in: [%s]}
                  options: {limit: 2000}
                ) {
                  instruction {
                    action {
                      name
                    }
                    callPath
                  }
                  amount(success: {is: true})
                  transaction {
                    signer
                    signature
                  }
                  block {
                    timestamp {
                      iso8601
                    }
                  }
                  currency {
                    name
                    address
                  }
                  sender {
                    address
                    mintAccount
                  }
                  receiver {
                    address
                  }
                }
              }
            }
        """

    ########################################################################################################
    ################################          Helper Functions             #################################
    ########################################################################################################

    # TODO: Add retry logic to this in case of hangups.
    @staticmethod
    def run_query(query, retries=10):
        """
        Query graphQL API.

        If timeerror
        """
        headers = {"X-API-KEY": "BQYCaXaMZlqZrPCSQVsiJrKtxKRVcSe4"}

        retries_counter = 0
        try:
            request = requests.post(
                "https://graphql.bitquery.io/", json={"query": query}, headers=headers
            )
            result = request.json()
            # print(dir(request.content))
            # Make sure that there is no error message
            # assert not request.content.errors
            assert "errors" not in result
        except:
            while (
                (request.status_code != 200
                or "errors" in result)
                and retries_counter < 10
            ):
                print(datetime.now(), f"Retry number {retries_counter}")
                if "errors" in result:
                    print(result["errors"])
                print(datetime.now(), f"Query failed for reason: {request.reason}. sleeping for {150*retries_counter} seconds and retrying...")
                time.sleep(150*retries_counter)
                request = requests.post(
                    "https://graphql.bitquery.io/",
                    json={"query": query},
                    headers=headers,
                )
                retries_counter += 1
            if retries_counter >= retries:
                raise Exception(
                    "Query failed after {} retries and return code is {}.{}".format(
                        retries_counter, request.status_code, query
                    )
                )
        return request.json()


    @staticmethod
    def batch_iterable(iterable, n=1):
        """
        Takes in an iterable and returns an iterable of iterables with len==x
        """
        idxs = []
        l = len(iterable)
        for idx in range(0, l, n):
            idxs.append(iterable[idx : min(idx + n, l)])
        return idxs

    def format_txs_for_query(self, tx_signatures):
        """
        Batches a list of transactions into a list of string formatted transactions for querying.
        Each of these strings contain (n=self.batch_size_xfers) unique transaction IDs.
        """
        batched_signatures = self.batch_iterable(tx_signatures, self.batch_size_xfers)

        def format_txs(x):
            return str(x)[1:-1].replace("'", '"').replace("\n", "")

        tx_strs = list(map(format_txs, batched_signatures))

        return tx_strs

    def get_existing_df(self, fname):
        """
        Create output file if doesn't exist and returns a DataFrame
        """
        if fname and exists(fname):
            return pd.read_csv(fname)
        else:
            return pd.DataFrame()

    @staticmethod
    def instruction_match(instructionData):
        """
        Match 8-bit instruction identifier with the corresonding instructionType
        """
        if not instructionData or len(instructionData) < 8:
            return False

        instructionDescriptor = instructionData[:8]

        if instructionDescriptor == "PcB3tF1K":
            return "Withdraw"
        elif instructionDescriptor == "WuE7Hjns":
            return "Deposit"
        elif instructionDescriptor == "V8cW2nMq":
            return "CancelPendingDeposit"
        elif instructionDescriptor == "dxUbSCWk":
            return "CancelPendingWithdrawal"
        elif instructionDescriptor == "WcTWQsnk":
            return "ClaimPendingWithdrawal"
        else:
            return "Unclassified"

    def get_friktion_snapshot(self):
        """
        Load Friktion Metadata for Volt/Symbol Mapping to join to normal data

        """
        try:
            return pd.DataFrame(
                dict(
                    json.loads(
                        requests.get(
                            "https://friktion-labs.github.io/mainnet-tvl-snapshots/friktionSnapshot.json"
                        ).content
                    )
                )["allMainnetVolts"]
            )[
                [
                    "globalId",
                    "vaultAuthority",
                    "shareTokenMint",
                    "depositTokenSymbol",
                    "depositTokenCoingeckoId",
                ]
            ]
        except Exception as e:
            print(datetime.now(), "Snapshot Data Invalid")
            traceback.print_exc()

    ########################################################################################################
    ################################          Data Retrieval             ###################################
    ########################################################################################################

    def get_ix(self, date_start, date_end):
        """
        Runs graphql instruction query for one date range.
        """
        print(date_start, date_end)
        query = self.ix_query % (date_start, date_end)
        print(
            datetime.now(),
            "retrieving instructions for {} to {}".format(date_start, date_end),
        )
        result = self.run_query(query)

        # convert GraphQL json to pandas dataframe
        try:
            df = pd.json_normalize(result["data"]["solana"]["instructions"])
        except:
            print(result)
            traceback.print_exc()
            raise Exception(datetime.now(), "Empty Results... Try Again")

        print(datetime.now(), df.shape[0], "instructions retrieved")

        df = df.rename(
            columns={
                "block.timestamp.iso8601": "timestamp",
                "log.consumed": "computeUnits",
                "transaction.signature": "txSignature",
                "transaction.feePayer": "txSigner",
                "data.base58": "instructionData",
            }
        )
        return df

    def get_ix_batch(self):
        """
        Batch the instruction retrieval. Save the shit Drop duplicates.

        """
        # Batch the days up nice and good so the graphql API calls don't bitch
        dates_batched = pd.date_range(self.date_start, self.date_end, freq=f"{self.batch_size_days}D")
        dates_batched = [
            str(x.isoformat())
            for x in dates_batched.append(pd.DatetimeIndex([self.date_end]))
        ]
        date_ranges = list(zip(dates_batched, dates_batched[1:]))
        ixs = []
        for date_range in date_ranges:
            assert len(date_range) == 2
            data = self.get_ix(date_range[0], date_range[1])
            ixs.append(data)

        df_ix = pd.concat(ixs, ignore_index=False)
        df_ix["instructionType"] = df_ix.instructionData.apply(
            lambda x: self.instruction_match(x)
        )

        # Store df_ix before we write it to the DataFrame so we avoid getting xfers for every single ix 
        self.df_ix = df_ix.drop_duplicates(["txSignature", "instructionType"]).reset_index(drop=True)
        print(datetime.now(), "final instruction data size: ", df_ix.shape[0])

        # Save new data to file
        df_old = self.get_existing_df(self.ix_fname)
        df = df_ix.append(df_old).reset_index(drop=True)
        df = df.drop_duplicates(["txSignature", "instructionType"])
        df.to_csv(self.ix_fname, index=False)
        print(datetime.now(), "wrote instruction data to csv...")

    def get_batched_xfers(self, instructionType, fname):
        """
        Get all transfers corresponding to a specific instructionType from Graphql query.
        Batch these queries up b/c the string size is
        too large (curse GraphQL for not supporting joins)

        :instructionType: String corresponding to the instruction type of each query.
        :fname: Name of where the old df is stored

        """

        temp = self.df_ix.query(f"instructionType == '{instructionType}'")

        if temp.empty:
            print(
                datetime.now(), "instructionType was not found in the data... breaking"
            )
            return

        tx_signatures = list(temp["txSignature"].unique())
        tx_strs = self.format_txs_for_query(tx_signatures)
        print(datetime.now(), len(tx_strs), "signature batches required...")
        xfers = []

        for i, tx_str in enumerate(tx_strs):
            query = self.xfer_query % (tx_str)
            result = self.run_query(query)
            # TODO: Clean up this duplicated logic
            try:
                df = pd.json_normalize(result["data"]["solana"]["transfers"])
            except:
                print(result)
                traceback.print_exc()
                raise Exception("Empty Results... Try Again")
            xfers.append(df)
            print(datetime.now(), df.shape[0], "transfers scraped in batch %d" % i)

        df_xfer = pd.concat(xfers, ignore_index=False)
        df_xfer = df_xfer.rename(
            columns={
                "block.timestamp.iso8601": "timestamp",
                "instruction.action.name": "instructionAction",
                "instruction.callPath": "instructionOrder",
                "transaction.signer": "userAddress",
                "transaction.signature": "txSignature",
                "currency.name": "currencyName",
                "receiver.address": "receiverAddress",
                "sender.address": "senderAddress",
                "currency.decimals": "currencyDecimals",
                "currency.address": "currencyAddress",
                "sender.mintAccount": "senderTokenMint",
            }
        )

        print(datetime.now(), df_xfer.shape[0], "transfers retrieved")

        df_old = self.get_existing_df(fname)
        df_final = df_old.append(df_xfer, ignore_index=True).sort_values(
            "instructionOrder"
        )

        return df_final

    def parse_deposits(self):
        instructionType = "Deposit"
        instructionAction = "transfer"
        tx_merge_key = "receiverAddress"
        meta_merge_key = "vaultAuthority"
        out_file = self.deposit_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_withdrawal(self):
        instructionType = "Withdraw"
        instructionAction = "burn"
        tx_merge_key = "currencyAddress"
        meta_merge_key = "shareTokenMint"
        out_file = self.withdraw_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_deposit_cancel(self):
        instructionType = "CancelPendingDeposit"
        instructionAction = "transfer"
        tx_merge_key = "senderAddress"
        meta_merge_key = "vaultAuthority"
        out_file = self.deposit_cxl_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_withdrawal_cancel(self):
        instructionType = "CancelPendingWithdrawal"
        instructionAction = "mintTo"
        tx_merge_key = "currencyAddress"
        meta_merge_key = "shareTokenMint"
        out_file = self.withdraw_cxl_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_claim_withdrawal(self):
        instructionType = "ClaimPendingWithdrawal"
        instructionAction = "transfer"
        tx_merge_key = "senderAddress"
        meta_merge_key = "vaultAuthority"
        out_file = self.withdraw_claim_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_base(
        self,
        instructionType,
        instructionAction,
        tx_merge_key,
        meta_merge_key,
        output_file,
    ):
        """
        generalized method for parsing transfer data.

        1. Call get_batched_xfers()
        2. for each unique txSignature, find the xfer matching to the last instance of the instructionAction
        3. For SOL CC vaults, need an extra step and query for instructionAccount to find vaultAuthority.
        3. Join it to the friktion metadata based using tx_merge_key and meta_merge_key
        4. Drop extraneous rows
        5. Save the file to the output_file

        :instructionType: Type of instruction listed out in the instruction_match() method
        :instructionAction: type of transfer we are matching towards
        :tx_merge_key: what key in the xfer dataFrame do we want to merge on
        :meta_merge_key: what key in the metadata dataFrame we want to merge on.
        :output_file: as name suggests
        """
        print(
            datetime.now(),
            "Parsing transfers for instructionType: %s" % instructionType,
        )
        df = self.get_batched_xfers(instructionType, output_file)

        # Target only wrapped SOL entries for SOL vaults
        df = df.query('currencyName != "Solana"')

        df = (
            df.query('instructionAction=="{}"'.format(instructionAction))
            .groupby("txSignature")
            .last()
            .reset_index()
        )

        # Join tables and get rid of extraneous columns from metadata.
        df = pd.merge(
            df,
            self.friktion_metadata,
            how="left",
            left_on=tx_merge_key,
            right_on=meta_merge_key,
            suffixes=("", "_drop"),
        )
        df.drop([col for col in df.columns if "drop" in col], axis=1, inplace=True)

        # Tag the row with the instructionType
        df["userAction"] = instructionType

        df.drop_duplicates().to_csv(output_file, index=False)
        print(datetime.now(), "{} data size: {}".format(instructionType, df.shape[0]))

    def parse_all(self):
        if not self.skip_ix_scrape:
            self.get_ix_batch()
#         self.parse_claim_withdrawal()
#         self.parse_deposit_cancel()
#         self.parse_withdrawal_cancel()
#         self.parse_withdrawal()
        self.parse_deposits()

    ########################################################################################################
    #####################################          Tests             #######################################
    ########################################################################################################

    def check_fidelity(self):
        ix = pd.read_csv(self.ix_fname)
        deposits = pd.read_csv(self.deposit_fname)
        withdrawals = pd.read_csv(self.withdraw_fname)
        claim = pd.read_csv(self.withdraw_claim_fname)
        withdrawals_cxl = pd.read_csv(self.withdraw_cxl_fname)
        deposits_cxl = pd.read_csv(self.deposit_cxl_fname)

        assert ix.loc[ix.instructionType == "Deposit"].shape[0] == deposits.shape[0]
        assert ix.loc[ix.instructionType == "Withdraw"].shape[0] == withdrawals.shape[0]
        assert (
            ix.loc[ix.instructionType == "ClaimPendingWithdrawal"].shape[0]
            == claim.shape[0]
        )
        assert (
            ix.loc[ix.instructionType == "CancelPendingDeposit"].shape[0]
            == deposits_cxl.shape[0]
        )
        assert (
            ix.loc[ix.instructionType == "CancelPendingWithdrawal"].shape[0]
            == withdrawals_cxl.shape[0]
        )


# if __name__ == "__main__":
#     date_start = "2021-12-16T16:00:00Z"
#     date_end = "2022-04-01T00:00:00Z"

#     x = MyPortfolio(date_start, date_end)
#     x.parse_all()
#     x.check_fidelity()

# %%
date_start = "2021-12-16T00:00:00Z"
date_end = "2022-03-01T00:00:00Z"

x = MyPortfolio(date_start, date_end, skip_ix_scrape=True)

x.parse_all()

x.check_fidelity()
# Out:
# 2022-03-31 23:52:07.497426 Parsing transfers for instructionType: Deposit
# 2022-03-31 23:52:07.521870 327 signature batches required...
# 2022-03-31 23:52:11.428909 603 transfers scraped in batch 0
# 2022-03-31 23:52:17.099463 654 transfers scraped in batch 1
# 2022-03-31 23:52:24.195336 666 transfers scraped in batch 2
# 2022-03-31 23:52:28.822242 686 transfers scraped in batch 3
# 2022-03-31 23:52:40.784958 658 transfers scraped in batch 4
# 2022-03-31 23:52:47.940817 662 transfers scraped in batch 5
# 2022-03-31 23:52:53.297398 757 transfers scraped in batch 6
# 2022-03-31 23:52:56.809830 637 transfers scraped in batch 7
# 2022-03-31 23:53:00.357453 686 transfers scraped in batch 8
# 2022-03-31 23:53:05.589209 594 transfers scraped in batch 9
# 2022-03-31 23:53:09.133205 535 transfers scraped in batch 10
# 2022-03-31 23:53:12.669744 602 transfers scraped in batch 11
# 2022-03-31 23:53:15.983719 558 transfers scraped in batch 12
# 2022-03-31 23:53:24.047652 546 transfers scraped in batch 13
# 2022-03-31 23:53:28.243222 519 transfers scraped in batch 14
# 2022-03-31 23:53:32.513097 697 transfers scraped in batch 15
# 2022-03-31 23:53:36.142142 635 transfers scraped in batch 16
# 2022-03-31 23:53:42.329523 648 transfers scraped in batch 17
# 2022-03-31 23:53:45.857098 562 transfers scraped in batch 18
# 2022-03-31 23:53:49.193370 445 transfers scraped in batch 19
# 2022-03-31 23:53:52.687985 442 transfers scraped in batch 20
# 2022-03-31 23:53:55.755112 384 transfers scraped in batch 21
# 2022-03-31 23:54:03.283708 456 transfers scraped in batch 22
# 2022-03-31 23:54:11.316700 390 transfers scraped in batch 23
# 2022-03-31 23:54:14.480271 391 transfers scraped in batch 24
# 2022-03-31 23:54:20.595933 383 transfers scraped in batch 25
# 2022-03-31 23:54:24.351447 390 transfers scraped in batch 26
# 2022-03-31 23:54:28.072909 424 transfers scraped in batch 27
# 2022-03-31 23:54:32.055261 523 transfers scraped in batch 28
# 2022-03-31 23:54:37.218331 503 transfers scraped in batch 29
# 2022-03-31 23:54:42.090426 635 transfers scraped in batch 30
# 2022-03-31 23:54:45.477399 559 transfers scraped in batch 31
# 2022-03-31 23:54:48.807661 554 transfers scraped in batch 32
# 2022-03-31 23:54:52.068021 482 transfers scraped in batch 33
# 2022-03-31 23:54:56.923188 334 transfers scraped in batch 34
# 2022-03-31 23:55:05.473602 339 transfers scraped in batch 35
# 2022-03-31 23:55:14.061062 294 transfers scraped in batch 36
# 2022-03-31 23:55:17.357512 327 transfers scraped in batch 37
# 2022-03-31 23:55:28.318053 313 transfers scraped in batch 38
# 2022-03-31 23:55:32.848743 306 transfers scraped in batch 39
# 2022-03-31 23:55:36.741007 309 transfers scraped in batch 40
# 2022-03-31 23:55:40.500704 340 transfers scraped in batch 41
# 2022-03-31 23:55:45.505660 317 transfers scraped in batch 42
# 2022-03-31 23:55:49.530124 324 transfers scraped in batch 43
# 2022-03-31 23:55:52.513708 335 transfers scraped in batch 44
# 2022-03-31 23:55:55.544908 357 transfers scraped in batch 45
# 2022-03-31 23:55:58.563322 325 transfers scraped in batch 46
# 2022-03-31 23:56:01.874450 319 transfers scraped in batch 47
# 2022-03-31 23:56:04.792419 294 transfers scraped in batch 48
# 2022-03-31 23:56:07.756563 304 transfers scraped in batch 49
# 2022-03-31 23:56:10.677819 312 transfers scraped in batch 50
# 2022-03-31 23:56:16.827517 361 transfers scraped in batch 51
# 2022-03-31 23:56:20.303946 265 transfers scraped in batch 52
# 2022-03-31 23:56:23.450138 217 transfers scraped in batch 53
# 2022-03-31 23:56:27.068867 242 transfers scraped in batch 54
# 2022-03-31 23:56:32.511093 243 transfers scraped in batch 55
# 2022-03-31 23:56:36.305273 238 transfers scraped in batch 56
# 2022-03-31 23:56:39.361658 234 transfers scraped in batch 57
# 2022-03-31 23:56:42.200454 251 transfers scraped in batch 58
# 2022-03-31 23:56:44.910661 328 transfers scraped in batch 59
# 2022-03-31 23:56:47.795766 348 transfers scraped in batch 60
# 2022-03-31 23:56:51.960387 322 transfers scraped in batch 61
# 2022-03-31 23:56:54.941356 346 transfers scraped in batch 62
# 2022-03-31 23:56:57.807246 372 transfers scraped in batch 63
# 2022-03-31 23:57:00.673224 369 transfers scraped in batch 64
# 2022-03-31 23:57:08.703112 417 transfers scraped in batch 65
# 2022-03-31 23:57:21.011793 386 transfers scraped in batch 66
# 2022-03-31 23:57:30.468603 386 transfers scraped in batch 67
# 2022-03-31 23:57:48.412953 398 transfers scraped in batch 68
# 2022-03-31 23:58:05.040468 430 transfers scraped in batch 69
# 2022-03-31 23:58:19.586120 430 transfers scraped in batch 70
# 2022-03-31 23:58:26.001811 393 transfers scraped in batch 71
# 2022-03-31 23:58:29.541471 359 transfers scraped in batch 72
# 2022-03-31 23:58:33.148682 346 transfers scraped in batch 73
# 2022-03-31 23:58:38.244459 226 transfers scraped in batch 74
# 2022-03-31 23:58:41.295854 392 transfers scraped in batch 75
# 2022-03-31 23:58:44.220460 345 transfers scraped in batch 76
# 2022-03-31 23:58:46.972134 288 transfers scraped in batch 77
# 2022-03-31 23:58:50.375606 289 transfers scraped in batch 78
# 2022-03-31 23:58:58.563964 296 transfers scraped in batch 79
# 2022-03-31 23:59:02.217553 346 transfers scraped in batch 80
# 2022-03-31 23:59:05.536290 312 transfers scraped in batch 81
# 2022-03-31 23:59:08.465028 310 transfers scraped in batch 82
# 2022-03-31 23:59:11.197567 285 transfers scraped in batch 83
# 2022-03-31 23:59:16.818821 332 transfers scraped in batch 84
# 2022-03-31 23:59:19.864402 411 transfers scraped in batch 85
# 2022-03-31 23:59:23.522489 426 transfers scraped in batch 86
# 2022-03-31 23:59:26.905841 469 transfers scraped in batch 87
# 2022-03-31 23:59:31.212360 474 transfers scraped in batch 88
# 2022-03-31 23:59:38.737797 415 transfers scraped in batch 89
# 2022-03-31 23:59:42.856618 463 transfers scraped in batch 90
# 2022-03-31 23:59:45.656685 306 transfers scraped in batch 91
# 2022-03-31 23:59:48.704363 386 transfers scraped in batch 92
# 2022-03-31 23:59:51.382089 326 transfers scraped in batch 93
# 2022-03-31 23:59:54.694532 412 transfers scraped in batch 94
# 2022-03-31 23:59:57.745936 412 transfers scraped in batch 95
# 2022-04-01 00:00:00.818887 353 transfers scraped in batch 96
# 2022-04-01 00:00:08.756701 426 transfers scraped in batch 97
# 2022-04-01 00:00:12.193924 408 transfers scraped in batch 98
# 2022-04-01 00:00:15.533145 525 transfers scraped in batch 99
# 2022-04-01 00:00:20.555635 404 transfers scraped in batch 100
# 2022-04-01 00:00:32.492031 296 transfers scraped in batch 101
# 2022-04-01 00:00:43.978598 340 transfers scraped in batch 102
# 2022-04-01 00:00:51.914592 319 transfers scraped in batch 103
# 2022-04-01 00:00:55.625304 315 transfers scraped in batch 104
# 2022-04-01 00:00:58.728632 327 transfers scraped in batch 105
# 2022-04-01 00:01:01.772557 352 transfers scraped in batch 106
# 2022-04-01 00:01:05.273771 420 transfers scraped in batch 107
# 2022-04-01 00:01:10.367179 313 transfers scraped in batch 108
# 2022-04-01 00:01:13.085699 321 transfers scraped in batch 109
# 2022-04-01 00:01:15.894248 337 transfers scraped in batch 110
# 2022-04-01 00:01:18.985650 348 transfers scraped in batch 111
# 2022-04-01 00:01:22.443206 317 transfers scraped in batch 112
# 2022-04-01 00:01:29.659313 331 transfers scraped in batch 113
# 2022-04-01 00:01:35.081224 300 transfers scraped in batch 114
# 2022-04-01 00:01:38.375593 361 transfers scraped in batch 115
# 2022-04-01 00:01:41.298369 316 transfers scraped in batch 116
# 2022-04-01 00:01:44.345702 407 transfers scraped in batch 117
# 2022-04-01 00:01:48.399456 414 transfers scraped in batch 118
# 2022-04-01 00:01:52.683879 388 transfers scraped in batch 119
# 2022-04-01 00:01:55.550198 393 transfers scraped in batch 120
# 2022-04-01 00:01:58.501240 409 transfers scraped in batch 121
# 2022-04-01 00:02:01.722455 410 transfers scraped in batch 122
# 2022-04-01 00:02:04.900977 478 transfers scraped in batch 123
# 2022-04-01 00:02:11.158352 551 transfers scraped in batch 124
# 2022-04-01 00:02:14.391125 454 transfers scraped in batch 125
# 2022-04-01 00:02:17.615054 436 transfers scraped in batch 126
# 2022-04-01 00:02:21.434408 470 transfers scraped in batch 127
# 2022-04-01 00:02:29.165416 460 transfers scraped in batch 128
# 2022-04-01 00:02:34.481774 514 transfers scraped in batch 129
# 2022-04-01 00:02:37.597094 465 transfers scraped in batch 130
# 2022-04-01 00:02:40.754247 468 transfers scraped in batch 131
# 2022-04-01 00:02:43.625654 365 transfers scraped in batch 132
# 2022-04-01 00:02:49.283914 461 transfers scraped in batch 133
# 2022-04-01 00:02:52.653149 453 transfers scraped in batch 134
# 2022-04-01 00:02:55.935397 448 transfers scraped in batch 135
# 2022-04-01 00:03:02.250460 395 transfers scraped in batch 136
# 2022-04-01 00:03:13.275210 417 transfers scraped in batch 137
# 2022-04-01 00:03:23.237423 476 transfers scraped in batch 138
# 2022-04-01 00:03:27.917712 405 transfers scraped in batch 139
# 2022-04-01 00:03:31.737167 366 transfers scraped in batch 140
# 2022-04-01 00:03:36.974050 431 transfers scraped in batch 141
# 2022-04-01 00:03:45.090379 419 transfers scraped in batch 142
# 2022-04-01 00:03:49.902555 483 transfers scraped in batch 143
# 2022-04-01 00:03:52.945140 394 transfers scraped in batch 144
# 2022-04-01 00:03:55.898800 366 transfers scraped in batch 145
# 2022-04-01 00:03:58.736860 358 transfers scraped in batch 146
# 2022-04-01 00:04:02.264638 437 transfers scraped in batch 147
# 2022-04-01 00:04:05.947046 379 transfers scraped in batch 148
# 2022-04-01 00:04:21.182076 375 transfers scraped in batch 149
# 2022-04-01 00:04:24.896573 323 transfers scraped in batch 150
# 2022-04-01 00:04:28.429345 368 transfers scraped in batch 151
# 2022-04-01 00:04:31.907159 321 transfers scraped in batch 152
# 2022-04-01 00:04:34.779276 340 transfers scraped in batch 153
# 2022-04-01 00:04:40.916407 392 transfers scraped in batch 154
# 2022-04-01 00:04:44.147734 385 transfers scraped in batch 155
# 2022-04-01 00:04:46.974767 315 transfers scraped in batch 156
# 2022-04-01 00:04:49.957973 406 transfers scraped in batch 157
# 2022-04-01 00:04:52.752883 388 transfers scraped in batch 158
# 2022-04-01 00:05:01.152297 445 transfers scraped in batch 159
# 2022-04-01 00:05:04.411282 398 transfers scraped in batch 160
# 2022-04-01 00:05:07.435238 401 transfers scraped in batch 161
# 2022-04-01 00:05:10.389171 331 transfers scraped in batch 162
# 2022-04-01 00:05:16.357006 376 transfers scraped in batch 163
# 2022-04-01 00:05:19.886169 378 transfers scraped in batch 164
# 2022-04-01 00:05:23.685642 387 transfers scraped in batch 165
# 2022-04-01 00:05:27.503413 399 transfers scraped in batch 166
# 2022-04-01 00:05:34.000923 417 transfers scraped in batch 167
# 2022-04-01 00:05:42.626124 442 transfers scraped in batch 168
# 2022-04-01 00:05:45.700232 331 transfers scraped in batch 169
# 2022-04-01 00:05:54.051648 387 transfers scraped in batch 170
# 2022-04-01 00:06:05.446807 348 transfers scraped in batch 171
# 2022-04-01 00:06:10.732048 325 transfers scraped in batch 172
# 2022-04-01 00:06:13.758394 344 transfers scraped in batch 173
# 2022-04-01 00:06:16.995544 464 transfers scraped in batch 174
# 2022-04-01 00:06:22.391545 394 transfers scraped in batch 175
# 2022-04-01 00:06:26.296967 420 transfers scraped in batch 176
# 2022-04-01 00:06:30.306575 489 transfers scraped in batch 177
# 2022-04-01 00:06:33.837920 369 transfers scraped in batch 178
# 2022-04-01 00:06:36.767986 333 transfers scraped in batch 179
# 2022-04-01 00:06:42.407582 423 transfers scraped in batch 180
# 2022-04-01 00:06:45.555789 429 transfers scraped in batch 181
# 2022-04-01 00:06:58.645379 436 transfers scraped in batch 182
# 2022-04-01 00:07:01.807739 430 transfers scraped in batch 183
# 2022-04-01 00:07:04.985359 415 transfers scraped in batch 184
# 2022-04-01 00:07:10.483752 442 transfers scraped in batch 185
# 2022-04-01 00:07:13.692813 454 transfers scraped in batch 186
# 2022-04-01 00:07:16.698151 333 transfers scraped in batch 187
# 2022-04-01 00:07:20.292360 418 transfers scraped in batch 188
# 2022-04-01 00:07:24.393150 331 transfers scraped in batch 189
# 2022-04-01 00:07:31.449516 478 transfers scraped in batch 190
# 2022-04-01 00:07:35.200304 488 transfers scraped in batch 191
# 2022-04-01 00:07:38.203957 342 transfers scraped in batch 192
# 2022-04-01 00:07:41.164530 343 transfers scraped in batch 193
# 2022-04-01 00:07:44.320861 403 transfers scraped in batch 194
# 2022-04-01 00:07:49.089173 450 transfers scraped in batch 195
# 2022-04-01 00:07:51.965807 338 transfers scraped in batch 196
# 2022-04-01 00:07:54.838383 376 transfers scraped in batch 197
# 2022-04-01 00:07:57.801552 359 transfers scraped in batch 198
# 2022-04-01 00:08:01.067719 352 transfers scraped in batch 199
# 2022-04-01 00:08:07.007051 375 transfers scraped in batch 200
# 2022-04-01 00:08:10.980796 430 transfers scraped in batch 201
# 2022-04-01 00:08:14.286893 355 transfers scraped in batch 202
# 2022-04-01 00:08:21.510123 424 transfers scraped in batch 203
# 2022-04-01 00:08:33.056458 527 transfers scraped in batch 204
# 2022-04-01 00:08:41.265059 384 transfers scraped in batch 205
# 2022-04-01 00:08:54.374631 460 transfers scraped in batch 206
# 2022-04-01 00:08:59.790644 403 transfers scraped in batch 207
# 2022-04-01 00:09:02.958880 405 transfers scraped in batch 208
# 2022-04-01 00:09:06.149012 402 transfers scraped in batch 209
# 2022-04-01 00:09:09.634067 431 transfers scraped in batch 210
# 2022-04-01 00:09:15.046569 414 transfers scraped in batch 211
# 2022-04-01 00:09:20.043760 408 transfers scraped in batch 212
# 2022-04-01 00:09:23.697868 422 transfers scraped in batch 213
# 2022-04-01 00:09:27.342892 348 transfers scraped in batch 214
# 2022-04-01 00:09:32.083235 319 transfers scraped in batch 215
# 2022-04-01 00:09:37.712846 368 transfers scraped in batch 216
# 2022-04-01 00:09:40.617033 294 transfers scraped in batch 217
# 2022-04-01 00:09:43.708456 383 transfers scraped in batch 218
# 2022-04-01 00:09:46.789630 436 transfers scraped in batch 219
# 2022-04-01 00:09:50.029428 463 transfers scraped in batch 220
# 2022-04-01 00:09:54.949512 465 transfers scraped in batch 221
# 2022-04-01 00:09:58.031353 436 transfers scraped in batch 222
# 2022-04-01 00:10:01.014871 358 transfers scraped in batch 223
# 2022-04-01 00:10:03.888001 350 transfers scraped in batch 224
# 2022-04-01 00:10:06.799002 381 transfers scraped in batch 225
# 2022-04-01 00:10:13.152498 366 transfers scraped in batch 226
# 2022-04-01 00:10:16.915164 338 transfers scraped in batch 227
# 2022-04-01 00:10:20.907769 413 transfers scraped in batch 228
# 2022-04-01 00:10:24.504493 346 transfers scraped in batch 229
# 2022-04-01 00:10:27.849629 369 transfers scraped in batch 230
# 2022-04-01 00:10:30.915068 346 transfers scraped in batch 231
# 2022-04-01 00:10:38.710832 409 transfers scraped in batch 232
# 2022-04-01 00:10:50.620487 405 transfers scraped in batch 233
# 2022-04-01 00:10:55.821202 432 transfers scraped in batch 234
# 2022-04-01 00:11:04.293336 436 transfers scraped in batch 235
# 2022-04-01 00:11:10.895217 452 transfers scraped in batch 236
# 2022-04-01 00:11:15.744598 396 transfers scraped in batch 237
# 2022-04-01 00:11:18.870057 421 transfers scraped in batch 238
# 2022-04-01 00:11:22.172921 394 transfers scraped in batch 239
# 2022-04-01 00:11:28.088605 404 transfers scraped in batch 240
# 2022-04-01 00:11:31.977495 383 transfers scraped in batch 241
# 2022-04-01 00:11:35.959381 465 transfers scraped in batch 242
# 2022-04-01 00:11:39.201702 452 transfers scraped in batch 243
# 2022-04-01 00:11:45.599358 485 transfers scraped in batch 244
# 2022-04-01 00:11:48.926132 445 transfers scraped in batch 245
# 2022-04-01 00:11:52.343085 399 transfers scraped in batch 246
# 2022-04-01 00:11:55.181787 361 transfers scraped in batch 247
# 2022-04-01 00:11:58.132834 344 transfers scraped in batch 248
# 2022-04-01 00:12:06.799455 379 transfers scraped in batch 249
# 2022-04-01 00:12:10.488521 413 transfers scraped in batch 250
# 2022-04-01 00:12:13.823860 409 transfers scraped in batch 251
# 2022-04-01 00:12:17.067713 413 transfers scraped in batch 252
# 2022-04-01 00:12:25.143538 362 transfers scraped in batch 253
# 2022-04-01 00:12:32.923692 324 transfers scraped in batch 254
# 2022-04-01 00:12:46.256107 401 transfers scraped in batch 255
# 2022-04-01 00:12:59.931319 394 transfers scraped in batch 256
# 2022-04-01 00:13:11.491779 398 transfers scraped in batch 257
# 2022-04-01 00:13:14.922900 373 transfers scraped in batch 258
# 2022-04-01 00:13:18.124301 362 transfers scraped in batch 259
# 2022-04-01 00:13:26.583627 375 transfers scraped in batch 260
# 2022-04-01 00:13:34.242514 381 transfers scraped in batch 261
# 2022-04-01 00:13:40.087637 409 transfers scraped in batch 262
# 2022-04-01 00:13:45.179129 376 transfers scraped in batch 263
# 2022-04-01 00:13:57.002585 369 transfers scraped in batch 264
# 2022-04-01 00:14:01.310097 413 transfers scraped in batch 265
# 2022-04-01 00:14:04.561372 417 transfers scraped in batch 266
# 2022-04-01 00:14:16.164400 328 transfers scraped in batch 267
# 2022-04-01 00:14:24.407187 362 transfers scraped in batch 268
# 2022-04-01 00:14:28.315523 494 transfers scraped in batch 269
# 2022-04-01 00:14:31.591220 417 transfers scraped in batch 270
# 2022-04-01 00:14:34.682222 363 transfers scraped in batch 271
# 2022-04-01 00:14:37.586836 353 transfers scraped in batch 272
# 2022-04-01 00:14:40.530200 375 transfers scraped in batch 273
# 2022-04-01 00:14:43.485519 367 transfers scraped in batch 274
# 2022-04-01 00:14:46.477655 380 transfers scraped in batch 275
# 2022-04-01 00:14:49.267723 297 transfers scraped in batch 276
# 2022-04-01 00:14:52.083483 339 transfers scraped in batch 277
# 2022-04-01 00:14:55.238186 416 transfers scraped in batch 278
# 2022-04-01 00:14:58.043838 370 transfers scraped in batch 279
# 2022-04-01 00:15:01.105047 359 transfers scraped in batch 280
# 2022-04-01 00:15:04.053729 336 transfers scraped in batch 281
# 2022-04-01 00:15:06.898254 286 transfers scraped in batch 282
# 2022-04-01 00:15:22.551269 416 transfers scraped in batch 283
# 2022-04-01 00:15:26.580476 334 transfers scraped in batch 284
# 2022-04-01 00:15:29.494980 387 transfers scraped in batch 285
# 2022-04-01 00:15:32.203725 358 transfers scraped in batch 286
# 2022-04-01 00:15:35.308581 405 transfers scraped in batch 287
# 2022-04-01 00:15:38.385814 406 transfers scraped in batch 288
# 2022-04-01 00:15:41.071985 331 transfers scraped in batch 289
# 2022-04-01 00:15:44.042059 428 transfers scraped in batch 290
# 2022-04-01 00:15:47.119393 427 transfers scraped in batch 291
# 2022-04-01 00:15:49.741364 258 transfers scraped in batch 292
# 2022-04-01 00:15:52.676544 269 transfers scraped in batch 293
# 2022-04-01 00:15:55.592260 286 transfers scraped in batch 294
# 2022-04-01 00:16:00.401853 272 transfers scraped in batch 295
# 2022-04-01 00:16:04.518931 293 transfers scraped in batch 296
# 2022-04-01 00:16:08.270579 292 transfers scraped in batch 297
# 2022-04-01 00:16:16.871593 268 transfers scraped in batch 298
# 2022-04-01 00:16:20.075616 272 transfers scraped in batch 299
# 2022-04-01 00:16:23.602202 270 transfers scraped in batch 300
# 2022-04-01 00:16:27.920807 275 transfers scraped in batch 301
# 2022-04-01 00:16:32.612427 261 transfers scraped in batch 302
# 2022-04-01 00:16:35.772787 270 transfers scraped in batch 303
# 2022-04-01 00:16:38.659039 268 transfers scraped in batch 304
# 2022-04-01 00:16:41.603918 300 transfers scraped in batch 305
# 2022-04-01 00:16:44.358624 273 transfers scraped in batch 306
# 2022-04-01 00:16:47.116117 288 transfers scraped in batch 307
# 2022-04-01 00:16:49.939574 284 transfers scraped in batch 308
# 2022-04-01 00:16:52.824721 281 transfers scraped in batch 309
# 2022-04-01 00:16:55.754341 291 transfers scraped in batch 310
# 2022-04-01 00:16:58.655067 276 transfers scraped in batch 311
# 2022-04-01 00:17:01.592106 268 transfers scraped in batch 312
# 2022-04-01 00:17:04.506355 264 transfers scraped in batch 313
# 2022-04-01 00:17:07.715611 284 transfers scraped in batch 314
# 2022-04-01 00:17:11.299061 276 transfers scraped in batch 315
# 2022-04-01 00:17:14.938302 268 transfers scraped in batch 316
# 2022-04-01 00:17:18.990058 290 transfers scraped in batch 317
# 2022-04-01 00:17:23.061034 260 transfers scraped in batch 318
# 2022-04-01 00:17:26.645537 280 transfers scraped in batch 319
# 2022-04-01 00:17:29.496873 284 transfers scraped in batch 320
# 2022-04-01 00:17:32.378225 273 transfers scraped in batch 321
# 2022-04-01 00:17:35.864746 268 transfers scraped in batch 322
# 2022-04-01 00:17:38.615650 276 transfers scraped in batch 323
# 2022-04-01 00:17:41.332271 296 transfers scraped in batch 324
# 2022-04-01 00:17:44.101944 300 transfers scraped in batch 325
# 2022-04-01 00:17:46.352281 222 transfers scraped in batch 326
# 2022-04-01 00:17:46.576313 126607 transfers retrieved
# 2022-04-01 00:17:47.363235 Deposit data size: 29406
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/t5/lm3g0brx0dsf0ymt1ldc8xdr0000gp/T/ipykernel_44369/576960363.py in <module>
#       6 x.parse_all()
#       7
# ----> 8 x.check_fidelity()
#
# /var/folders/t5/lm3g0brx0dsf0ymt1ldc8xdr0000gp/T/ipykernel_44369/1452721183.py in check_fidelity(self)
#     542         deposits_cxl = pd.read_csv(self.deposit_cxl_fname)
#     543
# --> 544         assert ix.loc[ix.instructionType == "Deposit"].shape[0] == deposits.shape[0]
#     545         assert ix.loc[ix.instructionType == "Withdraw"].shape[0] == withdrawals.shape[0]
#     546         assert (
#
# AssertionError:

# %%
        ix = pd.read_csv("friktion_ix.csv")
#         deposits = pd.read_csv("friktion_deposit.csv")
        withdrawals = pd.read_csv("friktion_withdraw.csv")
#         claim = pd.read_csv(self.withdraw_claim_fname)
#         withdrawals_cxl = pd.read_csv(self.withdraw_cxl_fname)
#         deposits_cxl = pd.read_csv(self.deposit_cxl_fname)
        
#         print(ix)
#         print(deposits)

#         assert ix.loc[ix.instructionType=="Deposit"].shape[0] == deposits.shape[0]
#         assert ix.loc[ix.instructionType=="Withdraw"].shape[0] == withdrawals.shape[0]
#         assert ix.loc[ix.instructionType=="ClaimPendingWithdrawal"].shape[0] == claim.shape[0]
#         assert ix.loc[ix.instructionType=="CancelPendingDeposit"].shape[0] == deposits_cxl.shape[0]
#         assert ix.loc[ix.instructionType=="CancelPendingWithdrawal"].shape[0] == withdrawals_cxl.shape[0]

# %%
withdrawals
# Out:
#                                             txSignature      amount  \
# 0     122tbxak1CeaRQSMZD2izGb9tXa7rSaRpyD2s3iSv4bKp3...    1.062448
# 1     122urr2mqKPc1rE9EqpqZnFXWPasm27yAcLmsQP7XM7iKL...   48.722463
# 2     123Av6p8VGMApaN16jk3dUUYEze1RLPohUUg1h51XjNt8P...    0.480814
# 3     124pSR5mQXtZAQ3vES5QTqkZzyBiyYphVhc3CHkswcibTm...  380.320000
# 4     1271nQpntCG8PBGdDaqkdnFaUTogSCNRpR7LfZroJebaFc...    0.097854
# ...                                                 ...         ...
# 8353  zm4RdaCHmTft8VqHo8NciMgpDy8ER3CB5MrNhT1jZ5yqrE...    7.353616
# 8354  zmt2MvkhKRvz6W1LCrDmieTtiCKwFTXH5U7n145oUAyWY8...    5.013809
# 8355  zs6aB3F4Fr1kXgrLqn1YhWYPACPY7Cqfbf5e5YV1p9MnqB...    0.116981
# 8356  zyDd5GUUF8MdRuAqzSFDGfDqVETL34wvarchy4QazBguFD...    4.893362
# 8357  zzhG42wpUtDCxrPSwgXYLqB6ejeCf1SdBKUNmmzwWH4FcK...    9.883034
#
#      instructionAction instructionOrder  \
# 0                 burn              1-1
# 1                 burn              1-0
# 2                 burn              1-1
# 3                 burn              0-1
# 4                 burn              3-1
# ...                ...              ...
# 8353              burn              3-1
# 8354              burn              0-1
# 8355              burn              0-0
# 8356              burn              0-1
# 8357              burn              1-1
#
#                                        userAddress             timestamp  \
# 0     GbYTQgbXndUJoczx23Hy3hobAReguEuddijnsRTkn8pJ  2022-01-09T10:12:13Z
# 1     A3PS3sjJmNbMt1XZXVB7s5WVPnjPfUVykxmV6kVHqCQ4  2022-03-13T12:34:28Z
# 2     5e8tCdqSvhNhFWpDsy2at7LwnZwbh2RHRVvrcsUgeymi  2022-02-03T11:14:07Z
# 3     75JCoqqnK9aHwhGSTrYacwDDPxaySZBHVwxQ9WAdmRic  2022-01-01T07:47:41Z
# 4     4gsxjXky9Wrf6QwMFqCBjwaxzHfHLKgSv4ruCi1KKTi9  2021-12-24T06:32:57Z
# ...                                            ...                   ...
# 8353  8tK1XWzBbHiFCmwTnApHPvR35FiseNcuDBVnR1sWUEVo  2022-03-26T00:05:46Z
# 8354   PGuNrjurtW9sXYBgUPqKv3DCkthxGXwxsngrjUeNCBP  2022-01-24T02:31:21Z
# 8355  7wBi3emvUbYrVHBSPKkQh4kGsv3C8cA5Y6FnnhxJLc4S  2022-01-08T03:42:44Z
# 8356  7B8Y5Vs89J4n6LxVAzBwNGo2gbxhkTdfauUHt2EHMLk8  2022-01-21T08:04:12Z
# 8357  F2X4t4fSSzhvaQxSF7J5PPoDFXBDWdexXyzDihN2YVFC  2022-02-26T16:52:46Z
#
#       currencyName                               currencyAddress  \
# 0              NaN  6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt
# 1              NaN  DPMCwE9z9jXaDVDti5aKhdgCWGgsvioz6ZvB9eZjH7UE
# 2              NaN   5VmdHqvRMbXivuC34w4Hux9zb1y9moiBEQmXDrTR1kV
# 3              NaN  DPMCwE9z9jXaDVDti5aKhdgCWGgsvioz6ZvB9eZjH7UE
# 4              NaN  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2
# ...            ...                                           ...
# 8353           NaN  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2
# 8354           NaN  6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt
# 8355           NaN  6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt
# 8356           NaN   5VmdHqvRMbXivuC34w4Hux9zb1y9moiBEQmXDrTR1kV
# 8357           NaN  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU
#
#                                      senderAddress  \
# 0     GbYTQgbXndUJoczx23Hy3hobAReguEuddijnsRTkn8pJ
# 1     A3PS3sjJmNbMt1XZXVB7s5WVPnjPfUVykxmV6kVHqCQ4
# 2     5e8tCdqSvhNhFWpDsy2at7LwnZwbh2RHRVvrcsUgeymi
# 3     75JCoqqnK9aHwhGSTrYacwDDPxaySZBHVwxQ9WAdmRic
# 4     4gsxjXky9Wrf6QwMFqCBjwaxzHfHLKgSv4ruCi1KKTi9
# ...                                            ...
# 8353  8tK1XWzBbHiFCmwTnApHPvR35FiseNcuDBVnR1sWUEVo
# 8354   PGuNrjurtW9sXYBgUPqKv3DCkthxGXwxsngrjUeNCBP
# 8355  7wBi3emvUbYrVHBSPKkQh4kGsv3C8cA5Y6FnnhxJLc4S
# 8356  7B8Y5Vs89J4n6LxVAzBwNGo2gbxhkTdfauUHt2EHMLk8
# 8357  F2X4t4fSSzhvaQxSF7J5PPoDFXBDWdexXyzDihN2YVFC
#
#                                    senderTokenMint  receiverAddress  \
# 0     2ALneL69HRuthso7f4inq75g8AYBTbKHKgFB2oBgE6mh              NaN
# 1     GM3NcpB3Gwb8CBVvGNy3Nz2bHCgmDojKdWFMBBLQVCiL              NaN
# 2     8o6bKeAW6eRQT3SGh8QMkeAvjCXgtQWLrBHJXkgf5r4G              NaN
# 3     DMxk7cTKY94j9ks84nBFb1d5H5RisWqcKheuVPzY1mHX              NaN
# 4     4iHN5DsCNRufQQo1npz4JQvJubG7vJxjLng9iJ4y4SvU              NaN
# ...                                            ...              ...
# 8353  Bd1Dsjy3EQshNio6dCnNgTePSrbzvjQWCm5vV2KP1EqU              NaN
# 8354  E3Sxf6eCKfji2E1eBgvqKPBrFwkcbwTrN7aTfSHi7Bjx              NaN
# 8355   yBG2jniegFHRgzgPjMVExgtakmm2kVRKBoLzn78vopn              NaN
# 8356  AHY2753bkoTefHZuS4buxf84QdWccUrJrD3std4FscRU              NaN
# 8357  5haireH8XkfqX5gzt9WyK7JPr3NW7ewusJQhcDybYCR4              NaN
#
#                           globalId  \
# 0     mainnet_income_call_marinade
# 1          mainnet_income_call_sbr
# 2       mainnet_income_call_socean
# 3          mainnet_income_call_sbr
# 4          mainnet_income_call_sol
# ...                            ...
# 8353       mainnet_income_call_sol
# 8354  mainnet_income_call_marinade
# 8355  mainnet_income_call_marinade
# 8356    mainnet_income_call_socean
# 8357        mainnet_income_put_sol
#
#                                     vaultAuthority  \
# 0     6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH
# 1     BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h
# 2     A5MpyajTy6hdsg3S2em5ukcgY1ZBhxTxEKv8BgHajv1A
# 3     BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h
# 4     Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# ...                                            ...
# 8353  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 8354  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH
# 8355  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH
# 8356  A5MpyajTy6hdsg3S2em5ukcgY1ZBhxTxEKv8BgHajv1A
# 8357  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
#
#                                     shareTokenMint depositTokenSymbol  \
# 0     6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt               mSOL
# 1     DPMCwE9z9jXaDVDti5aKhdgCWGgsvioz6ZvB9eZjH7UE                SBR
# 2      5VmdHqvRMbXivuC34w4Hux9zb1y9moiBEQmXDrTR1kV             scnSOL
# 3     DPMCwE9z9jXaDVDti5aKhdgCWGgsvioz6ZvB9eZjH7UE                SBR
# 4     4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# ...                                            ...                ...
# 8353  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 8354  6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt               mSOL
# 8355  6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt               mSOL
# 8356   5VmdHqvRMbXivuC34w4Hux9zb1y9moiBEQmXDrTR1kV             scnSOL
# 8357  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU               USDC
#
#      depositTokenCoingeckoId userAction
# 0                       msol   Withdraw
# 1                      saber   Withdraw
# 2          socean-staked-sol   Withdraw
# 3                      saber   Withdraw
# 4                     solana   Withdraw
# ...                      ...        ...
# 8353                  solana   Withdraw
# 8354                    msol   Withdraw
# 8355                    msol   Withdraw
# 8356       socean-staked-sol   Withdraw
# 8357                usd-coin   Withdraw
#
# [8358 rows x 17 columns]

# %%
deposits.shape

# %%
ix.loc[ix.instructionType=="Deposit"].shape
# Out:
# (29408, 5)

# %%
deposits.sort_values("amount")[::-1]
# Out:
#                                              txSignature        amount  \
# 7486   3FvYTiomvJTpAjs5XxGc81egpWzebGXA4sSs7VMvWB6c9G...  4.879066e+06
# 11664  3zZ8TKn9gYpFhrqcx8W2HTJikwHSTZLG3GyiqbM12BWPQY...  2.998353e+06
# 19671  5M3H96K3RJghDp5R3SdJsCyeCnRYypTXtL5PvzE6W8wS82...  2.943753e+06
# 1691   2GR1JARZMSRP9wEtvVg5D1tbMptBayGuhCt6BuHjevvztx...  2.904146e+06
# 25363  JBK4C7XkJKknRMD9NTmiengbiBn9rwNTdFd8MUDvbvsSHa...  2.630611e+06
# ...                                                  ...           ...
# 15554  4eVtsrbxsB5yKwANXpWQU5kH5Qc3HAD37ak8L9uzk5GEeU...  1.000000e-09
# 12164  45X8ZKAUZUPZBVorVhavjAgncR2KXynevXNB9sRkAwbSQH...  1.000000e-09
# 16534  4pSgwJkyp6PuitQMC5UiKoJiV1bmUUk9E7VzE73Ds9XMqb...  1.000000e-09
# 2386   2PXZks2t4YUZWQuDc6MNo1nLre5SgMWhumRvGx4jqemQSS...  1.000000e-09
# 3583   2bYFAv2MMyQXzxth6cZpnpj6AFeLyXz2EoizcCvwXvVPF1...  1.000000e-09
#
#       instructionAction instructionOrder  \
# 7486           transfer              1-1
# 11664          transfer              1-1
# 19671          transfer              1-1
# 1691           transfer              0-0
# 25363          transfer              1-1
# ...                 ...              ...
# 15554          transfer            0-0-0
# 12164          transfer              1-1
# 16534          transfer              1-1
# 2386           transfer              0-0
# 3583           transfer              1-1
#
#                                         userAddress             timestamp  \
# 7486   7xTjub4EpTLx7QLHdeJKNQsuVYkqaiGbBd4DJRYjKAYZ  2022-01-13T17:40:28Z
# 11664  CHbwVQQvMvhGxLPBkaL6SZuJ8f895bGHZ5BsLXbaJL3N  2022-02-05T01:47:19Z
# 19671  GmRC6EhKtBEcKM1bjCBzamWDy3qmP5z2Kc9tYjQuc2Pn  2021-12-30T10:31:36Z
# 1691   3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs  2022-03-07T10:10:46Z
# 25363  3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs  2022-03-28T21:44:12Z
# ...                                             ...                   ...
# 15554  GgF8AhcdiJ4hhyFaMoJ3XpQo9q7NgFnNaMQ6x6Xj3Lvt  2021-12-27T02:05:05Z
# 12164  J1sFjvcmhAxiYS5oerp167VDCu1u76csG5bXkkgijVJn  2022-01-24T23:48:03Z
# 16534  GFZpgo47bsmPzLentNshwHnapbryMiu1hfisng7DBbDm  2022-03-30T09:39:59Z
# 2386   5cvX5RGXCbX12Rso1UCTFFDdzgN9W7jMTHCDzKAthmuo  2022-01-26T21:29:48Z
# 3583   FxZMeiQchnuppwe9SeyNYxkVchkpUjnnJsJM9DP3d78U  2022-03-30T09:29:45Z
#
#                      currencyName  \
# 7486         Saber Protocol Token
# 11664                         NaN
# 19671        Saber Protocol Token
# 1691                     USD Coin
# 25363                    USD Coin
# ...                           ...
# 15554  Marinade staked SOL (mSOL)
# 12164  Marinade staked SOL (mSOL)
# 16534  Marinade staked SOL (mSOL)
# 2386   Marinade staked SOL (mSOL)
# 3583   Marinade staked SOL (mSOL)
#
#                                     currencyAddress  \
# 7486    Saber2gLauYim4Mvftnrasomsv6NvAuncvMEZwcLpD1
# 11664  Cvvh8nsKZet59nsDDo3orMa3rZnPWQhpgrMCVcRDRgip
# 19671   Saber2gLauYim4Mvftnrasomsv6NvAuncvMEZwcLpD1
# 1691   EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 25363  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# ...                                             ...
# 15554   mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 12164   mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 16534   mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 2386    mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 3583    mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
#
#                                       senderAddress  \
# 7486   7xTjub4EpTLx7QLHdeJKNQsuVYkqaiGbBd4DJRYjKAYZ
# 11664  CHbwVQQvMvhGxLPBkaL6SZuJ8f895bGHZ5BsLXbaJL3N
# 19671  GmRC6EhKtBEcKM1bjCBzamWDy3qmP5z2Kc9tYjQuc2Pn
# 1691   3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs
# 25363  3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs
# ...                                             ...
# 15554  6qfyGvoUqGB6AQ7xLc4pVwFNdgJSbAMkTtKkBXhLRiV1
# 12164  J1sFjvcmhAxiYS5oerp167VDCu1u76csG5bXkkgijVJn
# 16534  GFZpgo47bsmPzLentNshwHnapbryMiu1hfisng7DBbDm
# 2386   5cvX5RGXCbX12Rso1UCTFFDdzgN9W7jMTHCDzKAthmuo
# 3583   FxZMeiQchnuppwe9SeyNYxkVchkpUjnnJsJM9DP3d78U
#
#                                     senderTokenMint  \
# 7486   3JEfWY4V6sQBQXsbXeWkDVA5pqPisudwhxRbWWd76rt9
# 11664  424dm7Lauis6QRBreU9nt8yvwe1FZqUtp6oiEAzMcttQ
# 19671  FLEiW8R1qj2XnZ5vuJskFZ1X7umntUJV2DAgFRckcfv5
# 1691   8LrqyZvCsyBVFXDU9YbVAj6ukJ9tSKeXTmXNHWfZkGRF
# 25363  8LrqyZvCsyBVFXDU9YbVAj6ukJ9tSKeXTmXNHWfZkGRF
# ...                                             ...
# 15554  5Vfn9EmBYkxDFASQKLEZqDuDCT2G2tbmNrizisa4m4uL
# 12164  EqXN26d6mKUKPXrziWxaHxF7wsDzt95vWPnFkFMe7Nok
# 16534  5BMHymXSNFgyoGYzxx6b9yGTTq4zRwXzCkrwu2SUFs2n
# 2386   EFHB1NyzjTQW7hmAorGzHBoUqdVZDsGQ4jDVyPMXTvjn
# 3583   ExAoBt7qQuc7G7sX65AA7nmxfTw4ZemWMFzJdvzz1Dmc
#
#                                     receiverAddress globalId vaultAuthority  \
# 7486   BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h      NaN            NaN
# 11664  AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8      NaN            NaN
# 19671  BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h      NaN            NaN
# 1691   BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ      NaN            NaN
# 25363  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY      NaN            NaN
# ...                                             ...      ...            ...
# 15554  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 12164  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 16534  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 2386   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 3583   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
#
#       shareTokenMint depositTokenSymbol depositTokenCoingeckoId userAction
# 7486             NaN                NaN                     NaN    Deposit
# 11664            NaN                NaN                     NaN    Deposit
# 19671            NaN                NaN                     NaN    Deposit
# 1691             NaN                NaN                     NaN    Deposit
# 25363            NaN                NaN                     NaN    Deposit
# ...              ...                ...                     ...        ...
# 15554            NaN                NaN                     NaN    Deposit
# 12164            NaN                NaN                     NaN    Deposit
# 16534            NaN                NaN                     NaN    Deposit
# 2386             NaN                NaN                     NaN    Deposit
# 3583             NaN                NaN                     NaN    Deposit
#
# [29406 rows x 17 columns]

# %%
pd.options.display.width = 0

# %%
deposits.loc[
    deposits.vaultAuthority=="Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G"].sort_values("amount")[["timestamp", "amount", "txSignature"]]
# Out:
#                  timestamp        amount  \
# 7978  2022-02-25T19:56:08Z  1.000000e-09
# 5862  2022-02-12T02:52:57Z  1.000000e-09
# 479   2022-02-03T21:05:08Z  1.000000e-09
# 4532  2022-03-18T14:21:43Z  1.000000e-09
# 5087  2022-01-07T15:34:27Z  1.000000e-09
# ...                    ...           ...
# 2415  2022-01-12T08:06:22Z  3.638800e+03
# 4309  2022-03-30T16:18:44Z  8.230664e+03
# 4799  2022-02-01T16:45:17Z  8.586272e+03
# 2362  2022-02-17T09:13:40Z  1.168541e+04
# 5075  2022-01-21T14:59:41Z  1.581595e+04
#
#                                             txSignature
# 7978  mQPf6mdLdSpCtnmvPkKarwhMykNNp5FEzKg6yzvJbo12yG...
# 5862  5VtrMPM6nGsWSzeWrFQ4dQFnHyixUMmK4GXF5wzyRsYp2L...
# 479   2H4hQFTSkvWJUTr3t5f9i8hFDG1XW7Rak31WoiDLqf733t...
# 4532  4h55mB7Hwosedtx3kttVfbLmAGdKoHkKRoSY7fhBoufYVU...
# 5087  52jsKGk4ryoqbQCiNnZg1TcDJ81RHxq5PrptiunnjW3TJb...
# ...                                                 ...
# 2415  3Rkt6Z9QHzxxrP6FhVoLA4jkcKCXJPjASDsjeUHmbbBsUd...
# 4309  4a2KegHZpt2Mfp45FjcbFUVV1HsMHSHzyN6kfML9mJ8qrN...
# 4799  4rbL6s8PcsHaPBBM5Sf1mgGBkQHUvVo8zxa5VhP92oU2oN...
# 2362  3PezBkLDECULRfmgLNz92qZewjzC6oAbr7xAbstGTuV1CN...
# 5075  529CebmeMLq6PLXNyNW4WTTNuEVKGoyNsUcGyQb1VVMvjc...
#
# [2680 rows x 3 columns]

# %%
deposits.loc[
    deposits.vaultAuthority=="Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G"].sort_values("amount")[["timestamp", "amount", "txSignature"]][::-1].iloc[3]["txSignature"]
# Out:
# '4a2KegHZpt2Mfp45FjcbFUVV1HsMHSHzyN6kfML9mJ8qrN4iQKGUWPXBetXMrGKDRtu8JuhZPC4ttBZqaiAtL3dD'

# %%
depsots

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId', 'userAction'],
#       dtype='object')

# %%
deposits

# %%
# Have Price
# Have VoltTokenShare

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId'],
#       dtype='object')

# %%
deposits.shape
# Out:
# (115, 16)

# %%
deposits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   txSignature              115 non-null    object
#  1   amount                   115 non-null    float64
#  2   instructionAction        115 non-null    object
#  3   instructionOrder         115 non-null    object
#  4   userAddress              115 non-null    object
#  5   timestamp                115 non-null    object
#  6   currencyName             115 non-null    object
#  7   currencyAddress          115 non-null    object
#  8   senderAddress            115 non-null    object
#  9   senderTokenMint          115 non-null    object
#  10  receiverAddress          115 non-null    object
#  11  globalId                 115 non-null    object
#  12  vaultAuthority           115 non-null    object
#  13  shareTokenMint           115 non-null    object
#  14  depositTokenSymbol       115 non-null    object
#  15  depositTokenCoingeckoId  115 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 14.5+ KB

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId'],
#       dtype='object')

# %%
deposits.iloc[0]
# Out:
# txSignature                122tbxak1CeaRQSMZD2izGb9tXa7rSaRpyD2s3iSv4bKp3...
# amount                                                              1.062448
# instructionAction                                                       burn
# instructionOrder                                                         1-1
# userAddress                     GbYTQgbXndUJoczx23Hy3hobAReguEuddijnsRTkn8pJ
# timestamp                                               2022-01-09T10:12:13Z
# currencyName                                                             NaN
# currencyAddress                 6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt
# senderAddress                   GbYTQgbXndUJoczx23Hy3hobAReguEuddijnsRTkn8pJ
# senderTokenMint                 2ALneL69HRuthso7f4inq75g8AYBTbKHKgFB2oBgE6mh
# receiverAddress                                                          NaN
# globalId                                                                 NaN
# vaultAuthority                                                           NaN
# shareTokenMint                                                           NaN
# depositTokenSymbol                                                       NaN
# depositTokenCoingeckoId                                                  NaN
# userAction                                                          Withdraw
# Name: 0, dtype: object

# %%
deposits.loc[deposits.depositTokenCoingeckoId.isna()].currencyAddress
# Out:
# Series([], Name: currencyAddress, dtype: object)

# %%
deposits.shape
# Out:
# (115, 16)

# %%
deposits.loc[deposits.txSignature=="24y4KRma4BUarjw4y8Rv9Dt1kZdVVSP5kVnkbu4Ra5KMs7G9Df2Vb9C1b3M8f6yCuNuhsEW9s1WR8WrSKuN5bVBX"].iloc[0]
# Out:
# txSignature                24y4KRma4BUarjw4y8Rv9Dt1kZdVVSP5kVnkbu4Ra5KMs7...
# amount                                                                 551.0
# instructionAction                                                   transfer
# instructionOrder                                                         3-1
# userAddress                     9T19SkKUpSNbt2cMcCQVz7NZEfmXW3gdMDkH9db1yidw
# timestamp                                               2022-03-17T18:39:38Z
# currencyName                                                     Wrapped SOL
# currencyAddress                  So11111111111111111111111111111111111111112
# senderAddress                   9T19SkKUpSNbt2cMcCQVz7NZEfmXW3gdMDkH9db1yidw
# senderTokenMint                 D9QnLjbjTEBCqFZUrovoFkNW3B8gLmsJkT6PDt4HUv1H
# receiverAddress                  wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# globalId                                        mainnet_income_call_sol_high
# vaultAuthority                   wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# shareTokenMint                  DNa849drqW19uBV5X9ohpJ5brRGzq856gk3HDRqveFrA
# depositTokenSymbol                                                       SOL
# depositTokenCoingeckoId                                               solana
# Name: 2, dtype: object

# %%
deposits.loc[deposits.txSignature=="1kx6PYTANDwsAZGZ5xoRNe51uRK68k6roF6KYDauHQMmemH4JunDBCA47oHT2J1QUbh5YJHFdoZtQECqUVLVbZp"].iloc[0]
# Out:
# txSignature                1kx6PYTANDwsAZGZ5xoRNe51uRK68k6roF6KYDauHQMmem...
# amount                                                               0.99859
# instructionAction                                                   transfer
# instructionOrder                                                         1-1
# userAddress                     79jbRVMQu5rQkEcAPbzZNqnwKEASHyEyWgUn9q76yUKT
# timestamp                                               2022-03-17T19:33:26Z
# currencyName                                       Wrapped Ethereum (Sollet)
# currencyAddress                 2FPyTwcZLUg1MDrwsyoP4D6s1tM7hAkHYRjkNb5w6Pxk
# senderAddress                   79jbRVMQu5rQkEcAPbzZNqnwKEASHyEyWgUn9q76yUKT
# senderTokenMint                 3e81Tr2AGVLwPLLsUwiBSaYdGDwSxCMXmhF5ZWUuQAsn
# receiverAddress                 FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# globalId                                             mainnet_income_call_eth
# vaultAuthority                  FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# shareTokenMint                  GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS
# depositTokenSymbol                                                       ETH
# depositTokenCoingeckoId                                             ethereum
# Name: 0, dtype: object

# %%
zz = pd.DataFrame(
                dict(
                    json.loads(
                        requests.get(
                            "https://friktion-labs.github.io/mainnet-tvl-snapshots/friktionSnapshot.json"
                        ).content
                    )
                )["allMainnetVolts"]
            )

# %%
zz
# Out:
#                                   globalId  \
# 0                  mainnet_income_call_btc
# 1                  mainnet_income_call_sol
# 2             mainnet_income_call_sol_high
# 3             mainnet_income_call_marinade
# 4                  mainnet_income_call_eth
# 5                  mainnet_income_call_ftt
# 6                  mainnet_income_call_srm
# 7                 mainnet_income_call_mngo
# 8               mainnet_income_call_socean
# 9                  mainnet_income_call_sbr
# 10                mainnet_income_call_luna
# 11                 mainnet_income_call_ray
# 12                mainnet_income_call_step
# 13               mainnet_income_call_stsol
# 14                mainnet_income_call_avax
# 15                 mainnet_income_put_luna
# 16                  mainnet_income_put_sol
# 17             mainnet_income_put_sol_high
# 18                 mainnet_income_put_mngo
# 19                  mainnet_income_put_btc
# 20               mainnet_income_put_tsUSDC
# 21                  mainnet_income_put_eth
# 22    mainnet_income_put_sol_step_circuits
# 23  mainnet_income_put_sol_parrot_circuits
# 24  mainnet_income_put_eth_parrot_circuits
# 25    mainnet_income_put_btc_step_circuits
# 26     mainnet_income_put_sol_uxd_circuits
#
#                                   vaultAuthority  \
# 0   DA1M8mw7GnPNKU9ReANtHPQyuVzKZtsuuSbCyc2uX2du
# 1   Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 2    wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# 3   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH
# 4   FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# 5   7KqHFuUksvNhrWgoacKkqyp2RwfBNdypCYgK9nxD1d6K
# 6   2P427N5sYcEXvZAZwqNzjXEHsBMESQoLyjNquTSmGPMb
# 7   B3yakZxwomkmnCxRr8ZmQtiWgtxtVBuCREDFDdAvcCVQ
# 8   A5MpyajTy6hdsg3S2em5ukcgY1ZBhxTxEKv8BgHajv1A
# 9   BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h
# 10  5oV1Yf8q1oQgPYuHjepjmKFuaG2Wng9dzTqbSWhU5W2X
# 11  A6XsYxGj9wpqUZG81XwgQJ2zJ3efCbuWSQfnkHqUSmdM
# 12  FiEHDTKT6X7VFwGaUmsm1XXYr8vvkoSR5EqcY4znpefq
# 13  2Ahpeqc1bo7Y4dVknvZUVfZPhHhym7JN6az2XMbUA6QA
# 14  5LrULR5w9N1dfnJ9vHnzRkQi9uBL3CkSRWkDGTG6dP1e
# 15  5kA7FPiB3t2X5s65dK1AoEu5asDjC5d7f5vaB4iY2yrj
# 16  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
# 17  BThMeTgWZBoBbAzp9sK9T7gQzpQDQdRQUVLtVQ3781q1
# 18  CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# 19  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 20  AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8
# 21  EA29Xf3HGMtYziw7UKZDUKby7gkoCbXwmiNKwc7z54Ax
# 22  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 23  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
# 24  EfxrH3pwGBuRJgbbA9x5skFamLVXUhDnA7DukZmDsjaL
# 25  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY
# 26  HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
#
#                                   shareTokenMint depositTokenSymbol  \
# 0   3BjcHXvyzMsjmeqE2qFLx45K4XFx3JPiyRnjJiF5MAHt                BTC
# 1   4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 2   DNa849drqW19uBV5X9ohpJ5brRGzq856gk3HDRqveFrA                SOL
# 3   6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt               mSOL
# 4   GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS                ETH
# 5   7wDh4VCTPwx41kvbLE6fkFgMEjnqw7NpGJvQtNabCm2B                FTT
# 6   5SLqZSywodLS8ih6U2AAioZrxpgR149hR8SApmCB7r5X                SRM
# 7   4sTuzTYfcE2NF7zy6Sy8XhVcNLa6JQSLrx3roy97n4sD               MNGO
# 8    5VmdHqvRMbXivuC34w4Hux9zb1y9moiBEQmXDrTR1kV             scnSOL
# 9   DPMCwE9z9jXaDVDti5aKhdgCWGgsvioz6ZvB9eZjH7UE                SBR
# 10  95sn4kgeJnnBfRCD8S2quu4HS9Y6vb7JDuXrarnmEjYE               LUNA
# 11   SoAnGsHVqSyaN4MjWoPCcftC1V6oSeNxLJjF5TXrtuL                RAY
# 12  AQFLXqLLofcbUCoi5HPfuuvX6vMPafubZfBNBMumnKq2               STEP
# 13  EPoDdEcDQ478YNRAiMYMHLs7mEnmo5z9322Q2D5exKFU              stSOL
# 14  HLfkEc6E2HEcABaWm3QZSfDvswzXjh1onF9xEzUAtWNS               AVAX
# 15  74ozhToAS71nDVBtFZMMucdkNB95tV2o5fhtFGQeixwS                UST
# 16  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU               USDC
# 17  G8jsAWUA2KdDn7XmV1sBqUdbEXESaPdjPWDEYCsnkRX2               USDC
# 18  CxHG1tPkeEHsAVmPF2UrjZK3W719J5DGFgMaLtUkBoeP               USDC
# 19   THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC               USDC
# 20  Fw8mw9zNyfngvBYuS2L6XWfvFE8fExQ3apZVw4Ery5oy             tsUSDC
# 21  2uTkms42P62dJ7JRaefc1HFkvyBeMP28J6MPmH1gVHoT               USDC
# 22   Bikt7D3nMQmJSpxX7oczCDKgevrpWk3g4D3VhQZzqAT               USDC
# 23  J1TX6c1R6WykW2wonvrL6xA2g8vZ2FLDqDDF1mLYrMYK               USDC
# 24  5VF9CTD9GNNDSrfQ1ZswfMdCc2NkbH2hvTirSb1FMEo3               USDC
# 25  ET4nQ6we7KDemfzni8dy2EkNCuYo1RryiRPjC6XwnnC3               USDC
# 26  BAyzqZuKUQ4k93Yfm3xp85SkAKtr4xghBsqZLBTZT14z               USDC
#
#    depositTokenCoingeckoId
# 0                  bitcoin
# 1                   solana
# 2                   solana
# 3                     msol
# 4                 ethereum
# 5                ftx-token
# 6                    serum
# 7            mango-markets
# 8        socean-staked-sol
# 9                    saber
# 10              terra-luna
# 11                 raydium
# 12            step-finance
# 13         lido-staked-sol
# 14             avalanche-2
# 15                terrausd
# 16                usd-coin
# 17                usd-coin
# 18                usd-coin
# 19                usd-coin
# 20                usd-coin
# 21                usd-coin
# 22                usd-coin
# 23                usd-coin
# 24                usd-coin
# 25                usd-coin
# 26                usd-coin
