# %%
"""
Python script to scrape Friktion User Data from Bitquery GraphQL API.

"""

import json
import requests
import requests
import traceback
import time

import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from os.path import exists


class MyPortfolio:
    """
    Python ETL script for Friktion user portfolio data. Currently supported Instruction Names:
        - Deposit
        - CancelPendingDeposit
        - Withdrawal
        - CancelPendingWithdrawal
        - ClaimPendingWithdrawal
    """

    def __init__(
        self,
        date_start,
        date_end,
        ix_fname="./friktion_ix.csv",
        deposit_fname="./friktion_deposit.csv",
        deposit_cxl_fname="./friktion_deposit_cxl.csv",
        withdraw_fname="./friktion_withdraw.csv",
        withdraw_cxl_fname="./friktion_withdraw_cancel.csv",
        withdraw_claim_fname="./friktion_claim_withdrawal.csv",
        batch_size_days=2,
        batch_size_xfers=90,
        skip_ix_scrape=False
    ):
        """
        :ix_fname:              output csv for instructions
        :deposit_fname:         output csv for deposits
        :deposit_cxl_fname:     output csv for deposit cancels
        :withdraw_fname:        output csv for withdrawals
        :withdraw_cxl_fname:    output csv for withdrawal cancels
        :withdraw_claim_fname:  output csv for claiming pending withdrawal
        :batch_size_days:       batch size in days for query to keep query < 10k symbols. Use bigger steps for larger data.
        :batch_size_transfers:  batch size transactions for query to keep query < 8kb

        """
        self.volt_program = "VoLT1mJz1sbnxwq5Fv2SXjdVDgPXrb9tJyC8WpMDkSp"
        self.date_start = date_start
        self.date_end = date_end
        self.ix_fname = ix_fname
        self.deposit_fname = deposit_fname
        self.deposit_cxl_fname = deposit_cxl_fname
        self.withdraw_fname = withdraw_fname
        self.withdraw_cxl_fname = withdraw_cxl_fname
        self.withdraw_claim_fname = withdraw_claim_fname
        self.batch_size_days = batch_size_days
        self.batch_size_xfers = batch_size_xfers
        self.skip_ix_scrape = skip_ix_scrape
        
        self.df_ix = pd.read_csv(ix_fname) if skip_ix_scrape else [] 
        self.friktion_metadata = self.get_friktion_snapshot()

    ########################################################################################################
    ####################################          Queries             ######################################
    ########################################################################################################

    @property
    def ix_query(self):
        return """
            query MyQuery {
              solana {
                instructions(
                  time: {between: ["%s", "%s"]}
                  success: {is: true}
                  programId: {is: "VoLT1mJz1sbnxwq5Fv2SXjdVDgPXrb9tJyC8WpMDkSp"}
                  options: {limit: 8700}
                ) {
                  block {
                    timestamp {
                      iso8601
                    }
                  }
                  transaction {
                    signature
                    feePayer
                  }
                  data {
                    base58
                  }
                }
              }
            }
        """

    @property
    def xfer_query(self):
        return """
            query MyQuery {
              solana(network: solana) {
                transfers(
                  signature: {in: [%s]}
                ) {
                  instruction {
                    action {
                      name
                    }
                    callPath
                  }
                  amount(success: {is: true})
                  transaction {
                    signer
                    signature
                  }
                  block {
                    timestamp {
                      iso8601
                    }
                  }
                  currency {
                    name
                    address
                  }
                  sender {
                    address
                    mintAccount
                  }
                  receiver {
                    address
                  }
                }
              }
            }
        """

    ########################################################################################################
    ################################          Helper Functions             #################################
    ########################################################################################################

    # TODO: Add retry logic to this in case of hangups.
    @staticmethod
    def run_query(query, retries=10):
        """
        Query graphQL API.

        If timeerror
        """
        headers = {"X-API-KEY": "BQYCaXaMZlqZrPCSQVsiJrKtxKRVcSe4"}

        retries_counter = 0
        try:
            request = requests.post(
                "https://graphql.bitquery.io/", json={"query": query}, headers=headers
            )
            result = request.json()
            # print(dir(request.content))
            # Make sure that there is no error message
            # assert not request.content.errors
            assert "errors" not in result
        except:
            while (
                (request.status_code != 200
                or "errors" in result)
                and retries_counter < 10
            ):
                print(datetime.now(), f"Retry number {retries_counter}")
                if "errors" in result:
                    print(result["errors"])
                print(datetime.now(), f"Query failed for reason: {request.reason}. sleeping for {60*retries_counter} seconds and retrying...")
                time.sleep(120*retries_counter)
                request = requests.post(
                    "https://graphql.bitquery.io/",
                    json={"query": query},
                    headers=headers,
                )
                retries_counter += 1
            if retries_counter >= retries:
                raise Exception(
                    "Query failed after {} retries and return code is {}.{}".format(
                        retries_counter, request.status_code, query
                    )
                )
        return request.json()


    @staticmethod
    def batch_iterable(iterable, n=1):
        """
        Takes in an iterable and returns an iterable of iterables with len==x
        """
        idxs = []
        l = len(iterable)
        for idx in range(0, l, n):
            idxs.append(iterable[idx : min(idx + n, l)])
        return idxs

    def format_txs_for_query(self, tx_signatures):
        """
        Batches a list of transactions into a list of string formatted transactions for querying.
        Each of these strings contain (n=self.batch_size_xfers) unique transaction IDs.
        """
        batched_signatures = self.batch_iterable(tx_signatures, self.batch_size_xfers)

        def format_txs(x):
            return str(x)[1:-1].replace("'", '"').replace("\n", "")

        tx_strs = list(map(format_txs, batched_signatures))

        return tx_strs

    def get_existing_df(self, fname):
        """
        Create output file if doesn't exist and returns a DataFrame
        """
        if fname and exists(fname):
            return pd.read_csv(fname)
        else:
            return pd.DataFrame()

    @staticmethod
    def instruction_match(instructionData):
        """
        Match 8-bit instruction identifier with the corresonding instructionType
        """
        if not instructionData or len(instructionData) < 8:
            return False

        instructionDescriptor = instructionData[:8]

        if instructionDescriptor == "PcB3tF1K":
            return "Withdraw"
        elif instructionDescriptor == "WuE7Hjns":
            return "Deposit"
        elif instructionDescriptor == "V8cW2nMq":
            return "CancelPendingDeposit"
        elif instructionDescriptor == "dxUbSCWk":
            return "CancelPendingWithdrawal"
        elif instructionDescriptor == "WcTWQsnk":
            return "ClaimPendingWithdrawal"
        else:
            return "Unclassified"

    def get_friktion_snapshot(self):
        """
        Load Friktion Metadata for Volt/Symbol Mapping to join to normal data

        """
        try:
            return pd.DataFrame(
                dict(
                    json.loads(
                        requests.get(
                            "https://friktion-labs.github.io/mainnet-tvl-snapshots/friktionSnapshot.json"
                        ).content
                    )
                )["allMainnetVolts"]
            )[
                [
                    "globalId",
                    "vaultAuthority",
                    "shareTokenMint",
                    "depositTokenSymbol",
                    "depositTokenCoingeckoId",
                ]
            ]
        except Exception as e:
            print(datetime.now(), "Snapshot Data Invalid")
            traceback.print_exc()

    ########################################################################################################
    ################################          Data Retrieval             ###################################
    ########################################################################################################

    def get_ix(self, date_start, date_end):
        """
        Runs graphql instruction query for one date range.
        """
        print(date_start, date_end)
        query = self.ix_query % (date_start, date_end)
        print(
            datetime.now(),
            "retrieving instructions for {} to {}".format(date_start, date_end),
        )
        result = self.run_query(query)

        # convert GraphQL json to pandas dataframe
        try:
            df = pd.json_normalize(result["data"]["solana"]["instructions"])
        except:
            print(result)
            traceback.print_exc()
            raise Exception(datetime.now(), "Empty Results... Try Again")

        print(datetime.now(), df.shape[0], "instructions retrieved")

        df = df.rename(
            columns={
                "block.timestamp.iso8601": "timestamp",
                "log.consumed": "computeUnits",
                "transaction.signature": "txSignature",
                "transaction.feePayer": "txSigner",
                "data.base58": "instructionData",
            }
        )
        return df

    def get_ix_batch(self):
        """
        Batch the instruction retrieval. Save the shit Drop duplicates.

        """
        # Batch the days up nice and good so the graphql API calls don't bitch
        dates_batched = pd.date_range(self.date_start, self.date_end, freq=f"{self.batch_size_days}D")
        dates_batched = [
            str(x.isoformat())
            for x in dates_batched.append(pd.DatetimeIndex([self.date_end]))
        ]
        date_ranges = list(zip(dates_batched, dates_batched[1:]))
        ixs = []
        for date_range in date_ranges:
            assert len(date_range) == 2
            data = self.get_ix(date_range[0], date_range[1])
            ixs.append(data)

        df_ix = pd.concat(ixs, ignore_index=False)
        df_ix["instructionType"] = df_ix.instructionData.apply(
            lambda x: self.instruction_match(x)
        )

        # Store df_ix before we write it to the DataFrame so we avoid getting xfers for every single ix
        self.df_ix = df_ix.drop_duplicates(["txSignature", "instructionType"])
        print(datetime.now(), "final instruction data size: ", df_ix.shape[0])

        # Save new data to file
        df_old = self.get_existing_df(self.ix_fname)
        df = df_ix.append(df_old).reset_index(drop=True)
        df = df.drop_duplicates(["txSignature", "instructionType"])
        df.to_csv(self.ix_fname, index=False)
        print(datetime.now(), "wrote instruction data to csv...")

    def get_batched_xfers(self, instructionType, fname):
        """
        Get all transfers corresponding to a specific instructionType from Graphql query.
        Batch these queries up b/c the string size is
        too large (curse GraphQL for not supporting joins)

        :instructionType: String corresponding to the instruction type of each query.
        :fname: Name of where the old df is stored

        """

        temp = self.df_ix.query(f"instructionType == '{instructionType}'")

        if temp.empty:
            print(
                datetime.now(), "instructionType was not found in the data... breaking"
            )
            return

        tx_signatures = list(temp["txSignature"].unique())
        tx_strs = self.format_txs_for_query(tx_signatures)
        print(datetime.now(), len(tx_strs), "signature batches required...")
        xfers = []

        for i, tx_str in enumerate(tx_strs):
            query = self.xfer_query % (tx_str)
            result = self.run_query(query)
            # TODO: Clean up this duplicated logic
            try:
                df = pd.json_normalize(result["data"]["solana"]["transfers"])
            except:
                print(result)
                traceback.print_exc()
                raise Exception("Empty Results... Try Again")
            xfers.append(df)
            print(datetime.now(), df.shape[0], "transfers scraped in batch %d" % i)

        df_xfer = pd.concat(xfers, ignore_index=False)
        df_xfer = df_xfer.rename(
            columns={
                "block.timestamp.iso8601": "timestamp",
                "instruction.action.name": "instructionAction",
                "instruction.callPath": "instructionOrder",
                "transaction.signer": "userAddress",
                "transaction.signature": "txSignature",
                "currency.name": "currencyName",
                "receiver.address": "receiverAddress",
                "sender.address": "senderAddress",
                "currency.decimals": "currencyDecimals",
                "currency.address": "currencyAddress",
                "sender.mintAccount": "senderTokenMint",
            }
        )

        print(datetime.now(), df_xfer.shape[0], "transfers retrieved")

        df_old = self.get_existing_df(fname)
        df_final = df_old.append(df_xfer, ignore_index=True).sort_values(
            "instructionOrder"
        )

        return df_final

    def parse_deposits(self):
        instructionType = "Deposit"
        instructionAction = "transfer"
        tx_merge_key = "receiverAddress"
        meta_merge_key = "vaultAuthority"
        out_file = self.deposit_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_withdrawal(self):
        instructionType = "Withdraw"
        instructionAction = "burn"
        tx_merge_key = "currencyAddress"
        meta_merge_key = "shareTokenMint"
        out_file = self.withdraw_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_deposit_cancel(self):
        instructionType = "CancelPendingDeposit"
        instructionAction = "transfer"
        tx_merge_key = "senderAddress"
        meta_merge_key = "vaultAuthority"
        out_file = self.deposit_cxl_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_withdrawal_cancel(self):
        instructionType = "CancelPendingWithdrawal"
        instructionAction = "mintTo"
        tx_merge_key = "currencyAddress"
        meta_merge_key = "shareTokenMint"
        out_file = self.withdraw_cxl_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_claim_withdrawal(self):
        instructionType = "ClaimPendingWithdrawal"
        instructionAction = "transfer"
        tx_merge_key = "senderAddress"
        meta_merge_key = "vaultAuthority"
        out_file = self.withdraw_claim_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_base(
        self,
        instructionType,
        instructionAction,
        tx_merge_key,
        meta_merge_key,
        output_file,
    ):
        """
        generalized method for parsing transfer data.

        1. Call get_batched_xfers()
        2. for each unique txSignature, find the xfer matching to the last instance of the instructionAction
        3. For SOL CC vaults, need an extra step and query for instructionAccount to find vaultAuthority.
        3. Join it to the friktion metadata based using tx_merge_key and meta_merge_key
        4. Drop extraneous rows
        5. Save the file to the output_file

        :instructionType: Type of instruction listed out in the instruction_match() method
        :instructionAction: type of transfer we are matching towards
        :tx_merge_key: what key in the xfer dataFrame do we want to merge on
        :meta_merge_key: what key in the metadata dataFrame we want to merge on.
        :output_file: as name suggests
        """
        print(
            datetime.now(),
            "Parsing transfers for instructionType: %s" % instructionType,
        )
        df = self.get_batched_xfers(instructionType, output_file)

        # Target only wrapped SOL entries for SOL vaults
        df = df.query('currencyName != "Solana"')

        df = (
            df.query('instructionAction=="{}"'.format(instructionAction))
            .groupby("txSignature")
            .last()
            .reset_index()
        )

        # Join tables and get rid of extraneous columns from metadata.
        df = pd.merge(
            df,
            self.friktion_metadata,
            how="left",
            left_on=tx_merge_key,
            right_on=meta_merge_key,
            suffixes=("", "_drop"),
        )
        df.drop([col for col in df.columns if "drop" in col], axis=1, inplace=True)

        # Tag the row with the instructionType
        df["userAction"] = instructionType

        df.drop_duplicates().to_csv(output_file, index=False)
        print(datetime.now(), "{} data size: {}".format(instructionType, df.shape[0]))

    def parse_all(self):
        if not self.skip_ix_scrape:
            self.get_ix_batch()
        self.parse_claim_withdrawal()
        self.parse_deposit_cancel()
        self.parse_withdrawal_cancel()
        self.parse_deposits()
        self.parse_withdrawal()

    ########################################################################################################
    #####################################          Tests             #######################################
    ########################################################################################################

    def check_fidelity(self):
        ix = pd.read_csv(self.ix_fname)
        deposits = pd.read_csv(self.deposit_fname)
        withdrawals = pd.read_csv(self.withdraw_fname)
        claim = pd.read_csv(self.withdraw_claim_fname)
        withdrawals_cxl = pd.read_csv(self.withdraw_cxl_fname)
        deposits_cxl = pd.read_csv(self.deposit_cxl_fname)

        assert ix.loc[ix.instructionType == "Deposit"].shape[0] == deposits.shape[0]
        assert ix.loc[ix.instructionType == "Withdraw"].shape[0] == withdrawals.shape[0]
        assert (
            ix.loc[ix.instructionType == "ClaimPendingWithdrawal"].shape[0]
            == claim.shape[0]
        )
        assert (
            ix.loc[ix.instructionType == "CancelPendingDeposit"].shape[0]
            == deposits_cxl.shape[0]
        )
        assert (
            ix.loc[ix.instructionType == "CancelPendingWithdrawal"].shape[0]
            == withdrawals_cxl.shape[0]
        )


# if __name__ == "__main__":
#     date_start = "2021-12-16T16:00:00Z"
#     date_end = "2022-04-01T00:00:00Z"

#     x = MyPortfolio(date_start, date_end)
#     x.parse_all()
#     x.check_fidelity()

# %%
date_start = "2021-12-16T00:00:00Z"
date_end = "2022-04-02T00:00:00Z"

x = MyPortfolio(date_start, date_end, skip_ix_scrape=True)

x.parse_all()

x.check_fidelity()
# Out:
# 2022-03-31 20:19:42.106867 Parsing transfers for instructionType: ClaimPendingWithdrawal
# 2022-03-31 20:19:42.117921 64 signature batches required...
# 2022-03-31 20:19:45.282583 213 transfers scraped in batch 0
# 2022-03-31 20:19:48.158102 163 transfers scraped in batch 1
# 2022-03-31 20:19:51.051203 183 transfers scraped in batch 2
# 2022-03-31 20:19:53.959187 244 transfers scraped in batch 3
# 2022-03-31 20:19:56.920423 171 transfers scraped in batch 4
# 2022-03-31 20:19:59.809382 221 transfers scraped in batch 5
# 2022-03-31 20:20:04.497262 219 transfers scraped in batch 6
# 2022-03-31 20:20:10.328160 241 transfers scraped in batch 7
# 2022-03-31 20:20:15.717891 191 transfers scraped in batch 8
# 2022-03-31 20:20:19.342960 204 transfers scraped in batch 9
# 2022-03-31 20:20:22.110222 188 transfers scraped in batch 10
# 2022-03-31 20:20:25.748282 223 transfers scraped in batch 11
# 2022-03-31 20:20:29.427290 225 transfers scraped in batch 12
# 2022-03-31 20:20:34.989326 248 transfers scraped in batch 13
# 2022-03-31 20:20:40.799118 209 transfers scraped in batch 14
# 2022-03-31 20:20:46.344801 208 transfers scraped in batch 15
# 2022-03-31 20:20:50.095198 203 transfers scraped in batch 16
# 2022-03-31 20:20:54.719647 235 transfers scraped in batch 17
# 2022-03-31 20:20:57.447772 190 transfers scraped in batch 18
# 2022-03-31 20:21:00.241528 189 transfers scraped in batch 19
# 2022-03-31 20:21:02.981544 263 transfers scraped in batch 20
# 2022-03-31 20:21:05.647314 257 transfers scraped in batch 21
# 2022-03-31 20:21:08.230040 199 transfers scraped in batch 22
# 2022-03-31 20:21:11.954298 214 transfers scraped in batch 23
# 2022-03-31 20:21:15.654878 205 transfers scraped in batch 24
# 2022-03-31 20:21:18.852680 218 transfers scraped in batch 25
# 2022-03-31 20:21:22.013788 187 transfers scraped in batch 26
# 2022-03-31 20:21:25.800115 240 transfers scraped in batch 27
# 2022-03-31 20:21:29.263384 197 transfers scraped in batch 28
# 2022-03-31 20:21:31.801327 208 transfers scraped in batch 29
# 2022-03-31 20:21:34.603914 271 transfers scraped in batch 30
# 2022-03-31 20:21:37.380274 197 transfers scraped in batch 31
# 2022-03-31 20:21:40.080740 207 transfers scraped in batch 32
# 2022-03-31 20:21:42.975372 272 transfers scraped in batch 33
# 2022-03-31 20:21:45.750097 256 transfers scraped in batch 34
# 2022-03-31 20:21:48.459265 212 transfers scraped in batch 35
# 2022-03-31 20:21:54.516802 233 transfers scraped in batch 36
# 2022-03-31 20:21:57.200472 266 transfers scraped in batch 37
# 2022-03-31 20:22:00.149686 273 transfers scraped in batch 38
# 2022-03-31 20:22:02.940844 286 transfers scraped in batch 39
# 2022-03-31 20:22:06.047491 274 transfers scraped in batch 40
# 2022-03-31 20:22:08.857157 245 transfers scraped in batch 41
# 2022-03-31 20:22:11.658641 266 transfers scraped in batch 42
# 2022-03-31 20:22:14.575848 326 transfers scraped in batch 43
# 2022-03-31 20:22:17.974984 220 transfers scraped in batch 44
# 2022-03-31 20:22:21.272718 258 transfers scraped in batch 45
# 2022-03-31 20:22:24.837631 258 transfers scraped in batch 46
# 2022-03-31 20:22:28.184875 198 transfers scraped in batch 47
# 2022-03-31 20:22:30.971574 216 transfers scraped in batch 48
# 2022-03-31 20:22:33.877573 241 transfers scraped in batch 49
# 2022-03-31 20:22:36.585847 266 transfers scraped in batch 50
# 2022-03-31 20:22:39.413894 225 transfers scraped in batch 51
# 2022-03-31 20:22:42.178652 254 transfers scraped in batch 52
# 2022-03-31 20:22:44.950892 245 transfers scraped in batch 53
# 2022-03-31 20:22:47.546811 239 transfers scraped in batch 54
# 2022-03-31 20:22:50.318161 264 transfers scraped in batch 55
# 2022-03-31 20:22:52.972707 231 transfers scraped in batch 56
# 2022-03-31 20:22:55.642962 277 transfers scraped in batch 57
# 2022-03-31 20:23:02.174098 376 transfers scraped in batch 58
# 2022-03-31 20:23:05.241103 313 transfers scraped in batch 59
# 2022-03-31 20:23:14.373032 264 transfers scraped in batch 60
# 2022-03-31 20:23:17.366092 222 transfers scraped in batch 61
# 2022-03-31 20:23:20.330266 283 transfers scraped in batch 62
# 2022-03-31 20:23:21.911748 78 transfers scraped in batch 63
# 2022-03-31 20:23:21.926729 14868 transfers retrieved
# 2022-03-31 20:23:22.029169 ClaimPendingWithdrawal data size: 5708
# 2022-03-31 20:23:22.030963 Parsing transfers for instructionType: CancelPendingDeposit
# 2022-03-31 20:23:22.033984 10 signature batches required...
# 2022-03-31 20:23:25.688217 241 transfers scraped in batch 0
# 2022-03-31 20:23:32.016303 270 transfers scraped in batch 1
# 2022-03-31 20:23:34.948079 275 transfers scraped in batch 2
# 2022-03-31 20:23:37.744096 256 transfers scraped in batch 3
# 2022-03-31 20:23:40.513213 220 transfers scraped in batch 4
# 2022-03-31 20:23:43.251771 186 transfers scraped in batch 5
# 2022-03-31 20:23:46.020406 325 transfers scraped in batch 6
# 2022-03-31 20:23:48.687056 250 transfers scraped in batch 7
# 2022-03-31 20:23:51.315174 236 transfers scraped in batch 8
# 2022-03-31 20:23:53.276177 167 transfers scraped in batch 9
# 2022-03-31 20:23:53.282351 2426 transfers retrieved
# 2022-03-31 20:23:53.312343 CancelPendingDeposit data size: 871
# 2022-03-31 20:23:53.312863 Parsing transfers for instructionType: CancelPendingWithdrawal
# 2022-03-31 20:23:53.316061 8 signature batches required...
# 2022-03-31 20:23:55.660696 90 transfers scraped in batch 0
# 2022-03-31 20:23:57.904530 90 transfers scraped in batch 1
# 2022-03-31 20:24:02.077727 90 transfers scraped in batch 2
# 2022-03-31 20:24:06.025764 90 transfers scraped in batch 3
# 2022-03-31 20:24:08.446955 90 transfers scraped in batch 4
# 2022-03-31 20:24:10.905737 91 transfers scraped in batch 5
# 2022-03-31 20:24:13.273752 90 transfers scraped in batch 6
# 2022-03-31 20:24:14.888160 50 transfers scraped in batch 7
# 2022-03-31 20:24:14.898383 681 transfers retrieved
# 2022-03-31 20:24:14.926478 CancelPendingWithdrawal data size: 680
# 2022-03-31 20:24:14.926680 Parsing transfers for instructionType: Deposit
# 2022-03-31 20:24:14.949886 327 signature batches required...
# 2022-03-31 20:24:18.131703 603 transfers scraped in batch 0
# 2022-03-31 20:24:22.269894 654 transfers scraped in batch 1
# 2022-03-31 20:24:26.437021 666 transfers scraped in batch 2
# 2022-03-31 20:24:30.476109 686 transfers scraped in batch 3
# 2022-03-31 20:24:33.893049 658 transfers scraped in batch 4
# 2022-03-31 20:24:37.224427 662 transfers scraped in batch 5
# 2022-03-31 20:24:44.112698 757 transfers scraped in batch 6
# 2022-03-31 20:24:48.983758 637 transfers scraped in batch 7
# 2022-03-31 20:24:52.340001 686 transfers scraped in batch 8
# 2022-03-31 20:24:55.564738 594 transfers scraped in batch 9
# 2022-03-31 20:24:58.690986 535 transfers scraped in batch 10
# 2022-03-31 20:25:02.152024 602 transfers scraped in batch 11
# 2022-03-31 20:25:05.368185 558 transfers scraped in batch 12
# 2022-03-31 20:25:08.614367 546 transfers scraped in batch 13
# 2022-03-31 20:25:11.954264 519 transfers scraped in batch 14
# 2022-03-31 20:25:15.454388 697 transfers scraped in batch 15
# 2022-03-31 20:25:19.307297 635 transfers scraped in batch 16
# 2022-03-31 20:25:23.186846 648 transfers scraped in batch 17
# 2022-03-31 20:25:26.997779 562 transfers scraped in batch 18
# 2022-03-31 20:25:30.140475 445 transfers scraped in batch 19
# 2022-03-31 20:25:33.626160 442 transfers scraped in batch 20
# 2022-03-31 20:25:39.392404 384 transfers scraped in batch 21
# 2022-03-31 20:25:42.768955 456 transfers scraped in batch 22
# 2022-03-31 20:25:48.084228 390 transfers scraped in batch 23
# 2022-03-31 20:25:52.622517 391 transfers scraped in batch 24
# 2022-03-31 20:25:56.003618 383 transfers scraped in batch 25
# 2022-03-31 20:25:58.962702 390 transfers scraped in batch 26
# 2022-03-31 20:26:02.080881 424 transfers scraped in batch 27
# 2022-03-31 20:26:05.280567 523 transfers scraped in batch 28
# 2022-03-31 20:26:08.495649 503 transfers scraped in batch 29
# 2022-03-31 20:26:11.826438 635 transfers scraped in batch 30
# 2022-03-31 20:26:14.918059 559 transfers scraped in batch 31
# 2022-03-31 20:26:18.559458 554 transfers scraped in batch 32
# 2022-03-31 20:26:22.160445 482 transfers scraped in batch 33
# 2022-03-31 20:26:25.639207 334 transfers scraped in batch 34
# 2022-03-31 20:26:28.605685 339 transfers scraped in batch 35
# 2022-03-31 20:26:31.415022 294 transfers scraped in batch 36
# 2022-03-31 20:26:34.383374 327 transfers scraped in batch 37
# 2022-03-31 20:26:37.447905 313 transfers scraped in batch 38
# 2022-03-31 20:26:40.339587 306 transfers scraped in batch 39
# 2022-03-31 20:26:43.293607 309 transfers scraped in batch 40
# 2022-03-31 20:26:46.120624 340 transfers scraped in batch 41
# 2022-03-31 20:26:49.049887 317 transfers scraped in batch 42
# 2022-03-31 20:26:51.897432 324 transfers scraped in batch 43
# 2022-03-31 20:26:54.791895 335 transfers scraped in batch 44
# 2022-03-31 20:26:57.705566 357 transfers scraped in batch 45
# 2022-03-31 20:27:00.550214 325 transfers scraped in batch 46
# 2022-03-31 20:27:03.437803 319 transfers scraped in batch 47
# 2022-03-31 20:27:06.306769 294 transfers scraped in batch 48
# 2022-03-31 20:27:14.867841 304 transfers scraped in batch 49
# 2022-03-31 20:27:19.235122 312 transfers scraped in batch 50
# 2022-03-31 20:27:22.417206 361 transfers scraped in batch 51
# 2022-03-31 20:27:29.285043 265 transfers scraped in batch 52
# 2022-03-31 20:27:32.582905 217 transfers scraped in batch 53
# 2022-03-31 20:27:36.297687 242 transfers scraped in batch 54
# 2022-03-31 20:27:39.404051 243 transfers scraped in batch 55
# 2022-03-31 20:27:42.221505 238 transfers scraped in batch 56
# 2022-03-31 20:27:45.094237 234 transfers scraped in batch 57
# 2022-03-31 20:27:47.839526 251 transfers scraped in batch 58
# 2022-03-31 20:27:50.923892 328 transfers scraped in batch 59
# 2022-03-31 20:27:53.904057 348 transfers scraped in batch 60
# 2022-03-31 20:27:56.632475 322 transfers scraped in batch 61
# 2022-03-31 20:28:02.471725 346 transfers scraped in batch 62
# 2022-03-31 20:28:05.713444 372 transfers scraped in batch 63
# 2022-03-31 20:28:16.311412 369 transfers scraped in batch 64
# 2022-03-31 20:28:19.766027 417 transfers scraped in batch 65
# 2022-03-31 20:28:22.828387 386 transfers scraped in batch 66
# 2022-03-31 20:28:26.615001 386 transfers scraped in batch 67
# 2022-03-31 20:28:31.214366 398 transfers scraped in batch 68
# 2022-03-31 20:28:34.833649 430 transfers scraped in batch 69
# 2022-03-31 20:28:38.049544 430 transfers scraped in batch 70
# 2022-03-31 20:28:41.234202 393 transfers scraped in batch 71
# 2022-03-31 20:28:44.074418 359 transfers scraped in batch 72
# 2022-03-31 20:28:46.897104 346 transfers scraped in batch 73
# 2022-03-31 20:28:52.711290 226 transfers scraped in batch 74
# 2022-03-31 20:28:59.754039 392 transfers scraped in batch 75
# 2022-03-31 20:29:04.692108 345 transfers scraped in batch 76
# 2022-03-31 20:29:10.508355 288 transfers scraped in batch 77
# 2022-03-31 20:29:13.414668 289 transfers scraped in batch 78
# 2022-03-31 20:29:16.387102 296 transfers scraped in batch 79
# 2022-03-31 20:29:19.762062 346 transfers scraped in batch 80
# 2022-03-31 20:29:23.002462 312 transfers scraped in batch 81
# 2022-03-31 20:29:26.522645 310 transfers scraped in batch 82
# 2022-03-31 20:29:29.706984 285 transfers scraped in batch 83
# 2022-03-31 20:29:32.570932 332 transfers scraped in batch 84
# 2022-03-31 20:29:35.660020 411 transfers scraped in batch 85
# 2022-03-31 20:29:38.871601 426 transfers scraped in batch 86
# 2022-03-31 20:29:41.946554 469 transfers scraped in batch 87
# 2022-03-31 20:29:45.037750 474 transfers scraped in batch 88
# 2022-03-31 20:29:48.040656 415 transfers scraped in batch 89
# 2022-03-31 20:29:51.159170 463 transfers scraped in batch 90
# 2022-03-31 20:29:53.869878 306 transfers scraped in batch 91
# 2022-03-31 20:29:56.872318 386 transfers scraped in batch 92
# 2022-03-31 20:30:00.004429 326 transfers scraped in batch 93
# 2022-03-31 20:30:04.392974 412 transfers scraped in batch 94
# 2022-03-31 20:30:27.999013 412 transfers scraped in batch 95
# 2022-03-31 20:30:30.928495 353 transfers scraped in batch 96
# 2022-03-31 20:30:35.139023 426 transfers scraped in batch 97
# 2022-03-31 20:30:39.797212 408 transfers scraped in batch 98
# 2022-03-31 20:30:43.618617 525 transfers scraped in batch 99
# 2022-03-31 20:30:47.602216 404 transfers scraped in batch 100
# 2022-03-31 20:30:50.435270 296 transfers scraped in batch 101
# 2022-03-31 20:30:53.360322 340 transfers scraped in batch 102
# 2022-03-31 20:30:56.130180 319 transfers scraped in batch 103
# 2022-03-31 20:30:58.857721 315 transfers scraped in batch 104
# 2022-03-31 20:31:01.708304 327 transfers scraped in batch 105
# 2022-03-31 20:31:04.490642 352 transfers scraped in batch 106
# 2022-03-31 20:31:07.465413 420 transfers scraped in batch 107
# 2022-03-31 20:31:10.388611 313 transfers scraped in batch 108
# 2022-03-31 20:31:13.028664 321 transfers scraped in batch 109
# 2022-03-31 20:31:15.754942 337 transfers scraped in batch 110
# 2022-03-31 20:31:19.194362 348 transfers scraped in batch 111
# 2022-03-31 20:31:23.024301 317 transfers scraped in batch 112
# 2022-03-31 20:31:26.627864 331 transfers scraped in batch 113
# 2022-03-31 20:31:29.268840 300 transfers scraped in batch 114
# 2022-03-31 20:31:32.421982 361 transfers scraped in batch 115
# 2022-03-31 20:31:35.120954 316 transfers scraped in batch 116
# 2022-03-31 20:31:38.248648 407 transfers scraped in batch 117
# 2022-03-31 20:31:41.194331 414 transfers scraped in batch 118
# 2022-03-31 20:31:44.205330 388 transfers scraped in batch 119
# 2022-03-31 20:31:47.019088 393 transfers scraped in batch 120
# 2022-03-31 20:31:49.985510 409 transfers scraped in batch 121
# 2022-03-31 20:31:53.086998 410 transfers scraped in batch 122
# 2022-03-31 20:31:56.144106 478 transfers scraped in batch 123
# 2022-03-31 20:31:59.336782 551 transfers scraped in batch 124
# 2022-03-31 20:32:02.579528 454 transfers scraped in batch 125
# 2022-03-31 20:32:05.650955 436 transfers scraped in batch 126
# 2022-03-31 20:32:08.612933 470 transfers scraped in batch 127
# 2022-03-31 20:32:11.785521 460 transfers scraped in batch 128
# 2022-03-31 20:32:14.854324 514 transfers scraped in batch 129
# 2022-03-31 20:32:18.342192 465 transfers scraped in batch 130
# 2022-03-31 20:32:22.086965 468 transfers scraped in batch 131
# 2022-03-31 20:32:25.419395 365 transfers scraped in batch 132
# 2022-03-31 20:32:28.517790 461 transfers scraped in batch 133
# 2022-03-31 20:32:31.599364 453 transfers scraped in batch 134
# 2022-03-31 20:32:34.668074 448 transfers scraped in batch 135
# 2022-03-31 20:32:37.405880 395 transfers scraped in batch 136
# 2022-03-31 20:32:40.246168 417 transfers scraped in batch 137
# 2022-03-31 20:32:43.340070 476 transfers scraped in batch 138
# 2022-03-31 20:32:46.366575 405 transfers scraped in batch 139
# 2022-03-31 20:32:49.120985 366 transfers scraped in batch 140
# 2022-03-31 20:32:55.993124 431 transfers scraped in batch 141
# 2022-03-31 20:32:59.260894 419 transfers scraped in batch 142
# 2022-03-31 20:33:03.946177 483 transfers scraped in batch 143
# 2022-03-31 20:33:07.036217 394 transfers scraped in batch 144
# 2022-03-31 20:33:11.306504 366 transfers scraped in batch 145
# 2022-03-31 20:33:15.652980 358 transfers scraped in batch 146
# 2022-03-31 20:33:19.151058 437 transfers scraped in batch 147
# 2022-03-31 20:33:22.634058 379 transfers scraped in batch 148
# 2022-03-31 20:33:26.679152 375 transfers scraped in batch 149
# 2022-03-31 20:33:29.877079 323 transfers scraped in batch 150
# 2022-03-31 20:33:32.664338 368 transfers scraped in batch 151
# 2022-03-31 20:33:35.553715 321 transfers scraped in batch 152
# 2022-03-31 20:33:38.247486 340 transfers scraped in batch 153
# 2022-03-31 20:33:41.234558 392 transfers scraped in batch 154
# 2022-03-31 20:33:44.195186 385 transfers scraped in batch 155
# 2022-03-31 20:33:46.908874 315 transfers scraped in batch 156
# 2022-03-31 20:33:49.920741 406 transfers scraped in batch 157
# 2022-03-31 20:33:52.737442 388 transfers scraped in batch 158
# 2022-03-31 20:33:55.852220 445 transfers scraped in batch 159
# 2022-03-31 20:33:58.811629 398 transfers scraped in batch 160
# 2022-03-31 20:34:01.844464 401 transfers scraped in batch 161
# 2022-03-31 20:34:04.751516 331 transfers scraped in batch 162
# 2022-03-31 20:34:07.439536 376 transfers scraped in batch 163
# 2022-03-31 20:34:10.357952 378 transfers scraped in batch 164
# 2022-03-31 20:34:13.359455 387 transfers scraped in batch 165
# 2022-03-31 20:34:16.929096 399 transfers scraped in batch 166
# 2022-03-31 20:34:20.569504 417 transfers scraped in batch 167
# 2022-03-31 20:34:24.442365 442 transfers scraped in batch 168
# 2022-03-31 20:34:27.735219 331 transfers scraped in batch 169
# 2022-03-31 20:34:30.649037 387 transfers scraped in batch 170
# 2022-03-31 20:34:33.556304 348 transfers scraped in batch 171
# 2022-03-31 20:34:36.294031 325 transfers scraped in batch 172
# 2022-03-31 20:34:39.058792 344 transfers scraped in batch 173
# 2022-03-31 20:34:42.140181 464 transfers scraped in batch 174
# 2022-03-31 20:34:44.994530 394 transfers scraped in batch 175
# 2022-03-31 20:34:48.198881 420 transfers scraped in batch 176
# 2022-03-31 20:34:51.344878 489 transfers scraped in batch 177
# 2022-03-31 20:34:54.187634 369 transfers scraped in batch 178
# 2022-03-31 20:34:57.019934 333 transfers scraped in batch 179
# 2022-03-31 20:35:00.100884 423 transfers scraped in batch 180
# 2022-03-31 20:35:03.264573 429 transfers scraped in batch 181
# 2022-03-31 20:35:06.318468 436 transfers scraped in batch 182
# 2022-03-31 20:35:14.091200 430 transfers scraped in batch 183
# 2022-03-31 20:35:17.703155 415 transfers scraped in batch 184
# 2022-03-31 20:35:23.515947 442 transfers scraped in batch 185
# 2022-03-31 20:35:27.585530 454 transfers scraped in batch 186
# 2022-03-31 20:35:31.525281 333 transfers scraped in batch 187
# 2022-03-31 20:35:34.489209 418 transfers scraped in batch 188
# 2022-03-31 20:35:37.426520 331 transfers scraped in batch 189
# 2022-03-31 20:35:40.460586 478 transfers scraped in batch 190
# 2022-03-31 20:35:43.504629 488 transfers scraped in batch 191
# 2022-03-31 20:35:46.412754 342 transfers scraped in batch 192
# 2022-03-31 20:35:49.149569 343 transfers scraped in batch 193
# 2022-03-31 20:35:52.081809 403 transfers scraped in batch 194
# 2022-03-31 20:35:55.006050 450 transfers scraped in batch 195
# 2022-03-31 20:35:57.779795 338 transfers scraped in batch 196
# 2022-03-31 20:36:03.244073 376 transfers scraped in batch 197
# 2022-03-31 20:36:07.394711 359 transfers scraped in batch 198
# 2022-03-31 20:36:10.364363 352 transfers scraped in batch 199
# 2022-03-31 20:36:13.563341 375 transfers scraped in batch 200
# 2022-03-31 20:36:16.739087 430 transfers scraped in batch 201
# 2022-03-31 20:36:20.236507 355 transfers scraped in batch 202
# 2022-03-31 20:36:24.035058 424 transfers scraped in batch 203
# 2022-03-31 20:36:28.011963 527 transfers scraped in batch 204
# 2022-03-31 20:36:31.414120 384 transfers scraped in batch 205
# 2022-03-31 20:36:34.543303 460 transfers scraped in batch 206
# 2022-03-31 20:36:37.632219 403 transfers scraped in batch 207
# 2022-03-31 20:36:40.715771 405 transfers scraped in batch 208
# 2022-03-31 20:36:43.692239 402 transfers scraped in batch 209
# 2022-03-31 20:36:46.702576 431 transfers scraped in batch 210
# 2022-03-31 20:36:49.903060 414 transfers scraped in batch 211
# 2022-03-31 20:36:52.985345 408 transfers scraped in batch 212
# 2022-03-31 20:36:56.043929 422 transfers scraped in batch 213
# 2022-03-31 20:36:58.815442 348 transfers scraped in batch 214
# 2022-03-31 20:37:01.660953 319 transfers scraped in batch 215
# 2022-03-31 20:37:04.665920 368 transfers scraped in batch 216
# 2022-03-31 20:37:08.027266 294 transfers scraped in batch 217
# 2022-03-31 20:37:11.115547 383 transfers scraped in batch 218
# 2022-03-31 20:37:14.298756 436 transfers scraped in batch 219
# 2022-03-31 20:37:20.542656 463 transfers scraped in batch 220
# 2022-03-31 20:37:24.250280 465 transfers scraped in batch 221
# 2022-03-31 20:37:33.439123 436 transfers scraped in batch 222
# 2022-03-31 20:37:38.261526 358 transfers scraped in batch 223
# 2022-03-31 20:37:46.573342 350 transfers scraped in batch 224
# 2022-03-31 20:37:50.532371 381 transfers scraped in batch 225
# 2022-03-31 20:37:53.988230 366 transfers scraped in batch 226
# 2022-03-31 20:37:57.896855 338 transfers scraped in batch 227
# 2022-03-31 20:38:01.297912 413 transfers scraped in batch 228
# 2022-03-31 20:38:04.183876 346 transfers scraped in batch 229
# 2022-03-31 20:38:07.143869 369 transfers scraped in batch 230
# 2022-03-31 20:38:10.101861 346 transfers scraped in batch 231
# 2022-03-31 20:38:13.192887 409 transfers scraped in batch 232
# 2022-03-31 20:38:16.262997 405 transfers scraped in batch 233
# 2022-03-31 20:38:20.080753 432 transfers scraped in batch 234
# 2022-03-31 20:38:24.027696 436 transfers scraped in batch 235
# 2022-03-31 20:38:27.739880 452 transfers scraped in batch 236
# 2022-03-31 20:38:30.652697 396 transfers scraped in batch 237
# 2022-03-31 20:38:33.763848 421 transfers scraped in batch 238
# 2022-03-31 20:38:36.652121 394 transfers scraped in batch 239
# 2022-03-31 20:38:39.541247 404 transfers scraped in batch 240
# 2022-03-31 20:38:43.412083 383 transfers scraped in batch 241
# 2022-03-31 20:38:46.631156 465 transfers scraped in batch 242
# 2022-03-31 20:38:50.083659 452 transfers scraped in batch 243
# 2022-03-31 20:38:53.362713 485 transfers scraped in batch 244
# 2022-03-31 20:38:56.315276 445 transfers scraped in batch 245
# 2022-03-31 20:38:59.449797 399 transfers scraped in batch 246
# 2022-03-31 20:39:02.370961 361 transfers scraped in batch 247
# 2022-03-31 20:39:05.193837 344 transfers scraped in batch 248
# 2022-03-31 20:39:08.144707 379 transfers scraped in batch 249
# 2022-03-31 20:39:16.782807 413 transfers scraped in batch 250
# 2022-03-31 20:39:26.745054 409 transfers scraped in batch 251
# 2022-03-31 20:39:33.993070 413 transfers scraped in batch 252
# 2022-03-31 20:39:37.828580 362 transfers scraped in batch 253
# 2022-03-31 20:39:40.702224 324 transfers scraped in batch 254
# 2022-03-31 20:39:43.648712 401 transfers scraped in batch 255
# 2022-03-31 20:39:47.239970 394 transfers scraped in batch 256
# 2022-03-31 20:39:53.866299 398 transfers scraped in batch 257
# 2022-03-31 20:39:59.084118 373 transfers scraped in batch 258
# 2022-03-31 20:40:02.705201 362 transfers scraped in batch 259
# 2022-03-31 20:40:08.490276 375 transfers scraped in batch 260
# 2022-03-31 20:40:11.861202 381 transfers scraped in batch 261
# 2022-03-31 20:40:19.499449 409 transfers scraped in batch 262
# 2022-03-31 20:40:25.410375 376 transfers scraped in batch 263
# 2022-03-31 20:40:28.907907 369 transfers scraped in batch 264
# 2022-03-31 20:40:35.539592 413 transfers scraped in batch 265
# 2022-03-31 20:40:38.561453 417 transfers scraped in batch 266
# 2022-03-31 20:40:41.367807 328 transfers scraped in batch 267
# 2022-03-31 20:40:44.248753 362 transfers scraped in batch 268
# 2022-03-31 20:40:47.481606 494 transfers scraped in batch 269
# 2022-03-31 20:40:50.733039 417 transfers scraped in batch 270
# 2022-03-31 20:40:53.600630 363 transfers scraped in batch 271
# 2022-03-31 20:40:56.667075 353 transfers scraped in batch 272
# 2022-03-31 20:40:59.587283 375 transfers scraped in batch 273
# 2022-03-31 20:41:02.542341 367 transfers scraped in batch 274
# 2022-03-31 20:41:05.620018 380 transfers scraped in batch 275
# 2022-03-31 20:41:08.356743 297 transfers scraped in batch 276
# 2022-03-31 20:41:11.236363 339 transfers scraped in batch 277
# 2022-03-31 20:41:14.335026 416 transfers scraped in batch 278
# 2022-03-31 20:41:17.371842 370 transfers scraped in batch 279
# 2022-03-31 20:41:20.771870 359 transfers scraped in batch 280
# 2022-03-31 20:41:24.325483 336 transfers scraped in batch 281
# 2022-03-31 20:41:28.104555 286 transfers scraped in batch 282
# 2022-03-31 20:41:31.080715 416 transfers scraped in batch 283
# 2022-03-31 20:41:33.945695 334 transfers scraped in batch 284
# 2022-03-31 20:41:36.982072 387 transfers scraped in batch 285
# 2022-03-31 20:41:39.774577 358 transfers scraped in batch 286
# 2022-03-31 20:41:42.745874 405 transfers scraped in batch 287
# 2022-03-31 20:41:45.687965 406 transfers scraped in batch 288
# 2022-03-31 20:41:48.598873 331 transfers scraped in batch 289
# 2022-03-31 20:41:51.571716 428 transfers scraped in batch 290
# 2022-03-31 20:41:55.360410 427 transfers scraped in batch 291
# 2022-03-31 20:42:02.139976 258 transfers scraped in batch 292
# 2022-03-31 20:42:08.232678 269 transfers scraped in batch 293
# 2022-03-31 20:42:11.767448 286 transfers scraped in batch 294
# 2022-03-31 20:42:14.760792 272 transfers scraped in batch 295
# 2022-03-31 20:42:17.694709 293 transfers scraped in batch 296
# 2022-03-31 20:42:20.540165 292 transfers scraped in batch 297
# 2022-03-31 20:42:23.919125 268 transfers scraped in batch 298
# 2022-03-31 20:42:27.374305 272 transfers scraped in batch 299
# 2022-03-31 20:42:30.894093 270 transfers scraped in batch 300
# 2022-03-31 20:42:34.107291 275 transfers scraped in batch 301
# 2022-03-31 20:42:39.884071 261 transfers scraped in batch 302
# 2022-03-31 20:42:44.042555 270 transfers scraped in batch 303
# 2022-03-31 20:42:50.542498 268 transfers scraped in batch 304
# 2022-03-31 20:42:55.639083 300 transfers scraped in batch 305
# 2022-03-31 20:42:58.815470 273 transfers scraped in batch 306
# 2022-03-31 20:43:02.802956 288 transfers scraped in batch 307
# 2022-03-31 20:43:06.232716 284 transfers scraped in batch 308
# 2022-03-31 20:43:09.265761 281 transfers scraped in batch 309
# 2022-03-31 20:43:12.178701 291 transfers scraped in batch 310
# 2022-03-31 20:43:15.052396 276 transfers scraped in batch 311
# 2022-03-31 20:43:18.920343 268 transfers scraped in batch 312
# 2022-03-31 20:43:22.646574 264 transfers scraped in batch 313
# 2022-03-31 20:43:26.094170 284 transfers scraped in batch 314
# 2022-03-31 20:43:28.962818 276 transfers scraped in batch 315
# 2022-03-31 20:43:31.624895 268 transfers scraped in batch 316
# 2022-03-31 20:43:34.399776 290 transfers scraped in batch 317
# 2022-03-31 20:43:37.509416 260 transfers scraped in batch 318
# 2022-03-31 20:43:40.345134 280 transfers scraped in batch 319
# 2022-03-31 20:43:43.158456 284 transfers scraped in batch 320
# 2022-03-31 20:43:45.920249 273 transfers scraped in batch 321
# 2022-03-31 20:43:49.589374 268 transfers scraped in batch 322
# 2022-03-31 20:43:52.470568 276 transfers scraped in batch 323
# 2022-03-31 20:43:55.172217 296 transfers scraped in batch 324
# 2022-03-31 20:43:58.074691 300 transfers scraped in batch 325
# 2022-03-31 20:44:00.401949 222 transfers scraped in batch 326
# 2022-03-31 20:44:00.520608 126607 transfers retrieved
# 2022-03-31 20:44:01.210023 Deposit data size: 29406
# 2022-03-31 20:44:01.226468 Parsing transfers for instructionType: Withdraw
# 2022-03-31 20:44:01.234510 93 signature batches required...
# 2022-03-31 20:44:04.975494 754 transfers scraped in batch 0
# 2022-03-31 20:44:08.073906 421 transfers scraped in batch 1
# 2022-03-31 20:44:11.004184 351 transfers scraped in batch 2
# 2022-03-31 20:44:13.914294 343 transfers scraped in batch 3
# 2022-03-31 20:44:17.006522 329 transfers scraped in batch 4
# 2022-03-31 20:44:21.705581 329 transfers scraped in batch 5
# 2022-03-31 20:44:25.502200 296 transfers scraped in batch 6
# 2022-03-31 20:44:29.121850 356 transfers scraped in batch 7
# 2022-03-31 20:44:31.968868 300 transfers scraped in batch 8
# 2022-03-31 20:44:34.763953 312 transfers scraped in batch 9
# 2022-03-31 20:44:37.523276 297 transfers scraped in batch 10
# 2022-03-31 20:44:40.365713 322 transfers scraped in batch 11
# 2022-03-31 20:44:43.306550 285 transfers scraped in batch 12
# 2022-03-31 20:44:46.112007 299 transfers scraped in batch 13
# 2022-03-31 20:44:49.177994 334 transfers scraped in batch 14
# 2022-03-31 20:44:52.163728 345 transfers scraped in batch 15
# 2022-03-31 20:44:55.069815 368 transfers scraped in batch 16
# 2022-03-31 20:44:57.797980 281 transfers scraped in batch 17
# 2022-03-31 20:45:02.500117 273 transfers scraped in batch 18
# 2022-03-31 20:45:08.318087 380 transfers scraped in batch 19
# 2022-03-31 20:45:15.617562 340 transfers scraped in batch 20
# 2022-03-31 20:45:20.821224 304 transfers scraped in batch 21
# 2022-03-31 20:45:24.707186 360 transfers scraped in batch 22
# 2022-03-31 20:45:28.625878 327 transfers scraped in batch 23
# 2022-03-31 20:45:32.163762 284 transfers scraped in batch 24
# 2022-03-31 20:45:35.794485 295 transfers scraped in batch 25
# 2022-03-31 20:45:38.715136 320 transfers scraped in batch 26
# 2022-03-31 20:45:41.484913 311 transfers scraped in batch 27
# 2022-03-31 20:45:44.258960 297 transfers scraped in batch 28
# 2022-03-31 20:45:47.105228 329 transfers scraped in batch 29
# 2022-03-31 20:45:49.878359 286 transfers scraped in batch 30
# 2022-03-31 20:45:52.511908 333 transfers scraped in batch 31
# 2022-03-31 20:45:55.409057 363 transfers scraped in batch 32
# 2022-03-31 20:45:58.676958 353 transfers scraped in batch 33
# 2022-03-31 20:46:01.716459 326 transfers scraped in batch 34
# 2022-03-31 20:46:04.828185 362 transfers scraped in batch 35
# 2022-03-31 20:46:07.722148 317 transfers scraped in batch 36
# 2022-03-31 20:46:10.476458 300 transfers scraped in batch 37
# 2022-03-31 20:46:13.367846 313 transfers scraped in batch 38
# 2022-03-31 20:46:16.262259 332 transfers scraped in batch 39
# 2022-03-31 20:46:20.210753 384 transfers scraped in batch 40
# 2022-03-31 20:46:23.982220 349 transfers scraped in batch 41
# 2022-03-31 20:46:27.305718 326 transfers scraped in batch 42
# 2022-03-31 20:46:30.384651 320 transfers scraped in batch 43
# 2022-03-31 20:46:33.159004 335 transfers scraped in batch 44
# 2022-03-31 20:46:36.266698 376 transfers scraped in batch 45
# 2022-03-31 20:46:39.067417 321 transfers scraped in batch 46
# 2022-03-31 20:46:42.071945 350 transfers scraped in batch 47
# 2022-03-31 20:46:44.736976 290 transfers scraped in batch 48
# 2022-03-31 20:46:47.570075 349 transfers scraped in batch 49
# 2022-03-31 20:46:50.534287 360 transfers scraped in batch 50
# 2022-03-31 20:46:53.320005 321 transfers scraped in batch 51
# 2022-03-31 20:46:56.289739 362 transfers scraped in batch 52
# 2022-03-31 20:46:59.549493 369 transfers scraped in batch 53
# 2022-03-31 20:47:03.101464 350 transfers scraped in batch 54
# 2022-03-31 20:47:05.926980 358 transfers scraped in batch 55
# 2022-03-31 20:47:08.974464 350 transfers scraped in batch 56
# 2022-03-31 20:47:12.104441 370 transfers scraped in batch 57
# 2022-03-31 20:47:15.200057 409 transfers scraped in batch 58
# 2022-03-31 20:47:18.673889 312 transfers scraped in batch 59
# 2022-03-31 20:47:21.999265 289 transfers scraped in batch 60
# 2022-03-31 20:47:26.978786 326 transfers scraped in batch 61
# 2022-03-31 20:47:31.432849 370 transfers scraped in batch 62
# 2022-03-31 20:47:38.593346 353 transfers scraped in batch 63
# 2022-03-31 20:47:42.615632 365 transfers scraped in batch 64
# 2022-03-31 20:47:45.461409 333 transfers scraped in batch 65
# 2022-03-31 20:47:48.431237 354 transfers scraped in batch 66
# 2022-03-31 20:47:51.095292 315 transfers scraped in batch 67
# 2022-03-31 20:47:54.057956 351 transfers scraped in batch 68
# 2022-03-31 20:47:56.938311 377 transfers scraped in batch 69
# 2022-03-31 20:48:00.193778 349 transfers scraped in batch 70
# 2022-03-31 20:48:04.753877 351 transfers scraped in batch 71
# 2022-03-31 20:48:07.597969 332 transfers scraped in batch 72
# 2022-03-31 20:48:10.824234 362 transfers scraped in batch 73
# 2022-03-31 20:48:14.111337 358 transfers scraped in batch 74
# 2022-03-31 20:48:16.903788 310 transfers scraped in batch 75
# 2022-03-31 20:48:20.399182 411 transfers scraped in batch 76
# 2022-03-31 20:48:24.092739 359 transfers scraped in batch 77
# 2022-03-31 20:48:27.562438 330 transfers scraped in batch 78
# 2022-03-31 20:48:31.617110 319 transfers scraped in batch 79
# 2022-03-31 20:48:34.675495 329 transfers scraped in batch 80
# 2022-03-31 20:48:37.493067 297 transfers scraped in batch 81
# 2022-03-31 20:48:40.721977 405 transfers scraped in batch 82
# 2022-03-31 20:48:43.851547 429 transfers scraped in batch 83
# 2022-03-31 20:48:46.722235 371 transfers scraped in batch 84
# 2022-03-31 20:48:49.616958 375 transfers scraped in batch 85
# 2022-03-31 20:48:52.454277 314 transfers scraped in batch 86
# 2022-03-31 20:48:55.316103 338 transfers scraped in batch 87
# 2022-03-31 20:48:58.390228 346 transfers scraped in batch 88
# 2022-03-31 20:49:01.503151 347 transfers scraped in batch 89
# 2022-03-31 20:49:04.723601 358 transfers scraped in batch 90
# 2022-03-31 20:49:07.866942 387 transfers scraped in batch 91
# 2022-03-31 20:49:10.743022 336 transfers scraped in batch 92
# 2022-03-31 20:49:10.772122 31934 transfers retrieved
# 2022-03-31 20:49:10.927193 Withdraw data size: 8358
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/t5/lm3g0brx0dsf0ymt1ldc8xdr0000gp/T/ipykernel_44369/3359866283.py in <module>
#       6 x.parse_all()
#       7
# ----> 8 x.check_fidelity()
#
# /var/folders/t5/lm3g0brx0dsf0ymt1ldc8xdr0000gp/T/ipykernel_44369/3747385213.py in check_fidelity(self)
#     541         deposits_cxl = pd.read_csv(self.deposit_cxl_fname)
#     542
# --> 543         assert ix.loc[ix.instructionType == "Deposit"].shape[0] == deposits.shape[0]
#     544         assert ix.loc[ix.instructionType == "Withdraw"].shape[0] == withdrawals.shape[0]
#     545         assert (
#
# AssertionError:

# %%
        ix = pd.read_csv("friktion_ix.csv")
        deposits = pd.read_csv("friktion_deposit.csv")
#         withdrawals = pd.read_csv(self.withdraw_fname)
#         claim = pd.read_csv(self.withdraw_claim_fname)
#         withdrawals_cxl = pd.read_csv(self.withdraw_cxl_fname)
#         deposits_cxl = pd.read_csv(self.deposit_cxl_fname)
        
#         print(ix)
#         print(deposits)

#         assert ix.loc[ix.instructionType=="Deposit"].shape[0] == deposits.shape[0]
#         assert ix.loc[ix.instructionType=="Withdraw"].shape[0] == withdrawals.shape[0]
#         assert ix.loc[ix.instructionType=="ClaimPendingWithdrawal"].shape[0] == claim.shape[0]
#         assert ix.loc[ix.instructionType=="CancelPendingDeposit"].shape[0] == deposits_cxl.shape[0]
#         assert ix.loc[ix.instructionType=="CancelPendingWithdrawal"].shape[0] == withdrawals_cxl.shape[0]

# %%
deposits.shape
# Out:
# (29406, 17)

# %%
ix.loc[ix.instructionType=="Deposit"].shape
# Out:
# (29408, 5)

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId', 'userAction'],
#       dtype='object')

# %%
deposits

# %%
# Have Price
# Have VoltTokenShare

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId'],
#       dtype='object')

# %%
deposits.shape
# Out:
# (115, 16)

# %%
deposits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   txSignature              115 non-null    object
#  1   amount                   115 non-null    float64
#  2   instructionAction        115 non-null    object
#  3   instructionOrder         115 non-null    object
#  4   userAddress              115 non-null    object
#  5   timestamp                115 non-null    object
#  6   currencyName             115 non-null    object
#  7   currencyAddress          115 non-null    object
#  8   senderAddress            115 non-null    object
#  9   senderTokenMint          115 non-null    object
#  10  receiverAddress          115 non-null    object
#  11  globalId                 115 non-null    object
#  12  vaultAuthority           115 non-null    object
#  13  shareTokenMint           115 non-null    object
#  14  depositTokenSymbol       115 non-null    object
#  15  depositTokenCoingeckoId  115 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 14.5+ KB

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId'],
#       dtype='object')

# %%
deposits
# Out:
#                                            txSignature        amount  \
# 0    1kx6PYTANDwsAZGZ5xoRNe51uRK68k6roF6KYDauHQMmem...      0.998590
# 1    231BLTQGbub2Cdm7s5Y7rSS4JN2L9JLWzhtwYG7Jowpd3e...    144.809361
# 2    24y4KRma4BUarjw4y8Rv9Dt1kZdVVSP5kVnkbu4Ra5KMs7...    551.000000
# 3    28SouEpsyqsi3u6Mmy1XRbjCEaab4M6YtofuEK1c85CDZv...    100.000000
# 4    28nZcxYZ9sMCbotCXRrdRLx8GWksnY4PeJYAeiaRcKNyGk...      0.388000
# ..                                                 ...           ...
# 110  fYVnATWfXi5r16jP1VPgSd7ppUoZKkrSgKEDEo8FJ4WhZh...  10000.000000
# 111  mT2cRegqHKyJ9wGUV4Eu5UPX5sK1csJBfFTv3cPiNMkkAD...    145.317189
# 112  uaZuopPrzfkJctoVVHoqz7SgP8P6uqu6wvMB63iAzmDL3t...      0.200000
# 113  vpBz5es8vUbCDt4MjKRFhDcZ8qC8rNhPfCqDzyB8SUmZzD...      0.040000
# 114  xNBk1syyK2NASzZBeUiQbCxGGLNxuTh6QQYbPKCAGq6Ltv...      4.670481
#
#     instructionAction instructionOrder  \
# 0            transfer              1-1
# 1            transfer              1-1
# 2            transfer              3-1
# 3            transfer              1-1
# 4            transfer              2-0
# ..                ...              ...
# 110          transfer              0-0
# 111          transfer              1-1
# 112          transfer              3-0
# 113          transfer              2-0
# 114          transfer              0-0
#
#                                       userAddress             timestamp  \
# 0    79jbRVMQu5rQkEcAPbzZNqnwKEASHyEyWgUn9q76yUKT  2022-03-17T19:33:26Z
# 1    EapjtDx27xLxAeKFhFUzsYdCT6BeeAEKcJ4NYoMqKubN  2022-03-17T18:19:02Z
# 2    9T19SkKUpSNbt2cMcCQVz7NZEfmXW3gdMDkH9db1yidw  2022-03-17T18:39:38Z
# 3    5KfRm2tAzQ4yFWKVvbWdtesvz4iuBfPxdJYwZB1yNJHP  2022-03-17T22:51:42Z
# 4    D6mQT7imPfYF4VUVdVXKR1Rgya6oefmxYnihzy9CpUxB  2022-03-17T21:20:45Z
# ..                                            ...                   ...
# 110  AT4qoJDVGXpEm3BGACUhC1zpVNLq4iX2bJ4cpABehpoD  2022-03-17T23:32:03Z
# 111  GedG3v5kyfKaqFdUXpY9SJ8tvZaKY1em5TrUf9ENfaPt  2022-03-17T21:14:53Z
# 112  D2Mo1W5UDAZJaKTZVp9QpaZGxXMJx58joijb9UrYcUNv  2022-03-17T18:42:51Z
# 113  C7kUxhQVt1PvaaxCsXi6qF9RP24MmCi9pdxAm4AVRwse  2022-03-17T19:29:52Z
# 114  ENvAgELWWXSFasbyzFuHKgaKSeFbU3eEHgZnHCFe1DKV  2022-03-17T20:39:25Z
#
#                   currencyName                               currencyAddress  \
# 0    Wrapped Ethereum (Sollet)  2FPyTwcZLUg1MDrwsyoP4D6s1tM7hAkHYRjkNb5w6Pxk
# 1                     USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 2                  Wrapped SOL   So11111111111111111111111111111111111111112
# 3                     USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 4                  Wrapped SOL   So11111111111111111111111111111111111111112
# ..                         ...                                           ...
# 110                   USD Coin  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 111       Wrapped FTT (Sollet)  AGFEad2et2ZJif9jaGpdMixQqvW5i81aBdvKe7PHNfz3
# 112                Wrapped SOL   So11111111111111111111111111111111111111112
# 113                Wrapped SOL   So11111111111111111111111111111111111111112
# 114            LUNA (Wormhole)  F6v4wfAdJB8D8p77bMXZgYt8TDKsYxLYxH5AFhUkYx9W
#
#                                     senderAddress  \
# 0    79jbRVMQu5rQkEcAPbzZNqnwKEASHyEyWgUn9q76yUKT
# 1    EapjtDx27xLxAeKFhFUzsYdCT6BeeAEKcJ4NYoMqKubN
# 2    9T19SkKUpSNbt2cMcCQVz7NZEfmXW3gdMDkH9db1yidw
# 3    5KfRm2tAzQ4yFWKVvbWdtesvz4iuBfPxdJYwZB1yNJHP
# 4    D6mQT7imPfYF4VUVdVXKR1Rgya6oefmxYnihzy9CpUxB
# ..                                            ...
# 110  AT4qoJDVGXpEm3BGACUhC1zpVNLq4iX2bJ4cpABehpoD
# 111  GedG3v5kyfKaqFdUXpY9SJ8tvZaKY1em5TrUf9ENfaPt
# 112  D2Mo1W5UDAZJaKTZVp9QpaZGxXMJx58joijb9UrYcUNv
# 113  C7kUxhQVt1PvaaxCsXi6qF9RP24MmCi9pdxAm4AVRwse
# 114  ENvAgELWWXSFasbyzFuHKgaKSeFbU3eEHgZnHCFe1DKV
#
#                                   senderTokenMint  \
# 0    3e81Tr2AGVLwPLLsUwiBSaYdGDwSxCMXmhF5ZWUuQAsn
# 1    AaV2HTiE7hJWzDA1od8wbBAGM1Kqmxo8BSoMkGV5VKbG
# 2    D9QnLjbjTEBCqFZUrovoFkNW3B8gLmsJkT6PDt4HUv1H
# 3    DMEMt2oVMq8TRvBWY79xfgYb6Kq5GHcwR8cKHgDy934S
# 4    25rEKbr8KDHj3UT1ZSSBYsmDCUQnWXn6PEFJMMZ6bHdg
# ..                                            ...
# 110  347NS5vxWV3p7GCHT7jgNDpsKHXzLYghro9BJxuXTpNk
# 111  FCFaWp8pyVG3iJA7YrDKC8nri9aLKz3BgVoKqCoKgwv7
# 112  9funBx9gwNU1PBvNkZVL1iohS4oEBYrKXaUuLgsdaAjp
# 113  7UCxgjmp7zwPX5ASWrmucW2Zi5jvPCu7x3mTvSkrQxnJ
# 114  5qZ9tbmDbamx7eyPWiPQMnXXu1zKjKrU5n5hEVAfozrb
#
#                                   receiverAddress  \
# 0    FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# 1    GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 2     wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# 3    GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 4     wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# ..                                            ...
# 110  BThMeTgWZBoBbAzp9sK9T7gQzpQDQdRQUVLtVQ3781q1
# 111  7KqHFuUksvNhrWgoacKkqyp2RwfBNdypCYgK9nxD1d6K
# 112  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 113   wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# 114  5oV1Yf8q1oQgPYuHjepjmKFuaG2Wng9dzTqbSWhU5W2X
#
#                          globalId  \
# 0         mainnet_income_call_eth
# 1          mainnet_income_put_btc
# 2    mainnet_income_call_sol_high
# 3          mainnet_income_put_btc
# 4    mainnet_income_call_sol_high
# ..                            ...
# 110   mainnet_income_put_sol_high
# 111       mainnet_income_call_ftt
# 112       mainnet_income_call_sol
# 113  mainnet_income_call_sol_high
# 114      mainnet_income_call_luna
#
#                                    vaultAuthority  \
# 0    FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# 1    GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 2     wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# 3    GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 4     wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# ..                                            ...
# 110  BThMeTgWZBoBbAzp9sK9T7gQzpQDQdRQUVLtVQ3781q1
# 111  7KqHFuUksvNhrWgoacKkqyp2RwfBNdypCYgK9nxD1d6K
# 112  Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 113   wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# 114  5oV1Yf8q1oQgPYuHjepjmKFuaG2Wng9dzTqbSWhU5W2X
#
#                                    shareTokenMint depositTokenSymbol  \
# 0    GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS                ETH
# 1     THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC               USDC
# 2    DNa849drqW19uBV5X9ohpJ5brRGzq856gk3HDRqveFrA                SOL
# 3     THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC               USDC
# 4    DNa849drqW19uBV5X9ohpJ5brRGzq856gk3HDRqveFrA                SOL
# ..                                            ...                ...
# 110  G8jsAWUA2KdDn7XmV1sBqUdbEXESaPdjPWDEYCsnkRX2               USDC
# 111  7wDh4VCTPwx41kvbLE6fkFgMEjnqw7NpGJvQtNabCm2B                FTT
# 112  4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 113  DNa849drqW19uBV5X9ohpJ5brRGzq856gk3HDRqveFrA                SOL
# 114  95sn4kgeJnnBfRCD8S2quu4HS9Y6vb7JDuXrarnmEjYE               LUNA
#
#     depositTokenCoingeckoId
# 0                  ethereum
# 1                  usd-coin
# 2                    solana
# 3                  usd-coin
# 4                    solana
# ..                      ...
# 110                usd-coin
# 111               ftx-token
# 112                  solana
# 113                  solana
# 114              terra-luna
#
# [115 rows x 16 columns]

# %%
deposits.loc[deposits.depositTokenCoingeckoId.isna()].currencyAddress
# Out:
# Series([], Name: currencyAddress, dtype: object)

# %%
deposits.shape
# Out:
# (115, 16)

# %%
deposits.loc[deposits.txSignature=="24y4KRma4BUarjw4y8Rv9Dt1kZdVVSP5kVnkbu4Ra5KMs7G9Df2Vb9C1b3M8f6yCuNuhsEW9s1WR8WrSKuN5bVBX"].iloc[0]
# Out:
# txSignature                24y4KRma4BUarjw4y8Rv9Dt1kZdVVSP5kVnkbu4Ra5KMs7...
# amount                                                                 551.0
# instructionAction                                                   transfer
# instructionOrder                                                         3-1
# userAddress                     9T19SkKUpSNbt2cMcCQVz7NZEfmXW3gdMDkH9db1yidw
# timestamp                                               2022-03-17T18:39:38Z
# currencyName                                                     Wrapped SOL
# currencyAddress                  So11111111111111111111111111111111111111112
# senderAddress                   9T19SkKUpSNbt2cMcCQVz7NZEfmXW3gdMDkH9db1yidw
# senderTokenMint                 D9QnLjbjTEBCqFZUrovoFkNW3B8gLmsJkT6PDt4HUv1H
# receiverAddress                  wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# globalId                                        mainnet_income_call_sol_high
# vaultAuthority                   wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# shareTokenMint                  DNa849drqW19uBV5X9ohpJ5brRGzq856gk3HDRqveFrA
# depositTokenSymbol                                                       SOL
# depositTokenCoingeckoId                                               solana
# Name: 2, dtype: object

# %%
deposits.loc[deposits.txSignature=="1kx6PYTANDwsAZGZ5xoRNe51uRK68k6roF6KYDauHQMmemH4JunDBCA47oHT2J1QUbh5YJHFdoZtQECqUVLVbZp"].iloc[0]
# Out:
# txSignature                1kx6PYTANDwsAZGZ5xoRNe51uRK68k6roF6KYDauHQMmem...
# amount                                                               0.99859
# instructionAction                                                   transfer
# instructionOrder                                                         1-1
# userAddress                     79jbRVMQu5rQkEcAPbzZNqnwKEASHyEyWgUn9q76yUKT
# timestamp                                               2022-03-17T19:33:26Z
# currencyName                                       Wrapped Ethereum (Sollet)
# currencyAddress                 2FPyTwcZLUg1MDrwsyoP4D6s1tM7hAkHYRjkNb5w6Pxk
# senderAddress                   79jbRVMQu5rQkEcAPbzZNqnwKEASHyEyWgUn9q76yUKT
# senderTokenMint                 3e81Tr2AGVLwPLLsUwiBSaYdGDwSxCMXmhF5ZWUuQAsn
# receiverAddress                 FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# globalId                                             mainnet_income_call_eth
# vaultAuthority                  FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# shareTokenMint                  GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS
# depositTokenSymbol                                                       ETH
# depositTokenCoingeckoId                                             ethereum
# Name: 0, dtype: object
