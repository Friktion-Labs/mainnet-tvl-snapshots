# %%
import json
import requests
import requests
import traceback
import time

import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from os.path import exists

# %%
df = pd.read_json("../../derived_timeseries/mainnet_income_call_sol_depositTokenByGlobalId.json")

# %%
df
# Out:
#                   0              1
# 0     1641159136000   84034.999963
# 1     1641159822000   84041.775963
# 2     1641160473000   84041.975963
# 3     1641161750000   84102.830463
# 4     1641162953000   84207.830463
# ...             ...            ...
# 5565  1651338999000  204144.122520
# 5566  1651348401000  204145.072520
# 5567  1651393130000  204154.072520
# 5568  1651395096000  204159.072520
# 5569  1651397352000  204161.377520
#
# [5570 rows x 2 columns]

# %%
z = df.groupby(pd.to_datetime(df[0], unit="ms").dt.week).first().values.tolist()
# Out:
# /var/folders/t5/lm3g0brx0dsf0ymt1ldc8xdr0000gp/T/ipykernel_1660/1024345963.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   z = df.groupby(pd.to_datetime(df[0], unit="ms").dt.week).first().values.tolist()

# %%
list(map(lambda x: [int(x[0]), x[1]], z))
# Out:
# [[1641171066000, 84285.122903016],
#  [1641775721000, 129456.099350644],
#  [1642380767000, 166847.05601187],
#  [1642982896000, 187698.942158812],
#  [1643588226000, 220778.585515986],
#  [1644193030000, 217296.087658274],
#  [1644799654000, 217129.228750781],
#  [1645403164000, 211744.583998592],
#  [1646009161000, 215659.964314888],
#  [1646619331000, 215915.113950005],
#  [1647217557000, 214856.321031107],
#  [1647822817000, 216955.112286199],
#  [1648427012000, 215853.075862774],
#  [1649038140000, 201312.754410741],
#  [1649643017000, 204736.239750945],
#  [1650241776000, 198620.862889071],
#  [1650847890000, 201263.318143213],
#  [1641159136000, 84034.999963016]]

# %%
xx = df.groupby(pd.to_datetime(df[0], unit="ms").dt.week).first()
# Out:
# /var/folders/t5/lm3g0brx0dsf0ymt1ldc8xdr0000gp/T/ipykernel_1660/1650705087.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   xx = df.groupby(pd.to_datetime(df[0], unit="ms").dt.week).first()

# %%
xx["time"] = pd.to_datetime(xx[0], unit='ms')
xx
# Out:
#                 0        1                time
# 0
# 8   1645607584000  1.00000 2022-02-23 09:13:04
# 9   1646358254000  1.00967 2022-03-04 01:44:14
# 10  1646961343000  1.01709 2022-03-11 01:15:43
# 11  1647558272000  1.02245 2022-03-17 23:04:32
# 12  1648167132000  1.02940 2022-03-25 00:12:12
# 13  1648768683000  1.00019 2022-03-31 23:18:03
# 14  1649374136000  1.00736 2022-04-07 23:28:56
# 15  1649988759000  1.01375 2022-04-15 02:12:39
# 16  1650354923000  1.01343 2022-04-19 07:55:23
# 17  1651191473000  1.02460 2022-04-29 00:17:53

# %%
z
# Out:
# [[1641536266000.0, 1.03765],
#  [1642123494000.0, 1.04513],
#  [1642485009000.0, 1.05342],
#  [1643341935000.0, 1.0587],
#  [1643953401000.0, 1.06779],
#  [1644553067000.0, 1.06967],
#  [1645167845000.0, 1.07281],
#  [1645745255000.0, 1.07944],
#  [1646358254000.0, 1.08401],
#  [1646962990000.0, 1.08905],
#  [1647556066000.0, 1.09476],
#  [1648167132000.0, 1.09869],
#  [1648769364000.0, 1.10107],
#  [1649374136000.0, 1.10446],
#  [1649991331000.0, 1.10859],
#  [1650354923000.0, 1.10813],
#  [1651195365000.0, 1.1157],
#  [1639712846000.0, 1.0],
#  [1640317646000.0, 1.02585],
#  [1640922446000.0, 1.03005]]

# %%
with open("test2.json", "w") as fl:
    json.dump(z, fl, separators=(",", ":"), indent=2)

# %%
fname = "../../derived_timeseries/mainnet_income_call_sol_sharePricesByGlobalId.json"
df = pd.read_json(fname)
vals = df.groupby(pd.to_datetime(df[0], unit="ms").dt.week).first().values
with open("./test", "w") as fl:
    json.dump(z, fl, separators=(",", ":"), indent=2)
# Out:
# /var/folders/t5/lm3g0brx0dsf0ymt1ldc8xdr0000gp/T/ipykernel_1660/2272411374.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   vals = df.groupby(pd.to_datetime(df[0], unit="ms").dt.week).first().values

# %%
df["time"] = pd.to_datetime(df[0], unit='ms')

# %%
df["week"] = df.time.dt.week
# Out:
# /var/folders/t5/lm3g0brx0dsf0ymt1ldc8xdr0000gp/T/ipykernel_1660/1907006362.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.time.dt.week

# %%
df["day"] = df.time.dt.dayofweek

# %%
df
# Out:
#                 0        1                time  week  day
# 0   1639712846000  1.00000 2021-12-17 03:47:26    50    4
# 1   1640317646000  1.02585 2021-12-24 03:47:26    51    4
# 2   1640922446000  1.03005 2021-12-31 03:47:26    52    4
# 3   1641536266000  1.03765 2022-01-07 06:17:46     1    4
# 4   1642123494000  1.04513 2022-01-14 01:24:54     2    4
# 5   1642485009000  1.05342 2022-01-18 05:50:09     3    1
# 6   1643341935000  1.05870 2022-01-28 03:52:15     4    4
# 7   1643953401000  1.06779 2022-02-04 05:43:21     5    4
# 8   1644553067000  1.06967 2022-02-11 04:17:47     6    4
# 9   1645167845000  1.07281 2022-02-18 07:04:05     7    4
# 10  1645745255000  1.07944 2022-02-24 23:27:35     8    3
# 11  1646358254000  1.08401 2022-03-04 01:44:14     9    4
# 12  1646962990000  1.08905 2022-03-11 01:43:10    10    4
# 13  1647556066000  1.09476 2022-03-17 22:27:46    11    3
# 14  1648167132000  1.09869 2022-03-25 00:12:12    12    4
# ...

# %%
df.groupby("week").first().values
# Out:
# array([[1641536266000, 1.06504, Timestamp('2022-01-07 06:17:46')],
#        [1642123494000, 1.06847, Timestamp('2022-01-14 01:24:54')],
#        [1642483587000, 1.06976, Timestamp('2022-01-18 05:26:27')],
#        [1643344243000, 1.07217, Timestamp('2022-01-28 04:30:43')],
