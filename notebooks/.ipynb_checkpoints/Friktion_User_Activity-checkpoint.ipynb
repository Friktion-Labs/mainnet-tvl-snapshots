# %%
"""
Python script to scrape Friktion User Data from Bitquery GraphQL API.

"""

import json
import requests
import requests
import traceback
import time

import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from os.path import exists


class MyPortfolio:
    """
    Python ETL script for Friktion user portfolio data. Currently supported Instruction Names:
        - Deposit
        - CancelPendingDeposit
        - Withdrawal
        - CancelPendingWithdrawal
        - ClaimPendingWithdrawal
    """

    def __init__(
        self,
        date_start,
        date_end,
        ix_fname="./friktion_ix.csv",
        deposit_fname="./friktion_deposit.csv",
        deposit_cxl_fname="./friktion_deposit_cxl.csv",
        withdraw_fname="./friktion_withdraw.csv",
        withdraw_cxl_fname="./friktion_withdraw_cancel.csv",
        withdraw_claim_fname="./friktion_claim_withdrawal.csv",
        batch_size_days=2,
        batch_size_xfers=90,
        skip_ix_scrape=False
    ):
        """
        :ix_fname:              output csv for instructions
        :deposit_fname:         output csv for deposits
        :deposit_cxl_fname:     output csv for deposit cancels
        :withdraw_fname:        output csv for withdrawals
        :withdraw_cxl_fname:    output csv for withdrawal cancels
        :withdraw_claim_fname:  output csv for claiming pending withdrawal
        :batch_size_days:       batch size in days for query to keep query < 10k symbols. Use bigger steps for larger data.
        :batch_size_transfers:  batch size transactions for query to keep query < 8kb

        """
        self.volt_program = "VoLT1mJz1sbnxwq5Fv2SXjdVDgPXrb9tJyC8WpMDkSp"
        self.date_start = date_start
        self.date_end = date_end
        self.ix_fname = ix_fname
        self.deposit_fname = deposit_fname
        self.deposit_cxl_fname = deposit_cxl_fname
        self.withdraw_fname = withdraw_fname
        self.withdraw_cxl_fname = withdraw_cxl_fname
        self.withdraw_claim_fname = withdraw_claim_fname
        self.batch_size_days = batch_size_days
        self.batch_size_xfers = batch_size_xfers
        self.skip_ix_scrape = skip_ix_scrape
        
        self.df_ix = pd.read_csv(ix_fname) if skip_ix_scrape else [] 
        self.friktion_metadata = self.get_friktion_snapshot()

    ########################################################################################################
    ####################################          Queries             ######################################
    ########################################################################################################

    @property
    def ix_query(self):
        return """
            query MyQuery {
              solana {
                instructions(
                  time: {between: ["%s", "%s"]}
                  success: {is: true}
                  programId: {is: "VoLT1mJz1sbnxwq5Fv2SXjdVDgPXrb9tJyC8WpMDkSp"}
                  options: {limit: 8700}
                ) {
                  block {
                    timestamp {
                      iso8601
                    }
                  }
                  transaction {
                    signature
                    feePayer
                  }
                  data {
                    base58
                  }
                }
              }
            }
        """

    @property
    def xfer_query(self):
        return """
            query MyQuery {
              solana(network: solana) {
                transfers(
                  signature: {in: [%s]}
                  options: {limit: 2000}
                ) {
                  instruction {
                    action {
                      name
                    }
                    callPath
                  }
                  amount(success: {is: true})
                  transaction {
                    signer
                    signature
                  }
                  block {
                    timestamp {
                      iso8601
                    }
                  }
                  currency {
                    name
                    address
                  }
                  sender {
                    address
                    mintAccount
                  }
                  receiver {
                    address
                  }
                }
              }
            }
        """

    ########################################################################################################
    ################################          Helper Functions             #################################
    ########################################################################################################

    # TODO: Add retry logic to this in case of hangups.
    @staticmethod
    def run_query(query, retries=10):
        """
        Query graphQL API.

        If timeerror
        """
        headers = {"X-API-KEY": "BQYCaXaMZlqZrPCSQVsiJrKtxKRVcSe4"}

        retries_counter = 0
        try:
            request = requests.post(
                "https://graphql.bitquery.io/", json={"query": query}, headers=headers
            )
            result = request.json()
            # print(dir(request.content))
            # Make sure that there is no error message
            # assert not request.content.errors
            assert "errors" not in result
        except:
            while (
                (request.status_code != 200
                or "errors" in result)
                and retries_counter < 10
            ):
                print(datetime.now(), f"Retry number {retries_counter}")
                if "errors" in result:
                    print(result["errors"])
                print(datetime.now(), f"Query failed for reason: {request.reason}. sleeping for {150*retries_counter} seconds and retrying...")
                time.sleep(150*retries_counter)
                request = requests.post(
                    "https://graphql.bitquery.io/",
                    json={"query": query},
                    headers=headers,
                )
                retries_counter += 1
            if retries_counter >= retries:
                raise Exception(
                    "Query failed after {} retries and return code is {}.{}".format(
                        retries_counter, request.status_code, query
                    )
                )
        return request.json()


    @staticmethod
    def batch_iterable(iterable, n=1):
        """
        Takes in an iterable and returns an iterable of iterables with len==x
        """
        idxs = []
        l = len(iterable)
        for idx in range(0, l, n):
            idxs.append(iterable[idx : min(idx + n, l)])
        return idxs

    def format_txs_for_query(self, tx_signatures):
        """
        Batches a list of transactions into a list of string formatted transactions for querying.
        Each of these strings contain (n=self.batch_size_xfers) unique transaction IDs.
        """
        batched_signatures = self.batch_iterable(tx_signatures, self.batch_size_xfers)

        def format_txs(x):
            return str(x)[1:-1].replace("'", '"').replace("\n", "")

        tx_strs = list(map(format_txs, batched_signatures))

        return tx_strs

    def get_existing_df(self, fname):
        """
        Create output file if doesn't exist and returns a DataFrame
        """
        if fname and exists(fname):
            return pd.read_csv(fname)
        else:
            return pd.DataFrame()

    @staticmethod
    def instruction_match(instructionData):
        """
        Match 8-bit instruction identifier with the corresonding instructionType
        """
        if not instructionData or len(instructionData) < 8:
            return False

        instructionDescriptor = instructionData[:8]

        if instructionDescriptor == "PcB3tF1K":
            return "Withdraw"
        elif instructionDescriptor == "WuE7Hjns":
            return "Deposit"
        elif instructionDescriptor == "V8cW2nMq":
            return "CancelPendingDeposit"
        elif instructionDescriptor == "dxUbSCWk":
            return "CancelPendingWithdrawal"
        elif instructionDescriptor == "WcTWQsnk":
            return "ClaimPendingWithdrawal"
        else:
            return "Unclassified"

    def get_friktion_snapshot(self):
        """
        Load Friktion Metadata for Volt/Symbol Mapping to join to normal data

        """
        try:
            return pd.DataFrame(
                dict(
                    json.loads(
                        requests.get(
                            "https://friktion-labs.github.io/mainnet-tvl-snapshots/friktionSnapshot.json"
                        ).content
                    )
                )["allMainnetVolts"]
            )[
                [
                    "globalId",
                    "vaultAuthority",
                    "shareTokenMint",
                    "depositTokenSymbol",
                    "depositTokenCoingeckoId",
                ]
            ]
        except Exception as e:
            print(datetime.now(), "Snapshot Data Invalid")
            traceback.print_exc()

    ########################################################################################################
    ################################          Data Retrieval             ###################################
    ########################################################################################################

    def get_ix(self, date_start, date_end):
        """
        Runs graphql instruction query for one date range.
        """
        print(date_start, date_end)
        query = self.ix_query % (date_start, date_end)
        print(
            datetime.now(),
            "retrieving instructions for {} to {}".format(date_start, date_end),
        )
        result = self.run_query(query)

        # convert GraphQL json to pandas dataframe
        try:
            df = pd.json_normalize(result["data"]["solana"]["instructions"])
        except:
            print(result)
            traceback.print_exc()
            raise Exception(datetime.now(), "Empty Results... Try Again")

        print(datetime.now(), df.shape[0], "instructions retrieved")

        df = df.rename(
            columns={
                "block.timestamp.iso8601": "timestamp",
                "log.consumed": "computeUnits",
                "transaction.signature": "txSignature",
                "transaction.feePayer": "txSigner",
                "data.base58": "instructionData",
            }
        )
        return df

    def get_ix_batch(self):
        """
        Batch the instruction retrieval. Save the shit Drop duplicates.

        """
        # Batch the days up nice and good so the graphql API calls don't bitch
        dates_batched = pd.date_range(self.date_start, self.date_end, freq=f"{self.batch_size_days}D")
        dates_batched = [
            str(x.isoformat())
            for x in dates_batched.append(pd.DatetimeIndex([self.date_end]))
        ]
        date_ranges = list(zip(dates_batched, dates_batched[1:]))
        ixs = []
        for date_range in date_ranges:
            assert len(date_range) == 2
            data = self.get_ix(date_range[0], date_range[1])
            ixs.append(data)

        df_ix = pd.concat(ixs, ignore_index=False)
        df_ix["instructionType"] = df_ix.instructionData.apply(
            lambda x: self.instruction_match(x)
        )

        # Store df_ix before we write it to the DataFrame so we avoid getting xfers for every single ix
        self.df_ix = df_ix.drop_duplicates(["txSignature", "instructionType"])
        print(datetime.now(), "final instruction data size: ", df_ix.shape[0])

        # Save new data to file
        df_old = self.get_existing_df(self.ix_fname)
        df = df_ix.append(df_old).reset_index(drop=True)
        df = df.drop_duplicates(["txSignature", "instructionType"])
        df.to_csv(self.ix_fname, index=False)
        print(datetime.now(), "wrote instruction data to csv...")

    def get_batched_xfers(self, instructionType, fname):
        """
        Get all transfers corresponding to a specific instructionType from Graphql query.
        Batch these queries up b/c the string size is
        too large (curse GraphQL for not supporting joins)

        :instructionType: String corresponding to the instruction type of each query.
        :fname: Name of where the old df is stored

        """

        temp = self.df_ix.query(f"instructionType == '{instructionType}'")

        if temp.empty:
            print(
                datetime.now(), "instructionType was not found in the data... breaking"
            )
            return

        tx_signatures = list(temp["txSignature"].unique())
        tx_strs = self.format_txs_for_query(tx_signatures)
        print(datetime.now(), len(tx_strs), "signature batches required...")
        xfers = []

        for i, tx_str in enumerate(tx_strs):
            query = self.xfer_query % (tx_str)
            result = self.run_query(query)
            # TODO: Clean up this duplicated logic
            try:
                df = pd.json_normalize(result["data"]["solana"]["transfers"])
            except:
                print(result)
                traceback.print_exc()
                raise Exception("Empty Results... Try Again")
            xfers.append(df)
            print(datetime.now(), df.shape[0], "transfers scraped in batch %d" % i)

        df_xfer = pd.concat(xfers, ignore_index=False)
        df_xfer = df_xfer.rename(
            columns={
                "block.timestamp.iso8601": "timestamp",
                "instruction.action.name": "instructionAction",
                "instruction.callPath": "instructionOrder",
                "transaction.signer": "userAddress",
                "transaction.signature": "txSignature",
                "currency.name": "currencyName",
                "receiver.address": "receiverAddress",
                "sender.address": "senderAddress",
                "currency.decimals": "currencyDecimals",
                "currency.address": "currencyAddress",
                "sender.mintAccount": "senderTokenMint",
            }
        )

        print(datetime.now(), df_xfer.shape[0], "transfers retrieved")

        df_old = self.get_existing_df(fname)
        df_final = df_old.append(df_xfer, ignore_index=True).sort_values(
            "instructionOrder"
        )

        return df_final

    def parse_deposits(self):
        instructionType = "Deposit"
        instructionAction = "transfer"
        tx_merge_key = "receiverAddress"
        meta_merge_key = "vaultAuthority"
        out_file = self.deposit_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_withdrawal(self):
        instructionType = "Withdraw"
        instructionAction = "burn"
        tx_merge_key = "currencyAddress"
        meta_merge_key = "shareTokenMint"
        out_file = self.withdraw_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_deposit_cancel(self):
        instructionType = "CancelPendingDeposit"
        instructionAction = "transfer"
        tx_merge_key = "senderAddress"
        meta_merge_key = "vaultAuthority"
        out_file = self.deposit_cxl_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_withdrawal_cancel(self):
        instructionType = "CancelPendingWithdrawal"
        instructionAction = "mintTo"
        tx_merge_key = "currencyAddress"
        meta_merge_key = "shareTokenMint"
        out_file = self.withdraw_cxl_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_claim_withdrawal(self):
        instructionType = "ClaimPendingWithdrawal"
        instructionAction = "transfer"
        tx_merge_key = "senderAddress"
        meta_merge_key = "vaultAuthority"
        out_file = self.withdraw_claim_fname

        self.parse_base(
            instructionType, instructionAction, tx_merge_key, meta_merge_key, out_file
        )

    def parse_base(
        self,
        instructionType,
        instructionAction,
        tx_merge_key,
        meta_merge_key,
        output_file,
    ):
        """
        generalized method for parsing transfer data.

        1. Call get_batched_xfers()
        2. for each unique txSignature, find the xfer matching to the last instance of the instructionAction
        3. For SOL CC vaults, need an extra step and query for instructionAccount to find vaultAuthority.
        3. Join it to the friktion metadata based using tx_merge_key and meta_merge_key
        4. Drop extraneous rows
        5. Save the file to the output_file

        :instructionType: Type of instruction listed out in the instruction_match() method
        :instructionAction: type of transfer we are matching towards
        :tx_merge_key: what key in the xfer dataFrame do we want to merge on
        :meta_merge_key: what key in the metadata dataFrame we want to merge on.
        :output_file: as name suggests
        """
        print(
            datetime.now(),
            "Parsing transfers for instructionType: %s" % instructionType,
        )
        df = self.get_batched_xfers(instructionType, output_file)

        # Target only wrapped SOL entries for SOL vaults
        df = df.query('currencyName != "Solana"')

        df = (
            df.query('instructionAction=="{}"'.format(instructionAction))
            .groupby("txSignature")
            .last()
            .reset_index()
        )

        # Join tables and get rid of extraneous columns from metadata.
        df = pd.merge(
            df,
            self.friktion_metadata,
            how="left",
            left_on=tx_merge_key,
            right_on=meta_merge_key,
            suffixes=("", "_drop"),
        )
        df.drop([col for col in df.columns if "drop" in col], axis=1, inplace=True)

        # Tag the row with the instructionType
        df["userAction"] = instructionType

        df.drop_duplicates().to_csv(output_file, index=False)
        print(datetime.now(), "{} data size: {}".format(instructionType, df.shape[0]))

    def parse_all(self):
        if not self.skip_ix_scrape:
            self.get_ix_batch()
#         self.parse_claim_withdrawal()
#         self.parse_deposit_cancel()
#         self.parse_withdrawal_cancel()
#         self.parse_withdrawal()
        self.parse_deposits()

    ########################################################################################################
    #####################################          Tests             #######################################
    ########################################################################################################

    def check_fidelity(self):
        ix = pd.read_csv(self.ix_fname)
        deposits = pd.read_csv(self.deposit_fname)
        withdrawals = pd.read_csv(self.withdraw_fname)
        claim = pd.read_csv(self.withdraw_claim_fname)
        withdrawals_cxl = pd.read_csv(self.withdraw_cxl_fname)
        deposits_cxl = pd.read_csv(self.deposit_cxl_fname)

        assert ix.loc[ix.instructionType == "Deposit"].shape[0] == deposits.shape[0]
        assert ix.loc[ix.instructionType == "Withdraw"].shape[0] == withdrawals.shape[0]
        assert (
            ix.loc[ix.instructionType == "ClaimPendingWithdrawal"].shape[0]
            == claim.shape[0]
        )
        assert (
            ix.loc[ix.instructionType == "CancelPendingDeposit"].shape[0]
            == deposits_cxl.shape[0]
        )
        assert (
            ix.loc[ix.instructionType == "CancelPendingWithdrawal"].shape[0]
            == withdrawals_cxl.shape[0]
        )


# if __name__ == "__main__":
#     date_start = "2021-12-16T16:00:00Z"
#     date_end = "2022-04-01T00:00:00Z"

#     x = MyPortfolio(date_start, date_end)
#     x.parse_all()
#     x.check_fidelity()

# %%
date_start = "2021-12-16T00:00:00Z"
date_end = "2022-04-02T00:00:00Z"

x = MyPortfolio(date_start, date_end, skip_ix_scrape=True)

x.parse_all()

x.check_fidelity()
# Out:
# 2022-03-31 23:18:01.999634 Parsing transfers for instructionType: Deposit
# 2022-03-31 23:18:02.024449 327 signature batches required...
# 2022-03-31 23:18:18.631101 603 transfers scraped in batch 0
# 2022-03-31 23:18:22.899072 654 transfers scraped in batch 1
# 2022-03-31 23:18:26.838003 666 transfers scraped in batch 2
# 2022-03-31 23:18:32.054840 686 transfers scraped in batch 3
# 2022-03-31 23:18:39.734666 658 transfers scraped in batch 4
# 2022-03-31 23:18:43.800017 662 transfers scraped in batch 5
# 2022-03-31 23:18:48.514870 757 transfers scraped in batch 6
# 2022-03-31 23:18:52.247444 637 transfers scraped in batch 7
# 2022-03-31 23:18:55.756871 686 transfers scraped in batch 8
# 2022-03-31 23:18:59.167914 594 transfers scraped in batch 9
# 2022-03-31 23:19:02.488276 535 transfers scraped in batch 10
# 2022-03-31 23:19:08.051109 602 transfers scraped in batch 11
# 2022-03-31 23:19:11.602309 558 transfers scraped in batch 12
# 2022-03-31 23:19:15.127787 546 transfers scraped in batch 13
# 2022-03-31 23:19:18.893636 519 transfers scraped in batch 14
# 2022-03-31 23:19:27.652953 697 transfers scraped in batch 15
# 2022-03-31 23:19:32.016201 635 transfers scraped in batch 16
# 2022-03-31 23:19:35.467440 648 transfers scraped in batch 17
# 2022-03-31 23:19:38.792141 562 transfers scraped in batch 18
# 2022-03-31 23:19:43.736323 445 transfers scraped in batch 19
# 2022-03-31 23:19:46.935328 442 transfers scraped in batch 20
# 2022-03-31 23:19:49.960144 384 transfers scraped in batch 21
# 2022-03-31 23:19:53.154059 456 transfers scraped in batch 22
# 2022-03-31 23:19:58.970387 390 transfers scraped in batch 23
# 2022-03-31 23:20:02.396672 391 transfers scraped in batch 24
# 2022-03-31 23:20:05.667646 383 transfers scraped in batch 25
# 2022-03-31 23:20:10.490911 390 transfers scraped in batch 26
# 2022-03-31 23:20:22.277516 424 transfers scraped in batch 27
# 2022-03-31 23:20:28.486130 523 transfers scraped in batch 28
# 2022-03-31 23:20:35.960607 503 transfers scraped in batch 29
# 2022-03-31 23:20:48.394701 635 transfers scraped in batch 30
# 2022-03-31 23:20:59.002970 559 transfers scraped in batch 31
# 2022-03-31 23:21:04.452040 554 transfers scraped in batch 32
# 2022-03-31 23:21:08.511720 482 transfers scraped in batch 33
# 2022-03-31 23:21:16.895319 334 transfers scraped in batch 34
# 2022-03-31 23:21:21.171890 339 transfers scraped in batch 35
# 2022-03-31 23:21:24.065438 294 transfers scraped in batch 36
# 2022-03-31 23:21:27.569845 327 transfers scraped in batch 37
# 2022-03-31 23:21:34.227068 313 transfers scraped in batch 38
# 2022-03-31 23:21:39.932675 306 transfers scraped in batch 39
# 2022-03-31 23:21:43.446764 309 transfers scraped in batch 40
# 2022-03-31 23:21:46.469526 340 transfers scraped in batch 41
# 2022-03-31 23:21:49.465489 317 transfers scraped in batch 42
# 2022-03-31 23:21:54.458043 324 transfers scraped in batch 43
# 2022-03-31 23:21:58.940475 335 transfers scraped in batch 44
# 2022-03-31 23:22:02.462512 357 transfers scraped in batch 45
# 2022-03-31 23:22:05.581239 325 transfers scraped in batch 46
# 2022-03-31 23:22:08.798823 319 transfers scraped in batch 47
# 2022-03-31 23:22:11.751084 294 transfers scraped in batch 48
# 2022-03-31 23:22:14.725543 304 transfers scraped in batch 49
# 2022-03-31 23:22:21.494299 312 transfers scraped in batch 50
# 2022-03-31 23:22:26.344110 361 transfers scraped in batch 51
# 2022-03-31 23:22:30.182183 265 transfers scraped in batch 52
# 2022-03-31 23:22:33.394781 217 transfers scraped in batch 53
# 2022-03-31 23:22:36.230153 242 transfers scraped in batch 54
# 2022-03-31 23:22:40.567123 243 transfers scraped in batch 55
# 2022-03-31 23:22:43.249963 238 transfers scraped in batch 56
# 2022-03-31 23:22:46.807261 234 transfers scraped in batch 57
# 2022-03-31 23:22:49.637198 251 transfers scraped in batch 58
# 2022-03-31 23:22:52.391512 328 transfers scraped in batch 59
# 2022-03-31 23:22:57.374869 348 transfers scraped in batch 60
# 2022-03-31 23:23:00.479777 322 transfers scraped in batch 61
# 2022-03-31 23:23:03.445395 346 transfers scraped in batch 62
# 2022-03-31 23:23:06.997387 372 transfers scraped in batch 63
# 2022-03-31 23:23:21.103765 369 transfers scraped in batch 64
# 2022-03-31 23:23:26.126579 417 transfers scraped in batch 65
# 2022-03-31 23:23:31.862898 386 transfers scraped in batch 66
# 2022-03-31 23:23:41.792047 386 transfers scraped in batch 67
# 2022-03-31 23:23:48.303417 398 transfers scraped in batch 68
# 2022-03-31 23:23:51.615629 430 transfers scraped in batch 69
# 2022-03-31 23:23:54.746273 430 transfers scraped in batch 70
# 2022-03-31 23:23:57.631734 393 transfers scraped in batch 71
# 2022-03-31 23:24:04.738718 359 transfers scraped in batch 72
# 2022-03-31 23:24:09.016887 346 transfers scraped in batch 73
# 2022-03-31 23:24:11.810341 226 transfers scraped in batch 74
# 2022-03-31 23:24:14.789679 392 transfers scraped in batch 75
# 2022-03-31 23:24:17.734294 345 transfers scraped in batch 76
# 2022-03-31 23:24:23.069883 288 transfers scraped in batch 77
# 2022-03-31 23:24:28.321818 289 transfers scraped in batch 78
# 2022-03-31 23:24:32.035245 296 transfers scraped in batch 79
# 2022-03-31 23:24:35.876825 346 transfers scraped in batch 80
# 2022-03-31 23:24:38.579293 312 transfers scraped in batch 81
# 2022-03-31 23:24:43.769495 310 transfers scraped in batch 82
# 2022-03-31 23:24:46.941938 285 transfers scraped in batch 83
# 2022-03-31 23:24:49.799811 332 transfers scraped in batch 84
# 2022-03-31 23:24:53.028416 411 transfers scraped in batch 85
# 2022-03-31 23:24:56.253213 426 transfers scraped in batch 86
# 2022-03-31 23:24:59.913486 469 transfers scraped in batch 87
# 2022-03-31 23:25:04.957412 474 transfers scraped in batch 88
# 2022-03-31 23:25:08.294950 415 transfers scraped in batch 89
# 2022-03-31 23:25:12.109187 463 transfers scraped in batch 90
# 2022-03-31 23:25:15.121294 306 transfers scraped in batch 91
# 2022-03-31 23:25:18.145904 386 transfers scraped in batch 92
# 2022-03-31 23:25:21.316361 326 transfers scraped in batch 93
# 2022-03-31 23:25:25.224169 412 transfers scraped in batch 94
# 2022-03-31 23:25:37.772768 412 transfers scraped in batch 95
# 2022-03-31 23:25:43.957911 353 transfers scraped in batch 96
# 2022-03-31 23:25:56.876380 426 transfers scraped in batch 97
# 2022-03-31 23:26:17.843002 408 transfers scraped in batch 98
# 2022-03-31 23:26:24.189423 525 transfers scraped in batch 99
# 2022-03-31 23:26:31.601919 404 transfers scraped in batch 100
# 2022-03-31 23:26:36.909428 296 transfers scraped in batch 101
# 2022-03-31 23:26:39.958017 340 transfers scraped in batch 102
# 2022-03-31 23:26:43.252329 319 transfers scraped in batch 103
# 2022-03-31 23:26:48.370956 315 transfers scraped in batch 104
# 2022-03-31 23:26:51.180343 327 transfers scraped in batch 105
# 2022-03-31 23:26:54.000898 352 transfers scraped in batch 106
# 2022-03-31 23:26:57.141229 420 transfers scraped in batch 107
# 2022-03-31 23:27:00.179419 313 transfers scraped in batch 108
# 2022-03-31 23:27:09.346395 321 transfers scraped in batch 109
# 2022-03-31 23:27:19.126626 337 transfers scraped in batch 110
# 2022-03-31 23:27:26.160838 348 transfers scraped in batch 111
# 2022-03-31 23:27:29.797677 317 transfers scraped in batch 112
# 2022-03-31 23:27:34.986694 331 transfers scraped in batch 113
# 2022-03-31 23:27:39.011862 300 transfers scraped in batch 114
# 2022-03-31 23:27:46.930833 361 transfers scraped in batch 115
# 2022-03-31 23:27:53.963896 316 transfers scraped in batch 116
# 2022-03-31 23:27:58.523273 407 transfers scraped in batch 117
# 2022-03-31 23:28:01.839398 414 transfers scraped in batch 118
# 2022-03-31 23:28:04.918904 388 transfers scraped in batch 119
# 2022-03-31 23:28:10.311741 393 transfers scraped in batch 120
# 2022-03-31 23:28:13.359956 409 transfers scraped in batch 121
# 2022-03-31 23:28:16.625251 410 transfers scraped in batch 122
# 2022-03-31 23:28:20.129355 478 transfers scraped in batch 123
# 2022-03-31 23:28:23.817202 551 transfers scraped in batch 124
# 2022-03-31 23:28:31.644900 454 transfers scraped in batch 125
# 2022-03-31 23:28:35.445163 436 transfers scraped in batch 126
# 2022-03-31 23:28:43.029123 470 transfers scraped in batch 127
# 2022-03-31 23:28:46.330230 460 transfers scraped in batch 128
# 2022-03-31 23:28:50.742489 514 transfers scraped in batch 129
# 2022-03-31 23:28:54.652682 465 transfers scraped in batch 130
# 2022-03-31 23:29:06.143781 468 transfers scraped in batch 131
# 2022-03-31 23:29:09.619357 365 transfers scraped in batch 132
# 2022-03-31 23:29:13.396216 461 transfers scraped in batch 133
# 2022-03-31 23:29:16.635013 453 transfers scraped in batch 134
# 2022-03-31 23:29:19.913782 448 transfers scraped in batch 135
# 2022-03-31 23:29:25.188712 395 transfers scraped in batch 136
# 2022-03-31 23:29:28.920513 417 transfers scraped in batch 137
# 2022-03-31 23:29:32.492760 476 transfers scraped in batch 138
# 2022-03-31 23:29:35.721060 405 transfers scraped in batch 139
# 2022-03-31 23:29:41.362614 366 transfers scraped in batch 140
# 2022-03-31 23:29:44.423901 431 transfers scraped in batch 141
# 2022-03-31 23:29:47.551736 419 transfers scraped in batch 142
# 2022-03-31 23:29:50.687920 483 transfers scraped in batch 143
# 2022-03-31 23:29:57.088540 394 transfers scraped in batch 144
# 2022-03-31 23:30:01.432499 366 transfers scraped in batch 145
# 2022-03-31 23:30:05.684372 358 transfers scraped in batch 146
# 2022-03-31 23:30:08.923358 437 transfers scraped in batch 147
# 2022-03-31 23:30:15.293291 379 transfers scraped in batch 148
# 2022-03-31 23:30:18.955271 375 transfers scraped in batch 149
# 2022-03-31 23:30:23.724844 323 transfers scraped in batch 150
# 2022-03-31 23:30:30.026590 368 transfers scraped in batch 151
# 2022-03-31 23:30:37.318452 321 transfers scraped in batch 152
# 2022-03-31 23:30:41.007234 340 transfers scraped in batch 153
# 2022-03-31 23:30:43.982800 392 transfers scraped in batch 154
# 2022-03-31 23:30:47.162137 385 transfers scraped in batch 155
# 2022-03-31 23:30:49.990351 315 transfers scraped in batch 156
# 2022-03-31 23:30:53.837430 406 transfers scraped in batch 157
# 2022-03-31 23:31:03.202138 388 transfers scraped in batch 158
# 2022-03-31 23:31:08.959885 445 transfers scraped in batch 159
# 2022-03-31 23:31:13.141934 398 transfers scraped in batch 160
# 2022-03-31 23:31:23.567017 401 transfers scraped in batch 161
# 2022-03-31 23:31:31.148645 331 transfers scraped in batch 162
# 2022-03-31 23:31:40.424678 376 transfers scraped in batch 163
# 2022-03-31 23:31:45.302006 378 transfers scraped in batch 164
# 2022-03-31 23:31:48.911703 387 transfers scraped in batch 165
# 2022-03-31 23:31:51.932557 399 transfers scraped in batch 166
# 2022-03-31 23:31:55.017412 417 transfers scraped in batch 167
# 2022-03-31 23:32:00.906965 442 transfers scraped in batch 168
# 2022-03-31 23:32:03.705779 331 transfers scraped in batch 169
# 2022-03-31 23:32:06.648103 387 transfers scraped in batch 170
# 2022-03-31 23:32:09.471165 348 transfers scraped in batch 171
# 2022-03-31 23:32:12.244965 325 transfers scraped in batch 172
# 2022-03-31 23:32:14.986469 344 transfers scraped in batch 173
# 2022-03-31 23:32:18.588379 464 transfers scraped in batch 174
# 2022-03-31 23:32:22.088657 394 transfers scraped in batch 175
# 2022-03-31 23:32:30.276106 420 transfers scraped in batch 176
# 2022-03-31 23:32:35.033654 489 transfers scraped in batch 177
# 2022-03-31 23:32:39.278350 369 transfers scraped in batch 178
# 2022-03-31 23:32:43.518253 333 transfers scraped in batch 179
# 2022-03-31 23:32:49.212871 423 transfers scraped in batch 180
# 2022-03-31 23:32:52.261693 429 transfers scraped in batch 181
# 2022-03-31 23:32:55.268317 436 transfers scraped in batch 182
# 2022-03-31 23:32:58.332631 430 transfers scraped in batch 183
# 2022-03-31 23:33:03.937260 415 transfers scraped in batch 184
# 2022-03-31 23:33:07.131454 442 transfers scraped in batch 185
# 2022-03-31 23:33:11.874357 454 transfers scraped in batch 186
# 2022-03-31 23:33:15.791966 333 transfers scraped in batch 187
# 2022-03-31 23:33:21.880025 418 transfers scraped in batch 188
# 2022-03-31 23:33:26.445839 331 transfers scraped in batch 189
# 2022-03-31 23:33:30.550891 478 transfers scraped in batch 190
# 2022-03-31 23:33:34.606614 488 transfers scraped in batch 191
# 2022-03-31 23:33:38.308151 342 transfers scraped in batch 192
# 2022-03-31 23:33:46.292013 343 transfers scraped in batch 193
# 2022-03-31 23:33:49.513989 403 transfers scraped in batch 194
# 2022-03-31 23:33:56.301815 450 transfers scraped in batch 195
# 2022-03-31 23:34:04.422292 338 transfers scraped in batch 196
# 2022-03-31 23:34:07.559710 376 transfers scraped in batch 197
# 2022-03-31 23:34:10.842174 359 transfers scraped in batch 198
# 2022-03-31 23:34:13.705544 352 transfers scraped in batch 199
# 2022-03-31 23:34:16.876130 375 transfers scraped in batch 200
# 2022-03-31 23:34:23.658690 430 transfers scraped in batch 201
# 2022-03-31 23:34:28.861882 355 transfers scraped in batch 202
# 2022-03-31 23:34:32.790567 424 transfers scraped in batch 203
# 2022-03-31 23:34:36.115734 527 transfers scraped in batch 204
# 2022-03-31 23:34:39.113343 384 transfers scraped in batch 205
# 2022-03-31 23:34:44.531348 460 transfers scraped in batch 206
# 2022-03-31 23:34:47.591057 403 transfers scraped in batch 207
# 2022-03-31 23:34:50.640296 405 transfers scraped in batch 208
# 2022-03-31 23:34:53.686778 402 transfers scraped in batch 209
# 2022-03-31 23:34:56.823817 431 transfers scraped in batch 210
# 2022-03-31 23:35:01.326361 414 transfers scraped in batch 211
# 2022-03-31 23:35:04.806208 408 transfers scraped in batch 212
# 2022-03-31 23:35:07.909495 422 transfers scraped in batch 213
# 2022-03-31 23:35:10.867608 348 transfers scraped in batch 214
# 2022-03-31 23:35:13.745617 319 transfers scraped in batch 215
# 2022-03-31 23:35:17.498398 368 transfers scraped in batch 216
# 2022-03-31 23:35:24.196739 294 transfers scraped in batch 217
# 2022-03-31 23:35:28.498136 383 transfers scraped in batch 218
# 2022-03-31 23:35:32.386617 436 transfers scraped in batch 219
# 2022-03-31 23:35:35.784862 463 transfers scraped in batch 220
# 2022-03-31 23:35:38.946637 465 transfers scraped in batch 221
# 2022-03-31 23:35:42.014226 436 transfers scraped in batch 222
# 2022-03-31 23:35:45.274648 358 transfers scraped in batch 223
# 2022-03-31 23:35:50.053196 350 transfers scraped in batch 224
# 2022-03-31 23:35:53.170260 381 transfers scraped in batch 225
# 2022-03-31 23:35:56.370189 366 transfers scraped in batch 226
# 2022-03-31 23:35:59.273916 338 transfers scraped in batch 227
# 2022-03-31 23:36:06.452465 413 transfers scraped in batch 228
# 2022-03-31 23:36:22.117603 346 transfers scraped in batch 229
# 2022-03-31 23:36:35.856355 369 transfers scraped in batch 230
# 2022-03-31 23:36:48.352395 346 transfers scraped in batch 231
# 2022-03-31 23:37:00.898167 409 transfers scraped in batch 232
# 2022-03-31 23:37:09.788141 405 transfers scraped in batch 233
# 2022-03-31 23:37:13.733163 432 transfers scraped in batch 234
# 2022-03-31 23:37:17.119652 436 transfers scraped in batch 235
# 2022-03-31 23:37:20.305241 452 transfers scraped in batch 236
# 2022-03-31 23:37:24.048969 396 transfers scraped in batch 237
# 2022-03-31 23:37:28.341371 421 transfers scraped in batch 238
# 2022-03-31 23:37:32.187482 394 transfers scraped in batch 239
# 2022-03-31 23:37:35.805892 404 transfers scraped in batch 240
# 2022-03-31 23:37:39.639285 383 transfers scraped in batch 241
# 2022-03-31 23:37:45.738099 465 transfers scraped in batch 242
# 2022-03-31 23:37:48.965418 452 transfers scraped in batch 243
# 2022-03-31 23:37:52.073873 485 transfers scraped in batch 244
# 2022-03-31 23:37:55.237301 445 transfers scraped in batch 245
# 2022-03-31 23:37:58.853060 399 transfers scraped in batch 246
# 2022-03-31 23:38:03.896374 361 transfers scraped in batch 247
# 2022-03-31 23:38:06.864047 344 transfers scraped in batch 248
# 2022-03-31 23:38:09.866864 379 transfers scraped in batch 249
# 2022-03-31 23:38:13.064448 413 transfers scraped in batch 250
# 2022-03-31 23:38:16.226922 409 transfers scraped in batch 251
# 2022-03-31 23:38:23.554562 413 transfers scraped in batch 252
# 2022-03-31 23:38:27.171545 362 transfers scraped in batch 253
# 2022-03-31 23:38:30.687167 324 transfers scraped in batch 254
# 2022-03-31 23:38:34.252246 401 transfers scraped in batch 255
# 2022-03-31 23:38:37.173176 394 transfers scraped in batch 256
# 2022-03-31 23:38:42.869880 398 transfers scraped in batch 257
# 2022-03-31 23:38:45.872014 373 transfers scraped in batch 258
# 2022-03-31 23:38:48.953665 362 transfers scraped in batch 259
# 2022-03-31 23:38:51.937895 375 transfers scraped in batch 260
# 2022-03-31 23:38:54.865170 381 transfers scraped in batch 261
# 2022-03-31 23:39:00.660091 409 transfers scraped in batch 262
# 2022-03-31 23:39:03.866761 376 transfers scraped in batch 263
# 2022-03-31 23:39:11.235021 369 transfers scraped in batch 264
# 2022-03-31 23:39:15.086503 413 transfers scraped in batch 265
# 2022-03-31 23:39:21.697270 417 transfers scraped in batch 266
# 2022-03-31 23:39:30.518819 328 transfers scraped in batch 267
# 2022-03-31 23:39:40.093534 362 transfers scraped in batch 268
# 2022-03-31 23:39:44.406155 494 transfers scraped in batch 269
# 2022-03-31 23:39:48.059507 417 transfers scraped in batch 270
# 2022-03-31 23:39:53.173183 363 transfers scraped in batch 271
# 2022-03-31 23:39:56.742282 353 transfers scraped in batch 272
# 2022-03-31 23:39:59.945308 375 transfers scraped in batch 273
# 2022-03-31 23:40:02.969622 367 transfers scraped in batch 274
# 2022-03-31 23:40:05.903590 380 transfers scraped in batch 275
# 2022-03-31 23:40:10.286904 297 transfers scraped in batch 276
# 2022-03-31 23:40:13.201181 339 transfers scraped in batch 277
# 2022-03-31 23:40:17.187237 416 transfers scraped in batch 278
# 2022-03-31 23:40:20.716243 370 transfers scraped in batch 279
# 2022-03-31 23:40:29.972571 359 transfers scraped in batch 280
# 2022-03-31 23:40:34.757228 336 transfers scraped in batch 281
# 2022-03-31 23:40:38.322645 286 transfers scraped in batch 282
# 2022-03-31 23:40:41.440647 416 transfers scraped in batch 283
# 2022-03-31 23:40:44.386757 334 transfers scraped in batch 284
# 2022-03-31 23:40:51.412084 387 transfers scraped in batch 285
# 2022-03-31 23:40:54.503549 358 transfers scraped in batch 286
# 2022-03-31 23:40:57.509752 405 transfers scraped in batch 287
# 2022-03-31 23:41:00.843674 406 transfers scraped in batch 288
# 2022-03-31 23:41:03.629889 331 transfers scraped in batch 289
# 2022-03-31 23:41:09.932617 428 transfers scraped in batch 290
# 2022-03-31 23:41:13.261490 427 transfers scraped in batch 291
# 2022-03-31 23:41:16.165163 258 transfers scraped in batch 292
# 2022-03-31 23:41:19.193062 269 transfers scraped in batch 293
# 2022-03-31 23:41:22.903675 286 transfers scraped in batch 294
# 2022-03-31 23:41:31.073304 272 transfers scraped in batch 295
# 2022-03-31 23:41:36.467950 293 transfers scraped in batch 296
# 2022-03-31 23:41:40.709424 292 transfers scraped in batch 297
# 2022-03-31 23:41:44.967089 268 transfers scraped in batch 298
# 2022-03-31 23:41:49.131539 272 transfers scraped in batch 299
# 2022-03-31 23:42:09.761523 270 transfers scraped in batch 300
# 2022-03-31 23:42:28.768839 Retry number 0
# [{'message': 'ActiveRecord::ActiveRecordError: Response code: 500:\nCode: 160, e.displayText() = DB::Exception: Estimated query execution time (30.843144436911917 seconds) is too long. Maximum: 30. Estimated rows to process: 9784132: While executing Remote (version 20.8.11.17 (official build))\n', 'locations': [{'line': 4, 'column': 17}], 'path': ['solana', 'transfers'], 'error_type': 'server'}]
# 2022-03-31 23:42:28.769086 Query failed for reason: OK. sleeping for 0 seconds and retrying...
# 2022-03-31 23:42:29.371736 Retry number 1
# [{'message': 'ActiveRecord::ActiveRecordError: Response code: 500:\nCode: 160, e.displayText() = DB::Exception: Estimated query execution time (30.843144436911917 seconds) is too long. Maximum: 30. Estimated rows to process: 9784132: While executing Remote (version 20.8.11.17 (official build))\n', 'locations': [{'line': 4, 'column': 17}], 'path': ['solana', 'transfers'], 'error_type': 'server'}]
# 2022-03-31 23:42:29.372120 Query failed for reason: OK. sleeping for 60 seconds and retrying...
# 2022-03-31 23:44:32.768375 Retry number 2
# [{'message': 'ActiveRecord::ActiveRecordError: Response code: 500:\nCode: 160, e.displayText() = DB::Exception: Estimated query execution time (30.843144436911917 seconds) is too long. Maximum: 30. Estimated rows to process: 9784132: While executing Remote (version 20.8.11.17 (official build))\n', 'locations': [{'line': 4, 'column': 17}], 'path': ['solana', 'transfers'], 'error_type': 'server'}]
# 2022-03-31 23:44:32.771940 Query failed for reason: OK. sleeping for 120 seconds and retrying...
# 2022-03-31 23:48:36.261705 Retry number 3
# [{'message': 'ActiveRecord::ActiveRecordError: Response code: 500:\nCode: 160, e.displayText() = DB::Exception: Estimated query execution time (30.843144436911917 seconds) is too long. Maximum: 30. Estimated rows to process: 9784132: While executing Remote (version 20.8.11.17 (official build))\n', 'locations': [{'line': 4, 'column': 17}], 'path': ['solana', 'transfers'], 'error_type': 'server'}]
# 2022-03-31 23:48:36.262770 Query failed for reason: OK. sleeping for 180 seconds and retrying...

# %%
        ix = pd.read_csv("friktion_ix.csv")
        deposits = pd.read_csv("friktion_deposit.csv")
#         withdrawals = pd.read_csv(self.withdraw_fname)
#         claim = pd.read_csv(self.withdraw_claim_fname)
#         withdrawals_cxl = pd.read_csv(self.withdraw_cxl_fname)
#         deposits_cxl = pd.read_csv(self.deposit_cxl_fname)
        
#         print(ix)
#         print(deposits)

#         assert ix.loc[ix.instructionType=="Deposit"].shape[0] == deposits.shape[0]
#         assert ix.loc[ix.instructionType=="Withdraw"].shape[0] == withdrawals.shape[0]
#         assert ix.loc[ix.instructionType=="ClaimPendingWithdrawal"].shape[0] == claim.shape[0]
#         assert ix.loc[ix.instructionType=="CancelPendingDeposit"].shape[0] == deposits_cxl.shape[0]
#         assert ix.loc[ix.instructionType=="CancelPendingWithdrawal"].shape[0] == withdrawals_cxl.shape[0]

# %%
deposits.shape

# %%
ix.loc[ix.instructionType=="Deposit"].shape
# Out:
# (29408, 5)

# %%
deposits.sort_values("amount")[::-1]
# Out:
#                                              txSignature        amount  \
# 7486   3FvYTiomvJTpAjs5XxGc81egpWzebGXA4sSs7VMvWB6c9G...  4.879066e+06
# 11664  3zZ8TKn9gYpFhrqcx8W2HTJikwHSTZLG3GyiqbM12BWPQY...  2.998353e+06
# 19671  5M3H96K3RJghDp5R3SdJsCyeCnRYypTXtL5PvzE6W8wS82...  2.943753e+06
# 1691   2GR1JARZMSRP9wEtvVg5D1tbMptBayGuhCt6BuHjevvztx...  2.904146e+06
# 25363  JBK4C7XkJKknRMD9NTmiengbiBn9rwNTdFd8MUDvbvsSHa...  2.630611e+06
# ...                                                  ...           ...
# 15554  4eVtsrbxsB5yKwANXpWQU5kH5Qc3HAD37ak8L9uzk5GEeU...  1.000000e-09
# 12164  45X8ZKAUZUPZBVorVhavjAgncR2KXynevXNB9sRkAwbSQH...  1.000000e-09
# 16534  4pSgwJkyp6PuitQMC5UiKoJiV1bmUUk9E7VzE73Ds9XMqb...  1.000000e-09
# 2386   2PXZks2t4YUZWQuDc6MNo1nLre5SgMWhumRvGx4jqemQSS...  1.000000e-09
# 3583   2bYFAv2MMyQXzxth6cZpnpj6AFeLyXz2EoizcCvwXvVPF1...  1.000000e-09
#
#       instructionAction instructionOrder  \
# 7486           transfer              1-1
# 11664          transfer              1-1
# 19671          transfer              1-1
# 1691           transfer              0-0
# 25363          transfer              1-1
# ...                 ...              ...
# 15554          transfer            0-0-0
# 12164          transfer              1-1
# 16534          transfer              1-1
# 2386           transfer              0-0
# 3583           transfer              1-1
#
#                                         userAddress             timestamp  \
# 7486   7xTjub4EpTLx7QLHdeJKNQsuVYkqaiGbBd4DJRYjKAYZ  2022-01-13T17:40:28Z
# 11664  CHbwVQQvMvhGxLPBkaL6SZuJ8f895bGHZ5BsLXbaJL3N  2022-02-05T01:47:19Z
# 19671  GmRC6EhKtBEcKM1bjCBzamWDy3qmP5z2Kc9tYjQuc2Pn  2021-12-30T10:31:36Z
# 1691   3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs  2022-03-07T10:10:46Z
# 25363  3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs  2022-03-28T21:44:12Z
# ...                                             ...                   ...
# 15554  GgF8AhcdiJ4hhyFaMoJ3XpQo9q7NgFnNaMQ6x6Xj3Lvt  2021-12-27T02:05:05Z
# 12164  J1sFjvcmhAxiYS5oerp167VDCu1u76csG5bXkkgijVJn  2022-01-24T23:48:03Z
# 16534  GFZpgo47bsmPzLentNshwHnapbryMiu1hfisng7DBbDm  2022-03-30T09:39:59Z
# 2386   5cvX5RGXCbX12Rso1UCTFFDdzgN9W7jMTHCDzKAthmuo  2022-01-26T21:29:48Z
# 3583   FxZMeiQchnuppwe9SeyNYxkVchkpUjnnJsJM9DP3d78U  2022-03-30T09:29:45Z
#
#                      currencyName  \
# 7486         Saber Protocol Token
# 11664                         NaN
# 19671        Saber Protocol Token
# 1691                     USD Coin
# 25363                    USD Coin
# ...                           ...
# 15554  Marinade staked SOL (mSOL)
# 12164  Marinade staked SOL (mSOL)
# 16534  Marinade staked SOL (mSOL)
# 2386   Marinade staked SOL (mSOL)
# 3583   Marinade staked SOL (mSOL)
#
#                                     currencyAddress  \
# 7486    Saber2gLauYim4Mvftnrasomsv6NvAuncvMEZwcLpD1
# 11664  Cvvh8nsKZet59nsDDo3orMa3rZnPWQhpgrMCVcRDRgip
# 19671   Saber2gLauYim4Mvftnrasomsv6NvAuncvMEZwcLpD1
# 1691   EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 25363  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# ...                                             ...
# 15554   mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 12164   mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 16534   mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 2386    mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 3583    mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
#
#                                       senderAddress  \
# 7486   7xTjub4EpTLx7QLHdeJKNQsuVYkqaiGbBd4DJRYjKAYZ
# 11664  CHbwVQQvMvhGxLPBkaL6SZuJ8f895bGHZ5BsLXbaJL3N
# 19671  GmRC6EhKtBEcKM1bjCBzamWDy3qmP5z2Kc9tYjQuc2Pn
# 1691   3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs
# 25363  3KNZ9i1dLNNqpBTKEkTgUQs6TNCd3bzuy6HwfoXACaRs
# ...                                             ...
# 15554  6qfyGvoUqGB6AQ7xLc4pVwFNdgJSbAMkTtKkBXhLRiV1
# 12164  J1sFjvcmhAxiYS5oerp167VDCu1u76csG5bXkkgijVJn
# 16534  GFZpgo47bsmPzLentNshwHnapbryMiu1hfisng7DBbDm
# 2386   5cvX5RGXCbX12Rso1UCTFFDdzgN9W7jMTHCDzKAthmuo
# 3583   FxZMeiQchnuppwe9SeyNYxkVchkpUjnnJsJM9DP3d78U
#
#                                     senderTokenMint  \
# 7486   3JEfWY4V6sQBQXsbXeWkDVA5pqPisudwhxRbWWd76rt9
# 11664  424dm7Lauis6QRBreU9nt8yvwe1FZqUtp6oiEAzMcttQ
# 19671  FLEiW8R1qj2XnZ5vuJskFZ1X7umntUJV2DAgFRckcfv5
# 1691   8LrqyZvCsyBVFXDU9YbVAj6ukJ9tSKeXTmXNHWfZkGRF
# 25363  8LrqyZvCsyBVFXDU9YbVAj6ukJ9tSKeXTmXNHWfZkGRF
# ...                                             ...
# 15554  5Vfn9EmBYkxDFASQKLEZqDuDCT2G2tbmNrizisa4m4uL
# 12164  EqXN26d6mKUKPXrziWxaHxF7wsDzt95vWPnFkFMe7Nok
# 16534  5BMHymXSNFgyoGYzxx6b9yGTTq4zRwXzCkrwu2SUFs2n
# 2386   EFHB1NyzjTQW7hmAorGzHBoUqdVZDsGQ4jDVyPMXTvjn
# 3583   ExAoBt7qQuc7G7sX65AA7nmxfTw4ZemWMFzJdvzz1Dmc
#
#                                     receiverAddress globalId vaultAuthority  \
# 7486   BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h      NaN            NaN
# 11664  AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8      NaN            NaN
# 19671  BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h      NaN            NaN
# 1691   BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ      NaN            NaN
# 25363  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY      NaN            NaN
# ...                                             ...      ...            ...
# 15554  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 12164  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 16534  6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 2386   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
# 3583   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH      NaN            NaN
#
#       shareTokenMint depositTokenSymbol depositTokenCoingeckoId userAction
# 7486             NaN                NaN                     NaN    Deposit
# 11664            NaN                NaN                     NaN    Deposit
# 19671            NaN                NaN                     NaN    Deposit
# 1691             NaN                NaN                     NaN    Deposit
# 25363            NaN                NaN                     NaN    Deposit
# ...              ...                ...                     ...        ...
# 15554            NaN                NaN                     NaN    Deposit
# 12164            NaN                NaN                     NaN    Deposit
# 16534            NaN                NaN                     NaN    Deposit
# 2386             NaN                NaN                     NaN    Deposit
# 3583             NaN                NaN                     NaN    Deposit
#
# [29406 rows x 17 columns]

# %%
pd.options.display.width = 0

# %%
deposits.loc[
    deposits.vaultAuthority=="Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G"].sort_values("amount")[["timestamp", "amount", "txSignature"]]
# Out:
#                  timestamp        amount  \
# 7978  2022-02-25T19:56:08Z  1.000000e-09
# 5862  2022-02-12T02:52:57Z  1.000000e-09
# 479   2022-02-03T21:05:08Z  1.000000e-09
# 4532  2022-03-18T14:21:43Z  1.000000e-09
# 5087  2022-01-07T15:34:27Z  1.000000e-09
# ...                    ...           ...
# 2415  2022-01-12T08:06:22Z  3.638800e+03
# 4309  2022-03-30T16:18:44Z  8.230664e+03
# 4799  2022-02-01T16:45:17Z  8.586272e+03
# 2362  2022-02-17T09:13:40Z  1.168541e+04
# 5075  2022-01-21T14:59:41Z  1.581595e+04
#
#                                             txSignature
# 7978  mQPf6mdLdSpCtnmvPkKarwhMykNNp5FEzKg6yzvJbo12yG...
# 5862  5VtrMPM6nGsWSzeWrFQ4dQFnHyixUMmK4GXF5wzyRsYp2L...
# 479   2H4hQFTSkvWJUTr3t5f9i8hFDG1XW7Rak31WoiDLqf733t...
# 4532  4h55mB7Hwosedtx3kttVfbLmAGdKoHkKRoSY7fhBoufYVU...
# 5087  52jsKGk4ryoqbQCiNnZg1TcDJ81RHxq5PrptiunnjW3TJb...
# ...                                                 ...
# 2415  3Rkt6Z9QHzxxrP6FhVoLA4jkcKCXJPjASDsjeUHmbbBsUd...
# 4309  4a2KegHZpt2Mfp45FjcbFUVV1HsMHSHzyN6kfML9mJ8qrN...
# 4799  4rbL6s8PcsHaPBBM5Sf1mgGBkQHUvVo8zxa5VhP92oU2oN...
# 2362  3PezBkLDECULRfmgLNz92qZewjzC6oAbr7xAbstGTuV1CN...
# 5075  529CebmeMLq6PLXNyNW4WTTNuEVKGoyNsUcGyQb1VVMvjc...
#
# [2680 rows x 3 columns]

# %%
deposits.loc[
    deposits.vaultAuthority=="Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G"].sort_values("amount")[["timestamp", "amount", "txSignature"]][::-1].iloc[3]["txSignature"]
# Out:
# '4a2KegHZpt2Mfp45FjcbFUVV1HsMHSHzyN6kfML9mJ8qrN4iQKGUWPXBetXMrGKDRtu8JuhZPC4ttBZqaiAtL3dD'

# %%
depsots

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId', 'userAction'],
#       dtype='object')

# %%
deposits

# %%
# Have Price
# Have VoltTokenShare

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId'],
#       dtype='object')

# %%
deposits.shape
# Out:
# (115, 16)

# %%
deposits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   txSignature              115 non-null    object
#  1   amount                   115 non-null    float64
#  2   instructionAction        115 non-null    object
#  3   instructionOrder         115 non-null    object
#  4   userAddress              115 non-null    object
#  5   timestamp                115 non-null    object
#  6   currencyName             115 non-null    object
#  7   currencyAddress          115 non-null    object
#  8   senderAddress            115 non-null    object
#  9   senderTokenMint          115 non-null    object
#  10  receiverAddress          115 non-null    object
#  11  globalId                 115 non-null    object
#  12  vaultAuthority           115 non-null    object
#  13  shareTokenMint           115 non-null    object
#  14  depositTokenSymbol       115 non-null    object
#  15  depositTokenCoingeckoId  115 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 14.5+ KB

# %%
deposits.columns
# Out:
# Index(['txSignature', 'amount', 'instructionAction', 'instructionOrder',
#        'userAddress', 'timestamp', 'currencyName', 'currencyAddress',
#        'senderAddress', 'senderTokenMint', 'receiverAddress', 'globalId',
#        'vaultAuthority', 'shareTokenMint', 'depositTokenSymbol',
#        'depositTokenCoingeckoId'],
#       dtype='object')

# %%
deposits.iloc[0]
# Out:
# txSignature                122tbxak1CeaRQSMZD2izGb9tXa7rSaRpyD2s3iSv4bKp3...
# amount                                                              1.062448
# instructionAction                                                       burn
# instructionOrder                                                         1-1
# userAddress                     GbYTQgbXndUJoczx23Hy3hobAReguEuddijnsRTkn8pJ
# timestamp                                               2022-01-09T10:12:13Z
# currencyName                                                             NaN
# currencyAddress                 6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt
# senderAddress                   GbYTQgbXndUJoczx23Hy3hobAReguEuddijnsRTkn8pJ
# senderTokenMint                 2ALneL69HRuthso7f4inq75g8AYBTbKHKgFB2oBgE6mh
# receiverAddress                                                          NaN
# globalId                                                                 NaN
# vaultAuthority                                                           NaN
# shareTokenMint                                                           NaN
# depositTokenSymbol                                                       NaN
# depositTokenCoingeckoId                                                  NaN
# userAction                                                          Withdraw
# Name: 0, dtype: object

# %%
deposits.loc[deposits.depositTokenCoingeckoId.isna()].currencyAddress
# Out:
# Series([], Name: currencyAddress, dtype: object)

# %%
deposits.shape
# Out:
# (115, 16)

# %%
deposits.loc[deposits.txSignature=="24y4KRma4BUarjw4y8Rv9Dt1kZdVVSP5kVnkbu4Ra5KMs7G9Df2Vb9C1b3M8f6yCuNuhsEW9s1WR8WrSKuN5bVBX"].iloc[0]
# Out:
# txSignature                24y4KRma4BUarjw4y8Rv9Dt1kZdVVSP5kVnkbu4Ra5KMs7...
# amount                                                                 551.0
# instructionAction                                                   transfer
# instructionOrder                                                         3-1
# userAddress                     9T19SkKUpSNbt2cMcCQVz7NZEfmXW3gdMDkH9db1yidw
# timestamp                                               2022-03-17T18:39:38Z
# currencyName                                                     Wrapped SOL
# currencyAddress                  So11111111111111111111111111111111111111112
# senderAddress                   9T19SkKUpSNbt2cMcCQVz7NZEfmXW3gdMDkH9db1yidw
# senderTokenMint                 D9QnLjbjTEBCqFZUrovoFkNW3B8gLmsJkT6PDt4HUv1H
# receiverAddress                  wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# globalId                                        mainnet_income_call_sol_high
# vaultAuthority                   wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# shareTokenMint                  DNa849drqW19uBV5X9ohpJ5brRGzq856gk3HDRqveFrA
# depositTokenSymbol                                                       SOL
# depositTokenCoingeckoId                                               solana
# Name: 2, dtype: object

# %%
deposits.loc[deposits.txSignature=="1kx6PYTANDwsAZGZ5xoRNe51uRK68k6roF6KYDauHQMmemH4JunDBCA47oHT2J1QUbh5YJHFdoZtQECqUVLVbZp"].iloc[0]
# Out:
# txSignature                1kx6PYTANDwsAZGZ5xoRNe51uRK68k6roF6KYDauHQMmem...
# amount                                                               0.99859
# instructionAction                                                   transfer
# instructionOrder                                                         1-1
# userAddress                     79jbRVMQu5rQkEcAPbzZNqnwKEASHyEyWgUn9q76yUKT
# timestamp                                               2022-03-17T19:33:26Z
# currencyName                                       Wrapped Ethereum (Sollet)
# currencyAddress                 2FPyTwcZLUg1MDrwsyoP4D6s1tM7hAkHYRjkNb5w6Pxk
# senderAddress                   79jbRVMQu5rQkEcAPbzZNqnwKEASHyEyWgUn9q76yUKT
# senderTokenMint                 3e81Tr2AGVLwPLLsUwiBSaYdGDwSxCMXmhF5ZWUuQAsn
# receiverAddress                 FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# globalId                                             mainnet_income_call_eth
# vaultAuthority                  FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# shareTokenMint                  GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS
# depositTokenSymbol                                                       ETH
# depositTokenCoingeckoId                                             ethereum
# Name: 0, dtype: object

# %%
zz = pd.DataFrame(
                dict(
                    json.loads(
                        requests.get(
                            "https://friktion-labs.github.io/mainnet-tvl-snapshots/friktionSnapshot.json"
                        ).content
                    )
                )["allMainnetVolts"]
            )

# %%
zz
# Out:
#                                   globalId  \
# 0                  mainnet_income_call_btc
# 1                  mainnet_income_call_sol
# 2             mainnet_income_call_sol_high
# 3             mainnet_income_call_marinade
# 4                  mainnet_income_call_eth
# 5                  mainnet_income_call_ftt
# 6                  mainnet_income_call_srm
# 7                 mainnet_income_call_mngo
# 8               mainnet_income_call_socean
# 9                  mainnet_income_call_sbr
# 10                mainnet_income_call_luna
# 11                 mainnet_income_call_ray
# 12                mainnet_income_call_step
# 13               mainnet_income_call_stsol
# 14                mainnet_income_call_avax
# 15                 mainnet_income_put_luna
# 16                  mainnet_income_put_sol
# 17             mainnet_income_put_sol_high
# 18                 mainnet_income_put_mngo
# 19                  mainnet_income_put_btc
# 20               mainnet_income_put_tsUSDC
# 21                  mainnet_income_put_eth
# 22    mainnet_income_put_sol_step_circuits
# 23  mainnet_income_put_sol_parrot_circuits
# 24  mainnet_income_put_eth_parrot_circuits
# 25    mainnet_income_put_btc_step_circuits
# 26     mainnet_income_put_sol_uxd_circuits
#
#                                   vaultAuthority  \
# 0   DA1M8mw7GnPNKU9ReANtHPQyuVzKZtsuuSbCyc2uX2du
# 1   Hxtb6APfNtf9m8jJjh7uYp8fCTGr9aeHxBSfiPqCrV6G
# 2    wJAoeEG2sfQ1xgXUNVVkJ5mCTCw4SLc6oJafDwf6jTf
# 3   6asST5hurmxJ8uFvh7ZRWkrMfSEzjEAJ4DNR1is3G6eH
# 4   FThcy5XXvab5u3jbA6NjWKdMNiCSV3oY5AAkvEvpa8wp
# 5   7KqHFuUksvNhrWgoacKkqyp2RwfBNdypCYgK9nxD1d6K
# 6   2P427N5sYcEXvZAZwqNzjXEHsBMESQoLyjNquTSmGPMb
# 7   B3yakZxwomkmnCxRr8ZmQtiWgtxtVBuCREDFDdAvcCVQ
# 8   A5MpyajTy6hdsg3S2em5ukcgY1ZBhxTxEKv8BgHajv1A
# 9   BH7Jg3f97FyeGxsPR7FFskvfqGiaLeUnJ9Ksda53Jj8h
# 10  5oV1Yf8q1oQgPYuHjepjmKFuaG2Wng9dzTqbSWhU5W2X
# 11  A6XsYxGj9wpqUZG81XwgQJ2zJ3efCbuWSQfnkHqUSmdM
# 12  FiEHDTKT6X7VFwGaUmsm1XXYr8vvkoSR5EqcY4znpefq
# 13  2Ahpeqc1bo7Y4dVknvZUVfZPhHhym7JN6az2XMbUA6QA
# 14  5LrULR5w9N1dfnJ9vHnzRkQi9uBL3CkSRWkDGTG6dP1e
# 15  5kA7FPiB3t2X5s65dK1AoEu5asDjC5d7f5vaB4iY2yrj
# 16  6Nkc8MEiz3WLz1xthYitmSuy3NGwn7782upRHo2iFmXK
# 17  BThMeTgWZBoBbAzp9sK9T7gQzpQDQdRQUVLtVQ3781q1
# 18  CVrRw6VtxSjokm2tKmaS5RCuoc9EFjN4wEoov6f2PST6
# 19  GrB6vbG2WP7eEnbwgxUbBGRMeXYq139jo2o9oW8cNK8f
# 20  AQRGh6PU7LzDHvvoPNS7wVVQaCBeftw9kVDAnvuEjbs8
# 21  EA29Xf3HGMtYziw7UKZDUKby7gkoCbXwmiNKwc7z54Ax
# 22  BVrYZ1XpjK85kYKSd2bsQweidBJxHnf8exbpZCNcMdTQ
# 23  EevTHu56oXvQSFw8yVFs9spjVCVsxemDLMpvfApW32eD
# 24  EfxrH3pwGBuRJgbbA9x5skFamLVXUhDnA7DukZmDsjaL
# 25  8ENPcthqhuWVaTG3eE28zJHxm4BWzyiyCFgqZL44szTY
# 26  HXNJ9xq648Ju9uJCZjxybBz4VHajMUCGo9hsF3Sb8Yyz
#
#                                   shareTokenMint depositTokenSymbol  \
# 0   3BjcHXvyzMsjmeqE2qFLx45K4XFx3JPiyRnjJiF5MAHt                BTC
# 1   4Hnh1UCC6HLzx9NaGKnTVHR2bANcRrhydumdHCnrT3i2                SOL
# 2   DNa849drqW19uBV5X9ohpJ5brRGzq856gk3HDRqveFrA                SOL
# 3   6UA3yn28XecAHLTwoCtjfzy3WcyQj1x13bxnH8urUiKt               mSOL
# 4   GjnoPUjQiEUYWuKAbMax2cM1Eony8Yutc133wuSun9hS                ETH
# 5   7wDh4VCTPwx41kvbLE6fkFgMEjnqw7NpGJvQtNabCm2B                FTT
# 6   5SLqZSywodLS8ih6U2AAioZrxpgR149hR8SApmCB7r5X                SRM
# 7   4sTuzTYfcE2NF7zy6Sy8XhVcNLa6JQSLrx3roy97n4sD               MNGO
# 8    5VmdHqvRMbXivuC34w4Hux9zb1y9moiBEQmXDrTR1kV             scnSOL
# 9   DPMCwE9z9jXaDVDti5aKhdgCWGgsvioz6ZvB9eZjH7UE                SBR
# 10  95sn4kgeJnnBfRCD8S2quu4HS9Y6vb7JDuXrarnmEjYE               LUNA
# 11   SoAnGsHVqSyaN4MjWoPCcftC1V6oSeNxLJjF5TXrtuL                RAY
# 12  AQFLXqLLofcbUCoi5HPfuuvX6vMPafubZfBNBMumnKq2               STEP
# 13  EPoDdEcDQ478YNRAiMYMHLs7mEnmo5z9322Q2D5exKFU              stSOL
# 14  HLfkEc6E2HEcABaWm3QZSfDvswzXjh1onF9xEzUAtWNS               AVAX
# 15  74ozhToAS71nDVBtFZMMucdkNB95tV2o5fhtFGQeixwS                UST
# 16  EBPM7fvPN8EuA65Uc7DT9eGyDUZ1sqMLM8Rb8y2YxBYU               USDC
# 17  G8jsAWUA2KdDn7XmV1sBqUdbEXESaPdjPWDEYCsnkRX2               USDC
# 18  CxHG1tPkeEHsAVmPF2UrjZK3W719J5DGFgMaLtUkBoeP               USDC
# 19   THjfJ7GUeW6aMU6dzYYFVs5LnKNvmPzgk2wbh3bWagC               USDC
# 20  Fw8mw9zNyfngvBYuS2L6XWfvFE8fExQ3apZVw4Ery5oy             tsUSDC
# 21  2uTkms42P62dJ7JRaefc1HFkvyBeMP28J6MPmH1gVHoT               USDC
# 22   Bikt7D3nMQmJSpxX7oczCDKgevrpWk3g4D3VhQZzqAT               USDC
# 23  J1TX6c1R6WykW2wonvrL6xA2g8vZ2FLDqDDF1mLYrMYK               USDC
# 24  5VF9CTD9GNNDSrfQ1ZswfMdCc2NkbH2hvTirSb1FMEo3               USDC
# 25  ET4nQ6we7KDemfzni8dy2EkNCuYo1RryiRPjC6XwnnC3               USDC
# 26  BAyzqZuKUQ4k93Yfm3xp85SkAKtr4xghBsqZLBTZT14z               USDC
#
#    depositTokenCoingeckoId
# 0                  bitcoin
# 1                   solana
# 2                   solana
# 3                     msol
# 4                 ethereum
# 5                ftx-token
# 6                    serum
# 7            mango-markets
# 8        socean-staked-sol
# 9                    saber
# 10              terra-luna
# 11                 raydium
# 12            step-finance
# 13         lido-staked-sol
# 14             avalanche-2
# 15                terrausd
# 16                usd-coin
# 17                usd-coin
# 18                usd-coin
# 19                usd-coin
# 20                usd-coin
# 21                usd-coin
# 22                usd-coin
# 23                usd-coin
# 24                usd-coin
# 25                usd-coin
# 26                usd-coin
